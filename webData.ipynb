# %% [markdown]
# # Intercity Python API Development

# %%
from bs4 import BeautifulSoup
import requests
import numpy
import tweepy

# %%
loadSite = requests.get('http://www.intercity.co.nz/')
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-24-70ce13f5eb16> in <module>()
# ----> 1 loadSite = requests.get('http://www.intercity.co.nz/')
#
# /usr/local/lib/python2.7/dist-packages/requests/api.pyc in get(url, **kwargs)
#      53
#      54     kwargs.setdefault('allow_redirects', True)
# ---> 55     return request('get', url, **kwargs)
#      56
#      57
#
# /usr/local/lib/python2.7/dist-packages/requests/api.pyc in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ---> 44     return session.request(method=method, url=url, **kwargs)
#      45
#      46
#
# /usr/local/lib/python2.7/dist-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert)
#     355             'allow_redirects': allow_redirects,
#     356         }
# --> 357         resp = self.send(prep, **send_kwargs)
#     358
#     359         return resp
#
# /usr/local/lib/python2.7/dist-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     458         start = datetime.utcnow()
#     459         # Send the request
# --> 460         r = adapter.send(request, **kwargs)
#     461         # Total elapsed time of the request (approximately)
#     462         r.elapsed = datetime.utcnow() - start
#
# /usr/local/lib/python2.7/dist-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     352
#     353         except MaxRetryError as e:
# --> 354             raise ConnectionError(e)
#     355
#     356         except (_SSLError, _HTTPError) as e:
#
# ConnectionError: HTTPConnectionPool(host='www.intercity.co.nz', port=80): Max retries exceeded with url: / (Caused by <class 'socket.gaierror'>: [Errno -2] Name or service not known)

# %%
reTweetz = open('testing.txt', 'w')
reTweetz.write('Testing Git')
reTweetz.close()

# %%
daTweetz = open('testing.txt', 'r')

daTweetz.read()
# Out:
# 'Testing Git'

# %%
# %%bash
# git add .
# git commit -m daTweetz
# Out:
# [master 023ebf4] daTweetz
#  1 file changed, 1 insertion(+)

# %%
testing = []

# %%
testing.append(daTweetz)

# %%
print testing
# Out:
# [<open file 'testing.txt', mode 'r' at 0x37f5390>, <open file 'testing.txt', mode 'r' at 0x37f5390>]

# %%
for site in loadSite:
    daLink = []
    dafile = open('output', 'w')
    daLink.append(site)
    inter = BeautifulSoup(site)
    daLink.append(inter)
    geter = inter.text
    daLink.append(geter)
    print'print daLink'
    beuLink = BeautifulSoup(daLink[0])
    print beuLink
# Out:
# print daLink
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <base href="http://ww"/></head></html>
# print daLink
# <html><body><p>w.intercity.co.nz/"&gt;<!--[if lte IE 6]></base><![endif]-->
# <meta charset="utf-8"/>
# </p><title>InterCity // Bus Ticket</title></body></html>
# print daLink
# <html><body><p>s From $1 // NZâs National Network // Bus Pass
#
#
# 		<meta content="New Zealand's most popul" name="description"/></p></body></html>
# print daLink
# <html><body><p>ar bus network. Bus tickets from $1 (+booking fee). Bus passes for backpackers. Book online - no credit card required. " /&gt;<meta/></p></body></html>
# print daLink
# <html><body><p>name="keywords" content="" /&gt;
#
# 		<link href="/assets/intercity12/main/favicon.ico" rel="shortcut icon"/>
# </p></body></html>
# print daLink
# <html><head><style>
# 					/*#Header {background: transparent url('/assets/intercity/main/header5.jpg') no-repeat !important;}*/
# 				<</style></head></html>
# print daLink
# <html><body><p>/style&gt;
#
#
#
#
#
# <!-- -->
# <link href="http://www.intercity.co.nz/mysite/javascr" rel="stylesheet" type="text/css"/></p></body></html>
# print daLink
# <html><body><p>ipt/lib/jquery-ui-themes/custom/jquery-ui-1.8.21.custom.css?m=1369093914" /&gt;
# <link href="http:/" rel="stylesheet" type="text/css"/></p></body></html>
# print daLink
# <html><body><p>/www.intercity.co.nz/mysite/javascript/lib/jquery-fancybox/jquery.fancybox-1.3.1.css?m=1369093915" /&gt;
# <link rel="stylesheet" typ=""/></p></body></html>
# print daLink
# <html><body><p>e="text/css" href="http://www.intercity.co.nz/mysite/css/iealert/style.css?m=1369093914" /&gt;
# <link rel="stylesheet" type="text/cs"/></p></body></html>
# print daLink
# <html><body><p>s" href="http://www.intercity.co.nz/mysite/css/common.css?m=1369093914" /&gt;
# <link href="http://w" rel="stylesheet" type="text/css"/></p></body></html>
# print daLink
# <html><body><p>ww.intercity.co.nz/themes/intercity12/css/reservations.css?m=1386162012" /&gt;
# <link href="http://" rel="stylesheet" type="text/css"/></p></body></html>
# print daLink
# <html><body><p>www.intercity.co.nz/themes/intercity12/css/app.css?m=1386162005" /&gt;
# <link href="http://www.inte" rel="stylesheet" type="text/css"/></p></body></html>
# print daLink
# <html><body><p>rcity.co.nz/themes/intercity12/css/typography.css?m=1386162006" /&gt;
# <link href="http://www.inter" rel="stylesheet" type="text/css"/></p></body></html>
# print daLink
# <html><body><p>city.co.nz/bookingelements/css/StopPickerField.css?m=1339120101" /&gt;
# <script type="text/javascript">
# var _gaq = _gaq || [];
# _ga</script></p></body></html>
# print daLink
# <html><body><p>q.push(['_setAccount', 'UA-1266228-1']);
# _gaq.push(['_setDomainName', '.intercity.co.nz']);
# _gaq.push(['_setAllowLinker', true</p></body></html>
# print daLink
# <html><body><p>]);
# _gaq.push(['_trackPageview']);
#
# (function() {
# 	var ga = document.createElement('script');
# 	ga.type = 'text/javascript'</p></body></html>
# print daLink
# <html><body><p>;
# 	ga.async = true;
# 	ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.co</p></body></html>
# print daLink
# <html><body><p>m/ga.js';
# 	var s = document.getElementsByTagName('script')[0];
# 	s.parentNode.insertBefore(ga, s);
# })();
#
# (function recordO</p></body></html>
# print daLink
# <html><body><p>utboundLink(link, category, action) {
#   try {
#     var myTracker=_gat._getTrackerByName();
#     _gaq.push(['myTracker._trackEve</p></body></html>
# print daLink
# <html><body><p>nt', ' + category + ', ' + action + ']);
#     setTimeout('document.location = "' + link.href + '"', 100)
#   }catch(err){}
# })();</p></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>lass="twenty columns"&gt;
#
# 					</p><div class="row" id="Header">
# <div class="twenty columns">
# <a class="logo l" href="/"></a></div></div></body></html>
# print daLink
# <html><body><p>eft" onClick="_gaq.push(['_trackEvent', 'HeaderLogo', 'Back Home', 'InterCity Logo']);"&gt;<img src="/assets/intercity12/main/iclog"/></p></body></html>
# print daLink
# <html><body><p>o.png" alt="iclogo.png" /&gt;
# 	</p><h2 class="left">Low fares, everywhere, everyday.</h2>
# <ul class="header-link right"><li></li></ul></body></html>
# print daLink
# <html><body><p>a href="http://m.intercity.co.nz"&gt;Mobile Site
# </p><li><a href="/info/about-us/">About Us</a></li>
# <li><a href="" id="feedback"></a></li></body></html>
# print daLink
# <html><body><p>="/contact-us"&gt;Contact Us
#
# 	</p><div class="clear"></div>
# <div class="" id="Navigation"></div></body></html>
# print daLink
# <html><body><p>row"&gt;
# 						</p><div class="twenty columns" id="Menu">
# <ul class="nav-bar">
# <li class="has-flyout">
# </li></ul></div></body></html>
# print daLink
# <html><body><a class="current" href="/">H</a>
# <a class="flyout-toggle" href="/#"><span></span></a>
# <li clas=""></li></body></html>
# print daLink
# <html><body><p>s="has-flyout"&gt;
#
# 						<span class="has-a-submenu">Travel Info</span>
# <a class="flyout-toggle" href="/#"><span></span></a></p></body></html>
# print daLink
# <html><body><p>pan&gt;
#
# 						</p><ul class="flyout">
# </ul></body></html>
# print daLink
# <html><body><a href="/travel-info/route-map/">View the route map</a>
# <div></div></body></html>
# print daLink
# <html><body><p>class="sub-menu-block"&gt;
# 								</p><li>
# <a href="/travel-info/north-island-booking-agents/">Booking Agents</a></li></body></html>
# print daLink
# <html><body><p>/a&gt;
#
#
#
#
#
# 								</p><div class="sub-menu-block">
# <li>
# </li></div></body></html>
# print daLink
# <html><body><a href="/travel-info/child-fares/">Child Fares </a>
# <div c=""></div></body></html>
# print daLink
# <html><body><p>lass="sub-menu-block"&gt;
# 								</p><li>
# <a href="/travel-info/frequently-asked-questions/">FAQ's</a>
# </li></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>href="/travel-info/delays-and-disruptions/"&gt;Delays / Disruptions
#
#
#
#
# 							--&gt;
# </p></body></html>
# print daLink
# <html><body><div class="subMenuRightColumn"><div class="menu-section">
# <h2><img src="assets/intercity12/main/ICONSMENU/_resampled/res"/></h2></div></div></body></html>
# print daLink
# <html><body><p>izedimage2525-timetable_icon2.png" alt="&gt;" width="25" height="25" title=""/&gt; Timetables
# </p><ul><li><a href="/timetable">Tim</a></li></ul></body></html>
# print daLink
# <html><body><p>etables and Bus Stops
# </p><li><a href="/route-map">Route Map</a></li>
# <div class="menu-section">
# <h2><img src=""/></h2></div></body></html>
# print daLink
# <html><body><p>assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-changes_icon2.png" alt="&gt;" width="25" height="25" title=""/&gt; Ch</p></body></html>
# print daLink
# <html><body><p>anges &amp; Refunds
# </p><ul><li><a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a></li>
# <li><a>Â </a></li></ul></body></html>
# print daLink
#
# print daLink
# <html><body><p>ng" alt="&gt;" width="28" height="28" title=""/&gt; Fares &amp; Bookings
# </p><ul><li><a href="/getting-a-1-fare">Getting a $1 Fare</a></li></ul></body></html>
# print daLink
#
# print daLink
# <html><body><p>Student,Backpacker &amp; Senior Fares
#
# </p><div class="menu-section">
# <h2><img src="assets/intercity12/main/ICON"/></h2></div></body></html>
# print daLink
# <html><body><p>SMENU/_resampled/resizedimage2525-luggage_icon2.png" alt="&gt;" width="25" height="25" title=""/&gt; Luggage
# </p><ul><li><a href=""></a></li></ul></body></html>
# print daLink
# <html><body><p>/carryon-checked-luggage"&gt;Carry on and Checked Luggage
# </p><li><a href="/oversized-items">Oversized Items/Bicycles</a></li></body></html>
# print daLink
# <html><body><li>Â </li>
# <div class="menu-section">
# <h2><img src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-"/></h2></div></body></html>
# print daLink
# <html><body><p>agents_icon2.png" alt="&gt;" width="25" height="25" title=""/&gt; Booking Agents
# </p><ul><li><a href="/north-island-booking-agents"></a></li></ul></body></html>
# print daLink
# <html><body><p>/"&gt;Find a North Island Agent
# </p><li><a href="/south-island-booking-agents/">Find a South Island Agent</a></li>
# </body></html>
# print daLink
# <html><body><div class="menu-section">
# <h2><img alt="&amp;" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-delays_icon2.png"/></h2></div></body></html>
# print daLink
# <html><body><p>gt;" width="25" height="25" title=""/&gt; Delays &amp; Disruptions
# </p><ul><li><a href="/delays-and-disruptions">View Current Disr</a></li></ul></body></html>
# print daLink
# <html><body><p>uptions
# </p><li>Â </li>
# <div class="menu-section">
# <h2><img src="assets/intercity12/main/ICONSMENU/_resampled/r"/></h2></div></body></html>
# print daLink
# <html><body><p>esizedimage2525-special_assistance_icon2.png" alt="&gt;" width="25" height="25" title=""/&gt; Special Assistance
# </p><ul><li><a hr=""></a></li></ul></body></html>
# print daLink
# <html><body><p>ef="/special-assistance"&gt;Special Needs and Assistance
#
# </p><div class="menu-section">
# <h2><img src="assets/inter"/></h2></div></body></html>
# print daLink
# <html><body><p>city12/main/ICONSMENU/_resampled/resizedimage2525-children_icon2.png" alt="&gt;" width="25" height="25" title=""/&gt; Travelling wi</p></body></html>
# print daLink
# <html><body><p>th Children
# </p><ul><li><a href="/child-fares">Child Fares</a></li>
# <li><a href="http://www.intercity.co.nz/assets/file/interci"></a></li></ul></body></html>
# print daLink
# <html><body><p>tyunaccompanied.pdf"&gt;Unaccompanied Minor Form
#
# </p><div class="menu-section faq"><a href="/frequently-asked-ques"></a></div></body></html>
# print daLink
# <html><body><p>tions/"&gt;
# </p><h2><img alt="&gt;" height="" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-faq_icon2.png" width="25"/></h2></body></html>
# print daLink
# <html><body><p>="25" title=""/&gt; Frequently Asked Questions
#
# </p><div class="menu-section groupbooking"><a href="/group-bookings">
# <h></h></a></div></body></html>
# print daLink
# <html><body><p>2&gt;<img alt="&gt;" height="" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-groupbookings_icon2.png" width="25"/></p></body></html>
# print daLink
# <html><body><p>"25" title=""/&gt; Group Bookings
#
#
#
#
#
# 			</p><li class="has-flyout">
# </li></body></html>
# print daLink
# <html><body><span class="has-a-submenu">Manage Booking</span>
# <a class="flyout-toggle" href="/#"><span></span></a>
# </body></html>
# print daLink
# <html><body><p>ul class="flyout"&gt;
# 							</p></body></html>
# print daLink
# <html><body><p>ng/change-cancel-a-booking/"&gt;How to Modify/Cancel a Booking
#
#
#
#
# 							--&gt;
# 					</p></body></html>
# print daLink
# <html><body><div class="subMenuRightColumn"><div class="menu-section">
# <h2><img src="/assets/intercity12/main/ICONSMENU/manage_icon2.png"/></h2></div></div></body></html>
# print daLink
# <html><body><p>alt="&gt;"/&gt; Manage your booking
# </p><ul><li><a href="/change-cancel-a-booking">How To Change/Cancel a Booking</a></li>
# <li><a></a></li></ul></body></html>
# print daLink
# <html><body><p>href="/managebooking"&gt;Login to Manage a booking
#
# </p><div class="menu-section">
# <h2><img src="assets/intercity12"/></h2></div></body></html>
# print daLink
# <html><body><p>/main/ICONSMENU/_resampled/resizedimage2525-changes_icon2.png" alt="&gt;" width="25" height="25"/&gt; Changes &amp; Refunds
# <u></u></p></body></html>
# print daLink
# <html><body><p>l&gt;</p><li><a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a></li>
# </body></html>
# print daLink
# <html><body><p>i&gt;
#
# 			</p><li class="has-flyout">
# <span class="has-a-submenu">Frequent Travellers</span>
# <a cla="" href="/#"></a></li></body></html>
# print daLink
# <html><body><p>ss="flyout-toggle"&gt;<span></span>
# </p><ul class="flyout">
# </ul></body></html>
# print daLink
# <html><body><li>
# <a href="/frequent-travellers/how-it-works/">How it Works</a>
# </li>
# </body></html>
# print daLink
#
#
# print daLink
# <html><body><p>-club-freeway/"&gt;Join Club Freeway
#
#
#
#
#
# 								</p><div class="sub-menu-block"></div></body></html>
# print daLink
# <html><body><p>"&gt;
# 								</p><li>
# <a href="/frequent-travellers/forgotpwd/">Club Password Reset</a>
# </li></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>city12/main/ICONSMENU/_resampled/resizedimage2828-rewards_icon2.png" alt="&gt;" width="28" height="28" title=""/&gt; FREEWAY Travel</p></body></html>
# print daLink
# <html><body><p>Rewards
# </p><ul><li><a href="/how-it-works">How it works </a></li>
# <li><a href="/about-earning-free-travel">Earning FREE Trave</a></li></ul></body></html>
# print daLink
# <html><body><p>l
# </p><li><a href="/join-club-freeway">Join FREEWAY</a></li>
# <div class="menu-section">
# <h2><img src="assets/in"/></h2></div></body></html>
# print daLink
# <html><body><p>tercity12/main/ICONSMENU/_resampled/resizedimage2525-freewaymember_icon2.png" alt="&gt;" width="25" height="25" title=""/&gt; FREEW</p></body></html>
# print daLink
# <html><body><p>AY Members
# </p><ul><li><a href="/rewards">Login to FREEWAY</a></li>
# <li><a href="/clubpasswordreset">Forgotten Password?</a></li></ul></body></html>
# print daLink
# <html><body><p>i&gt;
#
# </p><div class="menu-section">
# <h2><img src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2828-cheapas_ic"/></h2></div></body></html>
# print daLink
# <html><body><p>on2.png" alt="&gt;" width="28" height="28" title=""/&gt; Cheap-as Seats
# </p><ul><li><a href="/cheapas">Sign up for special offers</a></li></ul></body></html>
# print daLink
# <html><body><p>/a&gt;
#
#
#
#
#
# 			</p><li class="has-flyout">
# <span class="has-a-subme"></span></li></body></html>
# print daLink
# <html><body><p>nu"&gt;Tours
# 						<a class="flyout-toggle" href="/#"><span></span></a>
# </p><ul class="flyout">
# </ul></body></html>
# print daLink
# <html><body><div class="sub-menu-block">
# <li>
# <a href="/tours/intercity-hobbiton-excursion-auckland-to-"></a></li></div></body></html>
# print daLink
# <html><body><p>auckland/"&gt;Hobbiton Excursion
#
#
#
#
#
# 								</p><div class="sub-menu-block">
# </div></body></html>
# print daLink
# <html><body><li>
# <a href="/tours/intercity-milford-sound-tour/">Milford Sound Tour</a>
# </li></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>ity-dolphin-cruise-tour/"&gt;Dolphin Cruise Tour
#
#
#
#
#
# 								</p><div class="su"></div></body></html>
# print daLink
# <html><body><p>b-menu-block"&gt;
# 								</p><li>
# <a href="/tours/hukafalls-jet/">Hukafalls Jetboat Morning Tour (Return ex Tau</a></li></body></html>
# print daLink
# <html><body><p>po)
#
#
#
#
#
# 								</p><div class="sub-menu-block">
# <li>
# </li></div></body></html>
# print daLink
# <html><body><a href="/tours/the-lord-of-the-rings-film-locations/">LOTR Film Locations</a>
# </body></html>
# print daLink
# <html><body><p>/div&gt;
#
# 								</p><div class="sub-menu-block">
# <li>
# <a href="/tours/therockpass/">Overnight</a></li></div></body></html>
# print daLink
# <html><body><p>Aboard 'The Rock'
#
#
#
#
#
# 								</p><div class="sub-menu-block">
# </div></body></html>
# print daLink
# <html><body><li>
# <a href="/tours/Auckland-Morning-City-tour/">Auckland Morning City Tour </a>
# </li></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>amaki-maori-village-experience/"&gt;Tamaki Maori Village Evening Experience
#
#
#
#
# 				</p></body></html>
# print daLink
# <html><body><p>--&gt;
# 							</p><div class="subMenuRightColumn"><div class="menu-section tours-sub"><a href="/intercity-milford-sound-tour/"><img/></a></div></div></body></html>
# print daLink
# <html><body><p>style="float:left;" src="/assets/intercity12/main/ICONSMENU/milford_icon.png" alt="Milford Sound Bus Tour" title=""/&gt;
# </p><div></div></body></html>
# print daLink
# <html><body><p>style="float:left;" class="menu-dets"&gt;<a href="/intercity-milford-sound-tour/">
# <h2>Milford Sound</h2>
# </a>
# </p><ul><a href="/inter"></a></ul></body></html>
# print daLink
# <html><body><p>city-milford-sound-tour/"&gt;
# </p><li><a href="/intercity-milford-sound-tour/"></a><a href="/intercity-milford-sound-tour/">Day trip </a></li></body></html>
# print daLink
# <html><body><p>from Queenstown from $119*
#
#
# </p><div class="menu-section tours-sub"><a href="/intercity-hobbiton-excursio"></a></div></body></html>
# print daLink
# <html><body><p>n-auckland-to-auckland/"&gt;<img alt="Hobbiton Movie " src="/assets/intercity12/main/ICONSMENU/hobbiton_icon.png" style="float:left"/></p></body></html>
# print daLink
# <html><body><p>Set Day Tour" title=""/&gt;
# </p><div class="menu-dets" style="float:left;"><a href="/intercity-hobbiton-excursion-auckland-to-auckl"></a></div></body></html>
# print daLink
# <html><body><p>and/"&gt;
# </p><h2>Hobbiton Movie Set</h2>
# <ul><a href="/intercity-hobbiton-excursion-auckland-to-auckland/"> </a>
# <li><a href="/i"></a></li></ul></body></html>
# print daLink
# <html><body><p>ntercity-hobbiton-excursion-auckland-to-auckland/"/&gt;<a href="/intercity-hobbiton-excursion-auckland-to-auckland/">Day trip from </a></p></body></html>
# print daLink
# <html><body><p>Auckland from $139*
#
#
# </p><div class="menu-section tours-sub dart"><a href="/dart-river-jet/"><img style=""/></a></div></body></html>
# print daLink
# <html><body><p>float:left;" src="/assets/intercity12/main/ICONSMENU/Dart-River_icon.png" alt="Dart River Jet Tour" title=""/&gt;
# </p><div style="f"></div></body></html>
# print daLink
# <html><body><p>loat:left;" class="menu-dets"&gt;<a href="/dart-river-jet/">
# <h2>Dart River Jet</h2>
# </a>
# </p><ul><a href="/dart-river-jet/"> </a>
# <li></li></ul></body></html>
# print daLink
# <html><body><p>&gt;<a href="/dart-river-jet/"></a><a href="/dart-river-jet/">Dart River Jet Tour Ex Q'tn from $219*</a>
# </p><div></div></body></html>
# print daLink
# <html><body><p>class="menu-section tours-sub boi"&gt;<a href="/tours/waitomo-caves-tour/"><img src="assets/intercity12/main/IC" style="float:left;"/></a></p></body></html>
# print daLink
# <html><body><p>ONSMENU/waitomo_icon.png" alt="Waitomo Caves Day Tour" title=""/&gt;
# </p><div class="menu-dets" style="float:left;"><a href="/tours"></a></div></body></html>
# print daLink
# <html><body><p>/waitomo-caves-tour/"&gt;
# </p><h2>Waitomo Caves Tour</h2>
# <ul><a href="/tours/waitomo-caves-tour/"> </a>
# <li><a href="/tours/wait"></a></li></ul></body></html>
# print daLink
# <html><body><p>omo-caves-tour/"/&gt;<a href="/tours/waitomo-caves-tour/">Day trips to Waitomo Caves From $139*</a>
# </p><div cl=""></div></body></html>
# print daLink
# <html><body><p>ass="menu-section tours-sub boi"&gt;<a href="/intercity-dolphin-cruise-tour/"><img src="/assets/intercity12/mai" style="float:left;"/></a></p></body></html>
# print daLink
# <html><body><p>n/ICONSMENU/boi_icon.png" alt="Bay of Islands Day Tour" title=""/&gt;
# </p><div class="menu-dets" style="float:left;"><a href="/inte"></a></div></body></html>
# print daLink
# <html><body><p>rcity-dolphin-cruise-tour/"&gt;
# </p><h2>Bay of Islands</h2>
# <ul><a href="/intercity-dolphin-cruise-tour/"> </a>
# <li><a href="/int"></a></li></ul></body></html>
# print daLink
# <html><body><p>ercity-dolphin-cruise-tour/"/&gt;<a href="/intercity-dolphin-cruise-tour/">Day trip from Auckland from $119*</a>
# </p></body></html>
# print daLink
# <html><body><p>/div&gt;
# </p><div class="menu-section tours-sub film_locations"><a href="/the-lord-of-the-rings-film-locations/"><img style="float:left"/></a></div></body></html>
# print daLink
# <html><body><p>;" src="/assets/intercity12/main/ICONSMENU/lotr_thumb.jpg" alt="Lord of the Rings Tour" title=""/&gt;
# </p><div style="float:left;"></div></body></html>
# print daLink
# <html><body><p>class="menu-dets"&gt;<a href="/the-lord-of-the-rings-film-locations/">
# <h2>LOTR Film Locations</h2>
# </a>
# </p><ul><a href="/the-lord-of"></a></ul></body></html>
# print daLink
# <html><body><p>-the-rings-film-locations/"&gt;
# </p><li><a href="/the-lord-of-the-rings-film-locations/"></a><a href="/the-lord-of-the-rings-film-loc"></a></li></body></html>
# print daLink
# <html><body><p>ations/"&gt;Discover the films' locations in NZ
#
#
# </p><div class="menu-section tours-sub therock"><a href="/t"></a></div></body></html>
# print daLink
# <html><body><p>herockpass/"&gt;<img alt="&gt;" src="/assets/intercity12/main/ICONSMENU/therock_thumb.jpg" style="float:left;" title=""/>
# </p><div></div></body></html>
# print daLink
# <html><body><p>style="float:left;" class="menu-dets"&gt;<a href="/therockpass/">
# <h2>The Rock Cruise</h2>
# </a>
# </p><ul><a href="/therockpass/"> </a>
# </ul></body></html>
# print daLink
# <html><body><li><a href="/therockpass/"></a><a href="/therockpass/">Overnight cruise from $288*</a></li>
# <div class="menu-se"></div></body></html>
# print daLink
# <html><body><p>ction tours-sub AucklandCityTour"&gt;<a href="/Auckland-Morning-City-tour/"><img src="/assets/intercity12/main/" style="float:left;"/></a></p></body></html>
# print daLink
# <html><body><p>auckland-city-sightseeing-tour-thumb.jpg" alt="Auckland City Sightseeing Tour" title=""/&gt;
# </p><div class="me" style="float:left;"></div></body></html>
# print daLink
# <html><body><p>nu-dets"&gt;<a href="/Auckland-Morning-City-tour/">
# <h2>Auckland City Tour</h2>
# </a>
# </p><ul><a href="/Auckland-Monring-City-tour/"> </a></ul></body></html>
# print daLink
# <html><body><p>/a&gt;
# </p><li><a href="/Auckland-Morning-City-tour/"></a><a href="/Auckland-Morning-City-tour/">Half day city tours from $39*</a></li>
# </body></html>
# print daLink
# <html><body><p>ul&gt;
#
# </p><div class="menu-section tours-sub huka"><a href="/hukafalls-jet/"><img src="/assets/interc" style="float:left;"/></a></div></body></html>
# print daLink
# <html><body><p>ity12/main/ICONSMENU/huka_icon.png" alt="Huka Jet Tour" title=""/&gt;
# </p><div class="menu-dets" style="float:left;"><a href="/huka"></a></div></body></html>
# print daLink
# <html><body><p>falls-jet/"&gt;
# </p><h2>Hukafalls Jet</h2>
# <ul><a href="/hukafalls-jet/"> </a>
# <li><a href="/hukafalls-jet/"></a><a href="/hukafalls"></a></li></ul></body></html>
# print daLink
# <html><body><p>-jet/"&gt;Daily from Taupo from $109*
#
#
# </p><div class="menu-section tours-sub tamaki"><a href="/tamaki-maori"></a></div></body></html>
# print daLink
# <html><body><p>-village-experience/"&gt;<img alt="Tamaki Maor" src="/assets/intercity12/main/ICONSMENU/rotorua_tamaki_icon.jpg" style="float:left;"/></p></body></html>
# print daLink
# <html><body><p>i Village" title=""/&gt;
# </p><div class="menu-dets" style="float:left;"><a href="/tamaki-maori-village-experience/">
# <h2>Tamaki MÄ</h2></a></div></body></html>
# print daLink
# <html><body><p>ori Village
#
# </p><ul><a href="/tamaki-maori-village-experience/"> </a>
# <li><a href="/tamaki-maori-village-experience/"></a><a></a></li></ul></body></html>
# print daLink
# <html><body><p>href="/tamaki-maori-village-experience/"&gt;Daily from Rotorua from $110*
#
#
#
#
# 	</p></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>"/#" class="flyout-toggle"&gt;<span></span>
# </p><ul class="flyout">
# </ul></body></html>
# print daLink
# <html><body><p>"&gt;
# 								</p><li>
# <a href="/passes/flexi-options/">Flexi Options</a>
# </li>
# </body></html>
# print daLink
#
#
# print daLink
# <html><body><p>Pass
#
#
#
#
#
# 								</p><div class="sub-menu-block">
# <li>
# </li></div></body></html>
# print daLink
# <html><body><a href="/passes/intercity-commuter/">InterCity Commuter</a>
# </body></html>
# print daLink
# <html><body><div class="sub-menu-block">
# <li>
# <a href="/passes/student-bus-pass/">Student Pass </a> </li></div></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>ub clearfix"&gt;<a href="/flexi-options/"><img alt="New Z" src="/assets/intercity12/main/ICONSMENU/flexible.jpg" style="float:left;"/></a></p></body></html>
# print daLink
# <html><body><p>ealand Bus Tours and Passes"/&gt;
# </p><div class="menu-dets" style="float:left;"><a href="/flexi-options/">
# <h2>Flexible Itinerary </h2></a></div></body></html>
# print daLink
# <html><body><p>Options
#
# </p><ul><a href="/flexi-options/"> </a>
# <li><a href="/flexi-options/"></a><a href="/flexi-options/">Our most popular </a></li></ul></body></html>
# print daLink
# <html><body><p>transport passes for independent travellers.  'Travel like a local' NZ's largest Hop-on/Hop-off network.  Total freedom + sights</p></body></html>
# print daLink
# <html><body><p>eeing &amp; activity options.
#
#
# </p><div class="menu-section pass-sub clearfix"><a href="/travel-pass/"><i></i></a></div></body></html>
# print daLink
# <html><body><p>mg style="float:left" src="/assets/intercity12/main/ICONSMENU/fixed.jpg" alt="New Zealand Bus Pass"/&gt;
# </p><div class="menu-dets"></div></body></html>
# print daLink
# <html><body><p>style="float:left;"&gt;<a href="/travel-pass/">
# <h2>Fixed Itinerary Passes</h2>
# </a>
# </p><ul><a href="/travel-pass/"> </a>
# <li><a href=""></a></li></ul></body></html>
# print daLink
# <html><body><p>="/travel-pass/"/&gt;<a href="/travel-pass/">Pre-planned transport passes for those wanting a set itinerary travel.  Choose from a </a></p></body></html>
# print daLink
# <html><body><p>range of passes including sightseeing tour options.
#
#
# </p><div class="menu-section pass-sub huka clearfix"></div></body></html>
# print daLink
# <html><body><p>&gt;<a href="/intercity-commuter/"><img alt="Auckland to " src="/assets/intercity12/main/ICONSMENU/commuter.jpg" style="float:left;"/></a></p></body></html>
# print daLink
# <html><body><p>Hamilton Bus Pass New Zealand"/&gt;
# </p><div class="menu-dets" style="float:left;">
# <h2>InterCity Commuter</h2>
# <ul><li><a href="/i"></a></li></ul></div></body></html>
# print daLink
# <html><body><p>ntercity-commuter/"&gt;Save up to 38%* on regular fares between Hamilton/Auckland.  Over 20 services per day between cities on NZ's</p></body></html>
# print daLink
# <html><body><p>#1 Bus Network.
#
#
# </p><div class="menu-section pass-sub boi"><a href="/student-bus-pass/"><img style="flo"/></a></div></body></html>
# print daLink
# <html><body><p>at:left;" src="/assets/intercity12/main/ICONSMENU/student-pass.jpg" alt="Student Bus Pass New Zealand"/&gt;
# </p><div class="menu-de"></div></body></html>
# print daLink
# <html><body><p>ts" style="float:left;"&gt;<a href="/student-bus-pass/">
# <h2>Student Passes</h2>
# </a>
# </p><ul><a href="/student-bus-pass/"> </a>
# <li><a></a></li></ul></body></html>
# print daLink
# <html><body><p>href="/student-bus-pass/"/&gt;<a href="/student-bus-pass/">Great savings for students! <br/> Passes available for Hawke's Bay, New</a></p></body></html>
# print daLink
# <html><body><p>Plymouth and Dunedin students.
#
#
#
#
#
#
# 			</p><li class="has-flyout"></li></body></html>
# print daLink
# <html><body><a class="link" href="http://www.booking.com/index.html?aid=369493">Accommodation</a>
# <a class="fl" href="/#"></a></body></html>
# print daLink
# <html><body><p>yout-toggle"&gt;<span></span>
# <!-- HIDING SEARCH BAR FOR PRESENT TIME -->
# </p></body></html>
# print daLink
# <html><body><p>r"&gt;
# 			 </p><form action="#" method="Get">
# <input name="enter-search" type="textarea"/>
# <input type="submit" value=""/>
# </form></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>ame=enter-search&gt;
# 			<input type="Submit" value=""/>
#
# 	--&gt;
#
#
#
#
#
#
#
# 					<d></d></p></body></html>
# print daLink
# <html><body><p>iv id="ResCartSummary" class="row"&gt;
# 						</p><div class="typography ">
# <div class="row" id="Container">
# <div class="twenty co"></div></div></div></body></html>
# print daLink
# <html><body><p>lumns"&gt;
#
# </p><div class="NoCart"></div>
# <div class="s" id="Layout"></div></body></html>
# print daLink
# <html><body><p>idebar row"&gt;
#        					 </p><div class="six columns" id="Sidebar">
# <p style="display: none;">home</p>
# <div id="accordion">
# </div></div></body></html>
# print daLink
# <html><body><h2>Search Timetables &amp; Fares</h2>
# <div class="SearchForm">
# <p class="sidebar-blurb">Type in your origin &amp; destination b</p></div></body></html>
# print daLink
# <html><body><p>elow<br/>OR select from the drop down.</p>
# <form action="/search-results/Form" en="" id="SectorSearchForm_Form" method="post"></form></body></html>
# print daLink
# <html><body><p>ctype="application/x-www-form-urlencoded" class="sectorsearchform narrow"&gt;
#
#
# 	</p><p class="messag" id="SectorSearchForm_Form_error"></p></body></html>
# print daLink
# <html><body><p>e " style="display: none"&gt;</p>
# <fieldset>
# <div class="field h5option" data-role="fieldcontain" id="OneWayOrReturn"></div></fieldset></body></html>
# print daLink
# <html><body><p>set  isReturnTrip nolabel"&gt;</p><div class="middleColumn"><ul class="optionset isReturnTri" id="SectorSearchForm_Form_OneWayOrReturn"></ul></div></body></html>
# print daLink
# <html><body><p>p nolabel" data-role="controlgroup" data-type="horizontal"&gt;</p><li class="radio odd valOneWay"><input class="radio" id="SectorSearch"/></li></body></html>
# print daLink
# <html><body><p>Form_Form_OneWayOrReturn_OneWay" name="OneWayOrReturn" type="radio" value="OneWay" checked="checked" /&gt;<label for="SectorSearchF"></label></p></body></html>
# print daLink
# <html><body><p>orm_Form_OneWayOrReturn_OneWay"&gt;One-Way</p><li class="radio even valReturn"><input class="radio" id="SectorSearchForm_F"/></li></body></html>
# print daLink
# <html><body><p>orm_OneWayOrReturn_Return" name="OneWayOrReturn" type="radio" value="Return" /&gt;<label for="SectorSearchForm_Form_OneWayOrReturn_"></label></p></body></html>
# print daLink
# <html><body><p>Return"&gt;Return
#
# 			</p><div class="field fieldgroup FromStop stopPicker nolabel" id="FromfromPicker"></div></body></html>
# print daLink
# <html><body><p>"&gt;</p><div class="middleColumn"><div class="fieldgroup"><div class="fieldgroupField"><div class="From leftlabel"><label class="leftl"></label></div></div></div></div></body></html>
# print daLink
# <html><body><p>abel" for="SectorSearchForm_Form_From"&gt;From<input class="text StopName" id="SectorSearchForm_Form_From" name="" type="text"/></p></body></html>
# print daLink
# <html><body><p>="From" value="" autocomplete="on" required="required" placeholder="From" /&gt;</p><div class="fieldgroupField"><a href="#"></a></div></body></html>
# print daLink
# <html><body><p>class='stoppicker' data-stopfield-id='SectorSearchForm_Form_From' data-title='Travelling from' title='Choose a stop to travel f</p></body></html>
# print daLink
# <html><body><p>rom...' &gt;V
#
# 			</p><div class="field fieldgroup ToStop stopPicker nolabel" id="TotoPicker"><div class=""></div></div></body></html>
# print daLink
# <html><body><p>="middleColumn"&gt;</p><div class="fieldgroup"><div class="fieldgroupField"><div class="To leftlabel"><label class="leftlabel" for="Sec"></label></div></div></div></body></html>
# print daLink
# <html><body><p>torSearchForm_Form_To"&gt;To<input autoc="" class="text StopName" id="SectorSearchForm_Form_To" name="To" type="text" value=""/></p></body></html>
# print daLink
# <html><body><p>omplete="on" required="required" placeholder="To" /&gt;</p><div class="fieldgroupField"><a class="stoppicker" data="" href="#"></a></div></body></html>
# print daLink
# <html><body><p>-stopfield-id='SectorSearchForm_Form_To' data-title='Travelling to' title='Choose a stop to travel to...' &gt;V</p></body></html>
# print daLink
# <html><body><p>v&gt;
#
# 			</p><div class="field h5input datePicker" id="Date_Travel"><label class="left" for="SectorSearchForm_Form_Date_Trave"></label></div></body></html>
# print daLink
# <html><body><p>l"&gt;Departure Date</p><div class="middleColumn"><input class="date text" id="SectorSearchForm_Form_Date_Travel" n="" type="date"/></div></body></html>
# print daLink
# <html><body><p>ame="Date_Travel" value="2013-12-06" autocomplete="off" min="2013-12-05" juiConfig="{"buttonImage":"\/assets\/res</p></body></html>
# print daLink
# <html><body><p>ervations\/button_calender.png","buttonImageOnly":"true","dateFormat":"dd\/mm\/yy",</p></body></html>
# print daLink
# <html><body><p>"locale":"en-GB","minDate":"+0d","showOn":"both"}" /&gt;
# 		</p></body></html>
# print daLink
# <html><body><div class="field h5input datePicker" id="Date_Return"><label class="left" for="SectorSearchForm_Form_Date_Return">Return D</label></div></body></html>
# print daLink
# <html><body><p>ate</p><div class="middleColumn"><input class="date text" id="SectorSearchForm_Form_Date_Return" name="Date_Retu" type="date"/></div></body></html>
# print daLink
# <html><body><p>rn" value="2013-12-12" autocomplete="off" juiConfig="{"buttonImage":"\/assets\/reservations\/button_calender.png</p></body></html>
# print daLink
# <html><body><p>quot;,"buttonImageOnly":"true","dateFormat":"dd\/mm\/yy","locale":"en-GB</p></body></html>
# print daLink
# <html><body><p>quot;,"minDate":"+0d","showOn":"both"}" /&gt;
#
#
#
# 			</p><div class="PaxComp"></div></body></html>
# print daLink
# <html><body><p>&gt;
#
# 			</p><h3 id="SectorSearchForm_Form_Pax">Passengers</h3>
# <div class="field fieldgroup nolabel" id="ADCHGA"><div class=""></div></div></body></html>
# print daLink
# <html><body><p>middleColumn"&gt;</p><div class="fieldgroup"><div class="fieldgroupField"><label for="SectorSearchForm_Form_AD">Adult</label>
# <select c=""></select></div></div></body></html>
# print daLink
# <html><body><p>lass=" disctype" id="SectorSearchForm_Form_AD" name="AD"&gt;<option value="">0</option><option value="1AD">1</option><option value=""></option></p></body></html>
# print daLink
# <html><body><p>"2AD"&gt;2<option value="3AD">3</option><option value="4AD">4</option><option value="5AD">5</option><option value="6AD">6</option></p></body></html>
# print daLink
# <html><body><p>/option&gt;<option value="7AD">7</option><option value="8AD">8</option><option value="9AD">9</option><option value="10AD">10</option></p></body></html>
# print daLink
# <html><body><p>n&gt;</p><div class="fieldgroupField"><label for="SectorSearchForm_Form_CH">Child (3-12 yrs)</label>
# <select class=" dis"></select></div></body></html>
# print daLink
# <html><body><p>ctype" id="SectorSearchForm_Form_CH" name="CH"&gt;<option value="">0</option><option value="1CH">1</option><option value="2CH">2</option></p></body></html>
# print daLink
# <html><body><p>ption&gt;<option value="3CH">3</option><option value="4CH">4</option><option value="5CH">5</option><option value="6CH">6</option><o></o></p></body></html>
# print daLink
# <html><body><p>ption value="7CH"&gt;7<option value="8CH">8</option><option value="9CH">9</option><option value="10CH">10</option></p></body></html>
# print daLink
# <html><body><p>&gt;</p><div class="fieldgroupField"><label for="SectorSearchForm_Form_GA">Golden Age (60+)</label>
# <select class=" disctype" id=""></select></div></body></html>
# print daLink
# <html><body><p>"SectorSearchForm_Form_GA" name="GA"&gt;<option value="">0</option><option value="1GA">1</option><option value="2GA">2</option><opt></opt></p></body></html>
# print daLink
# <html><body><p>ion value="3GA"&gt;3<option value="4GA">4</option><option value="5GA">5</option><option value="6GA">6</option><option valu=""></option></p></body></html>
# print daLink
# <html><body><p>e="7GA"&gt;7<option value="8GA">8</option><option value="9GA">9</option><option value="10GA">10</option></p></body></html>
# print daLink
# <html><body><p>iv&gt;
#
# 			</p><p class="ShowDiscTypes">Other fare types </p>
# <div class="field fieldgroup extraPaxTyp" id="STBPIN"></div></body></html>
# print daLink
# <html><body><p>es nolabel"&gt;</p><div class="middleColumn"><div class="fieldgroup"><div class="fieldgroupField"><label for="SectorSearchForm_Form_ST"></label></div></div></div></body></html>
# print daLink
# <html><body><p>&gt;Student (13+)
# <select class=" disctype" id="SectorSearchForm_Form_ST" name="ST"><option value="">0</option><option valu=""></option></select></p></body></html>
# print daLink
# <html><body><p>e="1ST"&gt;1<option value="2ST">2</option><option value="3ST">3</option><option value="4ST">4</option><option value="5ST"></option></p></body></html>
# print daLink
# <html><body><p>5<option value="6ST">6</option><option value="7ST">7</option><option value="8ST">8</option><option value="9ST">9</option></p></body></html>
# print daLink
# <html><body><p>n&gt;<option value="10ST">10</option></p><div class="fieldgroupField"><label for="SectorSearchForm_Form_BP">Backpacker (</label></div></body></html>
# print daLink
# <html><body><p>Valid ID)
# <select class=" disctype" id="SectorSearchForm_Form_BP" name="BP"><option value="">0</option><option value="1B"></option></select></p></body></html>
# print daLink
# <html><body><p>P"&gt;1<option value="2BP">2</option><option value="3BP">3</option><option value="4BP">4</option><option value="5BP">5</option></p></body></html>
# print daLink
# <html><body><p>tion&gt;<option value="6BP">6</option><option value="7BP">7</option><option value="8BP">8</option><option value="9BP">9</option><op></op></p></body></html>
# print daLink
# <html><body><p>tion value="10BP"&gt;10</p><div class="fieldgroupField"><label for="SectorSearchForm_Form_IN">Infant (0-2 yrs n</label></div></body></html>
# print daLink
# <html><body><p>o seat)
# <select class=" disctype" id="SectorSearchForm_Form_IN" name="IN"><option value="">0</option><option value="1IN"></option></select></p></body></html>
# print daLink
# <html><body><p>&gt;1<option value="2IN">2</option><option value="3IN">3</option><option value="4IN">4</option><option value="5IN">5</option></p></body></html>
# print daLink
# <html><body><p>on&gt;<option value="6IN">6</option><option value="7IN">7</option><option value="8IN">8</option><option value="9IN">9</option><opti></opti></p></body></html>
# print daLink
# <html><body><p>on value="10IN"&gt;10
#
#
#
# 			</p><div class="field formaction " id="action_search"></div></body></html>
# print daLink
# <html><body><p>"&gt;<label class="left" for="SectorSearchForm_Form_action_search">Search</label></p><div class="middleColumn"><input class="action "/></div></body></html>
# print daLink
# <html><body><p>id="SectorSearchForm_Form_action_search" type="submit" name="action_search" value="Search" title="Search" /&gt;
#
# 			</p></body></html>
# print daLink
# <html><body><p>div id="stoppickerdialog"&gt;
# 	</p><ul>
# <li><a href="#stoppickerdialog-main">Main Stops</a></li>
# <li><a href="#stoppickerdialog-ni"></a></li></ul></body></html>
# print daLink
# <html><body><p>&gt;North Island All Stops
# 		</p><li><a href="#stoppickerdialog-si">South Island All Stops</a></li>
# <div id="stoppicke"></div></body></html>
# print daLink
# <html><body><p>rdialog-main"&gt;
#
# 		</p><div class="stoppickerdialog-col leftcol">
# <h3 title="Most Popular stops in the North Island">North Island </h3></div></body></html>
# print daLink
# <html><body><p>h3&gt;
# <a data-stop-code="PIH" title="Maritime Building, Adjacent Wharf">Paihia</a>
# <a data-stop-code="AKL" title="Sky City Coach"></a></p></body></html>
# print daLink
# <html><body><p>Terminal, 102 Hobson Street"&gt;Auckland
# <a data-stop-code="AIR" title="Bus Stop 2008 International Terminal, Ray Emery Drive"></a></p></body></html>
# print daLink
# <html><body><p>."&gt;Auckland International Airport
# <a data-stop-code="MNK" title="Leyton Way near foodcourt">Manukau City</a>
# <a data-stop-c=""></a></p></body></html>
# print daLink
# <html><body><p>ode="HLZ"  title="Hamilton Transport Centre, Cnr Bryce &amp; Anglesea, Platforms A - D."&gt;Hamilton
# <a data-stop-code="ROT" t=""></a></p></body></html>
# print daLink
# <html><body><p>itle="Tourism Rotorua, 1167 Fenton Street"&gt;Rotorua
# <a data-stop-code="TUO" title="Taupo Travel Centre, 16 Gascoigne Street"></a></p></body></html>
# print daLink
# <html><body><p>&gt;Taupo
# <a data-stop-code="GIS" title="Outside Gisborne I-Site, 209 Grey Street">Gisborne</a>
# <a data-stop-code="NPE" title=""></a></p></body></html>
# print daLink
# <html><body><p>="135 Dalton St (Nearest Intersection - Station Street)"&gt;Napier
# <a data-stop-code="NPL" title="19 Ariki Street, New Plymout"></a></p></body></html>
# print daLink
# <html><body><p>h"&gt;New Plymouth
# <a data-stop-code="PMR" title="Travel Centre Corner Pitt &amp; Main Streets">Palmerston Nth</a>
# <a data-sto=""></a></p></body></html>
# print daLink
# <html><body><p>p-code="WLG"  title="Railway Station, Platform 9"&gt;Wellington
#
#
# </p><div class="stoppickerdialog-col rightcol">
# <h3 title=""></h3></div></body></html>
# print daLink
# <html><body><p>"Most Popular stops in the South Island"&gt;South Island
# <a data-stop-code="PCN" title="Outside Main Entrance of Interisland"></a></p></body></html>
# print daLink
# <html><body><p>er Ferry Terminal"&gt;Picton
# <a data-stop-code="NSN" title="Outside Travel Centre, 27 Bridge Street">Nelson</a>
# <a data-stop-c=""></a></p></body></html>
# print daLink
# <html><body><p>ode="GRM"  title="Greymouth Railway Station, 164 MacKay St"&gt;Greymouth
# <a data-stop-code="CHC" title="118 Bealey Ave (betwee"></a></p></body></html>
# print daLink
# <html><body><p>n Colombo St and Durham St intersections)"&gt;Christchurch
# <a data-stop-code="DUD" title="Ritchies/InterCity Travel, 7 Halsey "></a></p></body></html>
# print daLink
# <html><body><p>Street, near the corner of Sturdee Street"&gt;Dunedin
# <a data-stop-code="ZQN" title="Athol Street in the middle of the car par"></a></p></body></html>
# print daLink
# <html><body><p>k"&gt;Queenstown
# <a data-stop-code="WHO" title="Franz Josef Bus Stop, Main Road">Franz Josef</a>
# <a data-stop-code="MFN" titl=""></a></p></body></html>
# print daLink
# <html><body><p>e="Front Entrance of Visitors Centre, Milford Wharf"&gt;Milford Sound
# <a data-stop-code="IVC" title="Invercargill Information "></a></p></body></html>
# print daLink
# <html><body><p>Centre Car Park, 108 Gala Street"&gt;Invercargill
#
#
#
#
#
#
# 	</p><div id="stoppickerdialog-ni">
# <div class="stoppick"></div></div></body></html>
# print daLink
# <html><body><p>erdialog-letter"&gt;
# 				</p><h3>A</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="ABF" href="#">Abe</a></div></body></html>
# print daLink
# <html><body><p>rfeldy
#
# 						<a data-stop-code="AHT" href="#">Ahititi Turn Off</a>
# <a data-stop-code="AKO" href="#">Akoran</a></p></body></html>
# print daLink
# <html><body><p>ga (Auckland)
#
# 						<a data-stop-code="ALY" href="#">Albany (Auckland)</a>
# <a data-stop-code="ACL" href="#"></a></p></body></html>
# print daLink
# <html><body><p>"&gt;Anchor Lodge Backpackers (Coromandel)
#
# 						<a data-stop-code="ASH" href="#">Ashhurst</a>
# <a da="" href="#"></a></p></body></html>
# print daLink
# <html><body><p>ta-stop-code="ATI"&gt;Atiamuri
#
# 						<a data-stop-code="AKL" href="#">Auckland - Central</a>
# </p></body></html>
# print daLink
#
#
# print daLink
# <html><body><a href="#"></a></body></html>
# print daLink
# <html><body><p>data-stop-code="ADA"&gt;Auckland Domestic Airport
#
# 						<a data-stop-code="AIR" href="#">Auckland International Airport</a></p></body></html>
# print daLink
# <html><body><p>a&gt;
#
# 						<a data-stop-code="AVC" href="#">Auckland Vector Arena</a>
# <a data-stop-code="AWH" href="#">Awahuri</a></p></body></html>
# print daLink
# <html><body><p>a&gt;
#
# 						<a data-stop-code="AWK" href="#">Awakeri</a>
# <a data-stop-code="AKN" href="#">Awakino</a>
# </p></body></html>
# print daLink
# <html><body><a data-stop-code="AAI" href="#">Awanui</a>
# <div class="stoppickerdialog-letter">
# <h3>B</h3></div></body></html>
# print daLink
# <html><body><p>3&gt;
# 				</p><div class="stoppickerdialog-col leftcol">
# <a data-stop-code="MMB" href="#">Bayfair</a>
# <a href=""></a></div></body></html>
# print daLink
# <html><body><p>#' data-stop-code="BVW"&gt;Bayview
#
# 						<a data-stop-code="BBK" href="#">Bell Block</a>
# <a data-sto="" href="#"></a></p></body></html>
# print daLink
# <html><body><p>p-code="BOX"&gt;Bombay (Auckland)
#
#
#
#
#
#
#
#
# 				</p><div class="stoppickerdialog-col "></div></body></html>
# print daLink
# <html><body><p>rightcol"&gt;
#
#
#
#
#
#
#
#
#
# 						<a data-stop-code="BRY" href="#">Brynderwyn</a>
# </p></body></html>
# print daLink
# <html><body><a data-stop-code="BLS" href="#">Bulls</a>
# <a data-stop-code="GBW" href="#">BW Campground (for Rhythm and Vin</a></body></html>
# print daLink
# <html><body><p>es Festival - Gisborne)
#
#
#
#
# 			</p><div class="stoppickerdialog-letter">
# <h3>C</h3>
# <div class=""></div></div></body></html>
# print daLink
# <html><body><p>="stoppickerdialog-col leftcol"&gt;
#
# 						<a data-stop-code="CAB" href="#">Cable Bay</a>
# <a data-stop-co="" href="#"></a></p></body></html>
# print daLink
# <html><body><p>de="CBC"&gt;Cambridge
#
# 						<a data-stop-code="WPJ" href="#">Cats Pajamas Backpackers (Whitianga)</a>
# <a href=""></a></p></body></html>
# print daLink
# <html><body><p>='#' data-stop-code="CLV"&gt;Clive
#
# 						<a data-stop-code="COP" href="#">Coopers Beach</a>
# </p></body></html>
# print daLink
#
#
# print daLink
# <html><body><a data-stop-code="COG" href="#">Coroglen</a>
# <a data-stop-code="CML" href="#"></a></body></html>
# print daLink
# <html><body><p>Coromandel
#
# 						<a data-stop-code="CMP" href="#">Coromandel Kapanga Road</a>
# <a data-stop-code="" href="#"></a></p></body></html>
# print daLink
# <html><body><p>CTB"&gt;Coromandel Town Backpackers (Coromandel)
#
#
#
#
# 			</p><div class="stoppickerdialog-letter">
# <h3></h3></div></body></html>
# print daLink
# <html><body><p>&gt;D
# 				</p><div class="stoppickerdialog-col leftcol">
# <a data-stop-code="DVK" href="#">Dannevirke</a>
# </div></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>(Tokoroa)
#
#
#
#
# 			</p><div class="stoppickerdialog-letter">
# <h3>E</h3>
# <div class="stoppickerd"></div></div></body></html>
# print daLink
# <html><body><p>ialog-col leftcol"&gt;
#
# 						<a data-stop-code="EDG" href="#">Edgecumbe</a>
# <a data-stop-code="EGV" href="#">Egmo</a></p></body></html>
# print daLink
# <html><body><p>nt Village
#
# 						<a data-stop-code="EMJ" href="#">Eight Mile Junction</a>
# </p></body></html>
# print daLink
#
#
# print daLink
# <html><body><p>stop-code="EKT"&gt;Eketahuna
#
# 						<a data-stop-code="ELT" href="#">Eltham</a>
# <a data-stop-code="ES" href="#"></a></p></body></html>
# print daLink
# <html><body><p>K"&gt;Eskdale
#
#
#
#
# 			</p><div class="stoppickerdialog-letter">
# <h3>F</h3>
# <div class="stoppickerd"></div></div></body></html>
# print daLink
# <html><body><p>ialog-col leftcol"&gt;
#
# 						<a data-stop-code="FNR" href="#">Featherston</a>
# <a data-stop-code="FLG" href="#">Fe</a></p></body></html>
# print daLink
# <html><body><p>ilding
#
# 						<a data-stop-code="FTZ" href="#">Fitzroy</a>
# </p><div class="s"></div></body></html>
# print daLink
# <html><body><p>toppickerdialog-col rightcol"&gt;
#
#
#
#
#
#
#
# 						<a data-stop-code="FLT" href="#">Flat Hills Te</a></p></body></html>
# print daLink
# <html><body><p>a Rooms
#
# 						<a data-stop-code="FXN" href="#">Foxton</a>
# </p><div class="stoppickerdialo"></div></body></html>
# print daLink
# <html><body><p>g-letter"&gt;
# 				</p><h3>G</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="GCF" href="#">Gateway Ca</a></div></body></html>
# print daLink
# <html><body><p>fe (Kaiwaka)
#
# 						<a data-stop-code="GIS" href="#">Gisborne</a>
# <a data-stop-code="ARP" href="#">Glenview</a></p></body></html>
# print daLink
# <html><body><p>Farm Hostel (Tangoio)
#
# 						<a data-stop-code="GSP" href="#">Golden Springs</a>
# </p></body></html>
# print daLink
#
#
# print daLink
# <html><body><a data-stop-code="GTN" href="#">Greerton</a>
# <a data-stop-code="GRT" href="#">Greytown</a>
# <a href=""></a></body></html>
# print daLink
# <html><body><p>#' data-stop-code="GUM"&gt;Gumboot Manor Restaurant Taihape
#
#
#
#
# 			</p><div class="stoppickerdialog-lette"></div></body></html>
# print daLink
# <html><body><p>r"&gt;
# 				</p><h3>H</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="HLZ" href="#">Hamilton - Centra</a></div></body></html>
# print daLink
# <html><body><p>l
#
# 						<a data-stop-code="HGT" href="#">Hangatiki</a>
# <a data-stop-code="CHW" href="#">Hannafords Wharf (</a></p></body></html>
# print daLink
# <html><body><p>Coromandel)
#
# 						<a data-stop-code="HST" href="#">Hastings</a>
# <a data-stop-code="HWA" href="#">Hawera</a></p></body></html>
# print daLink
# <html><body><p>&gt;
#
# 						<a data-stop-code="HKI" href="#">Hikuai</a>
# </p></body></html>
# print daLink
#
#
# print daLink
# <html><body><a data-stop-code="HKR" href="#">Hikurangi</a>
# <a data-stop-code="HLC" href="#">H</a></body></html>
# print daLink
# <html><body><p>illcrest (Hamilton)
#
# 						<a data-stop-code="HMT" href="#">Himatangi</a>
# ...
# print daLink
# <html><body><p>MemberLoginForm" method="post" enctype="application/x-www-form-urlencoded" class="LoginClub"&gt;
#
#
# 	</p><p id="ICGLoginClubForm_ClubMe"></p></body></html>
# print daLink
# <html><body><p>mberLoginForm_error" class="message " style="display: none"&gt;</p>
# <fieldset>
# <div class="field CompositeField nol"></div></fieldset></body></html>
# print daLink
# <html><body><p>abel"&gt;
#
# </p><div class="field h5input " id="ClubMemberCode"><label class="left" for="ICGLoginClubForm_ClubMemberLoginForm_ClubMember"></label></div></body></html>
# print daLink
# <html><body><p>Code"&gt;Freeway Number</p><div class="middleColumn"><input class="text CmbCode" id="ICGLoginClubForm_ClubMemberLog" type="text"/></div></body></html>
# print daLink
# <html><body><p>inForm_ClubMemberCode" name="ClubMemberCode" value="" autocomplete="off" placeholder="Freeway Number" title="Freeway Number" /&gt;</p></body></html>
# print daLink
# <html><body><p>/div&gt;
#
# </p><div class="field h5input " id="Password"><label class="left" for="ICGLoginClubForm_ClubMemberLoginForm_Password">P</label></div></body></html>
# print daLink
# <html><body><p>assword</p><div class="middleColumn"><input class="text Password" id="ICGLoginClubForm_ClubMemberLoginForm_P" type="password"/></div></body></html>
# print daLink
# <html><body><p>assword" name="Password" value="" autocomplete="off" placeholder="Password" title="Password" /&gt;
#
#
#
# 		</p><div cl=""></div></body></html>
# print daLink
# <html><body><p>ass="clear"&gt;<!-- -->
# </p><div class="Actions">
# <input class="action Login" id="ICGLoginClubForm_ClubMem"/></div></body></html>
# print daLink
# <html><body><p>berLoginForm_action_loginClub" type="submit" name="action_loginClub" value="Login" title="Login" /&gt;
#
#
#
#
#
#
#
# 		</p></body></html>
# print daLink
# <html><body><p>/div&gt;
#
#
#
# 		</p><div id="Hitwise" style="text-align: center;">
# </div>
# <div class="fourteen columns "></div></body></html>
# print daLink
# <html><body><p>last"&gt;
#
#
# 						</p><div id="HomePage">
# <div class="new-slideshow" id="slideshow">
# <ul class="slideshow-nav"> </ul></div></div></body></html>
# print daLink
# <html><body><li data-id="969">1</li><li data-id="973">2</li><li data-id="743">3</li>
# <div class="slideshow-slides">
# </div></body></html>
# print daLink
# <html><body><div class="slideshow-slide first" data-id="969">
# <img src="/assets/intercity12/slideshow/dollarfares-slider.jpg" width=""/></div></body></html>
# print daLink
# <html><body><p>"700" height="288" alt="" class="first image" /&gt;
# 					<a href="#" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out Mor"></a></p></body></html>
# print daLink
# <html><body><p>e', 'Slide - $1fare']);"&gt;
# </p><div class="slideshow-text">
# <h1>$1* fares with InterCity</h1>
# <p>Everyone loves a bargain!  <br/><br/></p></div></body></html>
# print daLink
# <html><body><p>&gt;And we've got at least one $1* fare available on each and every InterCity速 bus service. <br/><br/>*+ Booking Fee.</p>
# </body></html>
# print daLink
# <html><body><p>v class="grey-btn"&gt;Find tours now --&gt;
#
#
#
#
# 				</p><div class="slideshow-slide " data-id="973">
# </div></body></html>
# print daLink
# <html><body><img alt="" class=" image" height="288" src="/assets/intercity12/slideshow/passes-slider.jpg" width="700"/>
# <a href="/pa"></a></body></html>
# print daLink
# <html><body><p>sses/flexi-options" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - flexiOptions']);"&gt;
# </p><div class="sli"></div></body></html>
# print daLink
# <html><body><p>deshow-text"&gt;
# </p><h1>NZ's National Bus Passes</h1>
# <p>See more of New Zealand! Travel on NZ's largest national network with one of </p></body></html>
# print daLink
# <html><body><p>our flexible bus pass options.</p>
# <div class="grey-btn">Search Passes Now</div>
# <div class="s"></div></body></html>
# print daLink
# <html><body><p>lideshow-slide " data-id="743"&gt;
# 					<img height="" src="/assets/intercity12/Promo-Pages/ic_interislander_slider.jpg" width="700"/></p></body></html>
# print daLink
# <html><body><p>"288" alt="Ferry combo passes" class="last image" /&gt;
# 					<a href="/bus-and-ferry-combos/" onclick="_gaq.push(['_trackEvent', '"></a></p></body></html>
# print daLink
# <html><body><p>HP Slider', 'Find Out More', 'Slide - ferrycombos']);"&gt;
# </p><div class="slideshow-text">
# <h1>Buy bus and ferry combos from <span cla=""></span></h1></div></body></html>
# print daLink
# <html><body><p>ss="price-highlight"&gt;$95*
# </p><p>Combine InterCity bus trips and Interislander passenger ferry trips on our new combo pa</p></body></html>
# print daLink
# <html><body><p>sses</p>
# <div class="grey-btn">Find Out More</div>
# <div class="twenty "></div></body></html>
# print daLink
# <html><body><p>columns"&gt;
#
# 	</p><div class="row">
# <div class=" promo ten columns ">
# <div class="content-box ">
# <p class=""></p></div></div></div></body></html>
# print daLink
# <html><body><p>"content-box-tagline"&gt;<a href="/tours/" style="text-decoration:none"><span class="content-box-highlight-red"></span> Discounted </a></p></body></html>
# print daLink
# <html><body><p>tours from $105</p>
# <div class="content-box-thumbnail"><img src="/assets/intercity12/Promo-Pages/ic_hukajet_thumb.jp"/></div></body></html>
# print daLink
# <html><body><p>g" alt="ic_hukajet_thumb.jpg" /&gt;
# 					</p><p class="content-box-description">Great value tours to Huka Falls, Milford Sound, </p></body></html>
# print daLink
# <html><body><p>Hobbiton and more. Seats sell fast!</p>
# <div class="content-box-textlink"><a href="/tours/" onclick="_gaq.push(['_trackE"></a></div></body></html>
# print daLink
# <html><body><p>vent', 'HP Promo', 'Find Out More', 'Discounted tours from $105']);"&gt;Search New Zealand Tours
#
#
# </p></body></html>
# print daLink
# <html><body><div class=" promo ten columns content-box-right">
# <div class="content-box content-box-right">
# <p class="cont"></p></div></div></body></html>
# print daLink
# <html><body><p>ent-box-tagline"&gt;<a href="http://www.booking.com/index.html?aid=369493" style="text-decoration:none"><span class="content-box-hi"></span></a></p></body></html>
# print daLink
# <html><body><p>ghlight-red"&gt; Need Accommodation?</p>
# <div class="content-box-thumbnail"><img src="/assets/intercity12/main/b"/></div></body></html>
# print daLink
# <html><body><p>us-and-beds.jpg" alt="New Zealand Accommodation" /&gt;
# 					</p><p class="content-box-description">Search &amp; book NZâs bigg</p></body></html>
# print daLink
# <html><body><p>est range of accommodation with Best Rates Guaranteed.</p>
# <div class="content-box-textlink"><a href="http://www.booking"></a></div></body></html>
# print daLink
# <html><body><p>.com/index.html?aid=369493" onClick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Need Accommodation?']);"&gt;Search acc</p></body></html>
# print daLink
# <html><body><p>ommodation now
#
#
#
# 			</p><div class=" promo ten columns ">
# <div class="content-box ">
# </div></div></body></html>
# print daLink
# <html><body><p class="content-box-tagline"><a href="travel-info/timetable/" style="text-decoration:none"><span class="content-box-highlight"></span></a></p></body></html>
# print daLink
# <html><body><p>-red"&gt; Find a bus stop</p>
# <div class="content-box-thumbnail"><img src="/assets/intercity12/Promo-Pages/ic_bu"/></div></body></html>
# print daLink
# <html><body><p>ssstopsign98.jpg" alt="ic_bussstopsign98.jpg" /&gt;
# 					</p><p class="content-box-description">Find bus stop locations around N</p></body></html>
# print daLink
# <html><body><p>ew Zealand and see timetable information.</p>
# <div class="content-box-textlink"><a href="travel-info/timetable/" onclick=""></a></div></body></html>
# print daLink
# <html><body><p>="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Find a bus stop']);"&gt;Get more info
#
#
# 	</p></body></html>
# print daLink
# <html><body><div class=" promo ten columns content-box-right">
# <div class="content-box content-box-right">
# <p class="conte"></p></div></div></body></html>
# print daLink
# <html><body><p>nt-box-tagline"&gt;<a href="/bus-to-auckland-airport" style="text-decoration:none"><span class="content-box-highlight-red"></span> </a></p></body></html>
# print daLink
# <html><body><p>Auckland Airport Connections</p>
# <div class="content-box-thumbnail"><img src="/assets/intercity12/main/ic_airport_bu"/></div></body></html>
# print daLink
# <html><body><p>s.jpg" alt="ic_airport_bus.jpg" /&gt;
# 					</p><p class="content-box-description">View connections to and from the airport from </p></body></html>
# print daLink
# <html><body><p>locations across the North Island.</p>
# <div class="content-box-textlink"><a href="/bus-to-auckland-airport" onclick="_ga"></a></div></body></html>
# print daLink
# <html><body><p>q.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Auckland Airport Connections']);"&gt;View Airport Connections
# 				</p></body></html>
# print daLink
# <html><body><p>/div&gt;
#
#
# 			</p><div class=" promo ten columns ">
# <div class="content-box ">
# <p class="content-box-tagline"></p></div></div></body></html>
# print daLink
# <html><body><p>&gt;<a href="http://www.milford-sound.co.nz/" style="text-decoration:none"><span class="content-box-highlight-red"></span> Featured</a></p></body></html>
# print daLink
# <html><body><p>Destination - Milford Sound</p>
# <div class="content-box-thumbnail"><img src="/assets/intercity12/main/milford-sound"/></div></body></html>
# print daLink
# <html><body><p>-promo-tile.jpg" alt="milford sound promo tile" /&gt;
# 					</p><p class="content-box-description">Take an unforgettable journey </p></body></html>
# print daLink
# <html><body><p>into this breathtaking region - a must-see destination.</p>
# <div class="content-box-textlink"><a href="http://www.milfor"></a></div></body></html>
# print daLink
# <html><body><p>d-sound.co.nz/" onClick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Featured Destination - Milford Sound']);"&gt;Visit</p></body></html>
# print daLink
# <html><body><p>milford-sound.co.nz
#
#
#
# 			</p><div class=" promo ten columns content-box-right">
# <div class=""></div></div></body></html>
# print daLink
# <html><body><p>="content-box  content-box-right"&gt;
# 					</p><p class="content-box-tagline"><a href="/passes/flexi-options/" style="text-decoration:"></a></p></body></html>
# print daLink
# <html><body><p>none"&gt;<span class="content-box-highlight-red"></span> NZ Bus Passes from just $39</p>
# <div class="content-box-thumbn"></div></body></html>
# print daLink
# <html><body><p>ail"&gt;<img alt="backpacker new zealand" src="/assets/Uploads/backpacker-new-zealand.jpg"/>
# </p><p class="content-box-des"></p></body></html>
# print daLink
# <html><body><p>cription"&gt;Looking for a way to explore NZ? InterCity passes offer great savings on travel.</p>
# <div class="content-box-t"></div></body></html>
# print daLink
# <html><body><p>extlink"&gt;<a href="/passes/flexi-options/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'NZ Bus Passes from ju"></a></p></body></html>
# print daLink
# <html><body><p>st $39']);"&gt;Search NZ Bus Passes
#
#
#
#
#
#
#
#
#
#
# 			</p></body></html>
# print daLink
# <html><body><p>v&gt;
#
#
# 		</p><div class="row" id="Footer">
# <div class="footer-content twenty columns">
# <div class="footer-column"></div></div></div></body></html>
# print daLink
# <html><body><p>left"&gt;
# 		</p><h3>About InterCity</h3>
# <p><a href="/about-us">About Us</a> . <a href="/about-us/media-releases">Media</a>. <a hr=""></a></p></body></html>
# print daLink
# <html><body><p>ef="/privacy-policy"&gt;Privacy . <a href="booking-agents/">Booking Agents</a> . <a href="/whatsnew/">What's New</a> . <a href=""></a></p></body></html>
# print daLink
# <html><body><p>"/help/"&gt;Site Map </p>
# <h3>Get Info</h3>
# <p><a href="/managebooking/" onclick="_gaq.push(['_trackEvent', 'Footer Link'"></a></p></body></html>
# print daLink
# <html><body><p>, 'Go To', 'Manage my Booking']);"&gt;Manage my booking . <a href="/frequently-asked-questions/">FAQs</a> . <a href="/delays-an"></a></p></body></html>
# print daLink
# <html><body><p>d-cancellations/"&gt;Delays &amp; Disruptions . <a href="/terms-and-conditions">Terms &amp; Conditions</a></p>
# <h3>Get Onboard</h3> </body></html>
# print daLink
# <html><body><p><a href="/rewards">Freeway Login</a> . <a href="/about-us/affiliate/">Affiliate Programme</a> . <a href="/feedback">Feedba</a></p></body></html>
# print daLink
# <html><body><p>ck . <a href="/feedback">Contact Us</a></p>
# <div class="footer-column right">
# <h3>Tours</h3>
# <p> <a href="/"></a></p></div></body></html>
# print daLink
# <html><body><p>tours"&gt;Tours . <a href="http://www.greatsights.co.nz/" target="blank">Great Sights</a> . <a href="http://www.awesomenz.com/"></a></p></body></html>
# print daLink
# <html><body><p>target="blank"&gt;Awesome NZ . <a href="http://www.dolphincruises.co.nz/" target="blank">Dolphin Cruise</a></p>
# <h3>Passes</h3></body></html>
# print daLink
# <html><body><p>/h3&gt;
# 		</p><p><a href="http://flexipass.intercity.co.nz/" target="blank">Flexipass</a> . <a href="http://www.flexitrips.co.nz" targ=""></a></p></body></html>
# print daLink
# <html><body><p>et="blank"&gt;Flexitrips . <a href="http://travelpass.intercity.co.nz">TravelPass</a> . <a href="/passes/intercity-commuter/">I</a></p></body></html>
# print daLink
# <html><body><p>nterCity Commuter . <a href="/passes/student-bus-pass/">Student Pass</a></p>
# <h3>Connect</h3>
# <div class="social-media"></div></body></html>
# print daLink
# <html><body><p>"&gt;
# 		</p><p><a href="http://www.facebook.com/intercity.coachlines" target="blank"><img class="left" src="assets/intercity12/main/ic"/></a></p></body></html>
# print daLink
# <html><body><p>_facebookIcon.png" alt="Facebook" width="27" height="27" title=""/&gt;<a href="http://www.twitter.com/InterCityBUS" target="bla"></a></p></body></html>
# print daLink
# <html><body><p>nk"&gt;<img alt="Twitter" class="left" height="27" src="assets/intercity12/main/ic_twitterIcon.png" title="" width="26"/><a hre=""></a></p></body></html>
# print daLink
# <html><body><p>f="http://plus.google.com/100713504200361907253" target="blank"&gt;<img class="left" src="assets/intercity12/main/ic_googleplusIcon"/></p></body></html>
# print daLink
# <html><body><p>.png" alt="Google+" width="27" height="27" title=""/&gt;Copyright ÂŠ 2012 InterCity Group (NZ) Ltd.</p>
# </body></html>
# print daLink
# <html><body><p>iv&gt;
#
#
#
#
# 	<script src="http://www.intercity.co.nz/assets/intercity12/js/jslibs.js?m=" type="text/javascript"></script></p></body></html>
# print daLink
# <html><body><p>1386109965"&gt;<script src="http://www.intercity.co.nz/assets/intercity12/js/global.js?m=1386109965" type="text/javascript"></script></p></body></html>
# print daLink
# <html><body><p>"&gt;<script src="http://www.intercity.co.nz/mysite/javascript/iealert.min.js?m=1369093915" type="text/javascript"></scrip</script></p></body></html>
# print daLink
# <html><body><p>t&gt;<script src="http://www.intercity.co.nz/mysite/javascript/page.js?m=1376345437" type="text/javascript"></script><script type=""></script></p></body></html>
# print daLink
# <html><body><p>text/javascript" src="http://www.intercity.co.nz/assets/intercity12/js/intercity12.js?m=1386109965"&gt;<script type="text/"></script></p></body></html>
# print daLink
# <html><body><p>javascript" src="http://www.intercity.co.nz/themes/intercity12/javascripts/theme.js?m=1385067882"&gt;<script type="text/ja"></script></p></body></html>
# print daLink
# <html><body><p>vascript" src="http://www.intercity.co.nz/bookingelements/javascript/SectorSearchForm.js?m=1368669239"&gt;<script type="te"></script></p></body></html>
# print daLink
# <html><body><p>xt/javascript" src="http://www.intercity.co.nz/assets/_stops/stop_autocomplete_field.js?m=1383165215"&gt;<script type="tex"></script></p></body></html>
# print daLink
# <html><body><p>t/javascript" src="http://www.intercity.co.nz/bookingelements/javascript/StopPickerField.js?m=1345523838"&gt;<script type=""></script></p></body></html>
# print daLink
# <html><body><p>"text/javascript"&gt;//<script type="text/javasc"></script></p></body></html>
# print daLink
# <html><body><p>ript"&gt;//</p></body>
# </html>

# %%
for site in loadSite:
    print'print site'
    inter = BeautifulSoup(site)
    print inter.titlefor site in loadSite:
    print'print site'
    inter = BeautifulSoup(site)
    print inter.title
# Out:
#   File "<ipython-input-50-cbfacba43087>", line 4
#     print inter.titlefor site in loadSite:
#                             ^
# SyntaxError: invalid syntax

# %%
for site in loadSite:
    print'print site'
    inter = BeautifulSoup(site)
    print inter.title
# Out:
# print site
# None
# print site
# <title>InterCity // Bus Ticket</title>
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None
# print site
# None

# %%
print inter
# Out:
# <html><body><p>ript"&gt;//</p></body>
# </html>

# %%
    print inter
# Out:
#   File "<ipython-input-53-939521066744>", line 1
#     print inter
#     ^
# IndentationError: unexpected indent
