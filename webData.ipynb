# %% [markdown]
# # Intercity Python API Development

# %%
from bs4 import BeautifulSoup
import requests
import numpy
import tweepy

# %%
loadSite = requests.get('http://www.intercity.co.nz/')

# %%
siteData =  loadSite.content

# %%
omgSite = BeautifulSoup(siteData)

# %%
print omgSite.find_all('a')
# Out:
# [<a class="logo left" href="/" onclick="_gaq.push(['_trackEvent', 'HeaderLogo', 'Back Home', 'InterCity Logo']);"><img alt="iclogo.png" src="/assets/intercity12/main/iclogo.png"/></a>, <a href="http://m.intercity.co.nz">Mobile Site</a>, <a href="/info/about-us/">About Us</a>, <a href="/contact-us" id="feedback">Contact Us</a>, <a class="current" href="/">H</a>, <a class="flyout-toggle" href="/#"><span></span></a>, <a class="flyout-toggle" href="/#"><span></span></a>, <a href="/timetable">Timetables and Bus Stops</a>, <a href="/route-map">Route Map</a>, <a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a>, <a> </a>, <a href="/getting-a-1-fare">Getting a $1 Fare</a>, <a href="/non-refundable-vs-flexible">Non Refundable vs Flexible Fares</a>, <a href="/discount-bus-fares">Student,Backpacker &amp; Senior Fares</a>, <a href="/carryon-checked-luggage">Carry on and Checked Luggage</a>, <a href="/oversized-items">Oversized Items/Bicycles</a>, <a href="/north-island-booking-agents/">Find a North Island Agent</a>, <a href="/south-island-booking-agents/">Find a South Island Agent</a>, <a href="/delays-and-disruptions">View Current Disruptions</a>, <a href="/special-assistance">Special Needs and Assistance</a>, <a href="/child-fares">Child Fares</a>, <a href="http://www.intercity.co.nz/assets/file/intercityunaccompanied.pdf">Unaccompanied Minor Form</a>, <a href="/frequently-asked-questions/">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-faq_icon2.png" title="" width="25"/> Frequently Asked Questions</h2>
# </a>, <a href="/group-bookings">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-groupbookings_icon2.png" title="" width="25"/> Group Bookings</h2>
# </a>, <a class="flyout-toggle" href="/#"><span></span></a>, <a href="/change-cancel-a-booking">How To Change/Cancel a Booking</a>, <a href="/managebooking">Login to Manage a booking</a>, <a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a>, <a class="flyout-toggle" href="/#"><span></span></a>, <a href="/how-it-works">How it works </a>, <a href="/about-earning-free-travel">Earning FREE Travel</a>, <a href="/join-club-freeway">Join FREEWAY</a>, <a href="/rewards">Login to FREEWAY</a>, <a href="/clubpasswordreset">Forgotten Password?</a>, <a href="/cheapas">Sign up for special offers</a>, <a class="flyout-toggle" href="/#"><span></span></a>, <a href="/intercity-milford-sound-tour/"><img alt="Milford Sound Bus Tour" src="/assets/intercity12/main/ICONSMENU/milford_icon.png" style="float:left;" title=""/></a>, <a href="/intercity-milford-sound-tour/">
# <h2>Milford Sound</h2>
# </a>, <a href="/intercity-milford-sound-tour/"> </a>, <a href="/intercity-milford-sound-tour/"></a>, <a href="/intercity-milford-sound-tour/">Day trip from Queenstown from $119*</a>, <a href="/intercity-hobbiton-excursion-auckland-to-auckland/"><img alt="Hobbiton Movie Set Day Tour" src="/assets/intercity12/main/ICONSMENU/hobbiton_icon.png" style="float:left" title=""/></a>, <a href="/intercity-hobbiton-excursion-auckland-to-auckland/">
# <h2>Hobbiton Movie Set</h2>
# </a>, <a href="/intercity-hobbiton-excursion-auckland-to-auckland/"> </a>, <a href="/intercity-hobbiton-excursion-auckland-to-auckland/"></a>, <a href="/intercity-hobbiton-excursion-auckland-to-auckland/">Day trip from Auckland from $139*</a>, <a href="/dart-river-jet/"><img alt="Dart River Jet Tour" src="/assets/intercity12/main/ICONSMENU/Dart-River_icon.png" style="float:left;" title=""/></a>, <a href="/dart-river-jet/">
# <h2>Dart River Jet</h2>
# </a>, <a href="/dart-river-jet/"> </a>, <a href="/dart-river-jet/"></a>, <a href="/dart-river-jet/">Dart River Jet Tour Ex Q'tn from $219*</a>, <a href="/tours/waitomo-caves-tour/"><img alt="Waitomo Caves Day Tour" src="assets/intercity12/main/ICONSMENU/waitomo_icon.png" style="float:left;" title=""/></a>, <a href="/tours/waitomo-caves-tour/">
# <h2>Waitomo Caves Tour</h2>
# </a>, <a href="/tours/waitomo-caves-tour/"> </a>, <a href="/tours/waitomo-caves-tour/"></a>, <a href="/tours/waitomo-caves-tour/">Day trips to Waitomo Caves From $139*</a>, <a href="/intercity-dolphin-cruise-tour/"><img alt="Bay of Islands Day Tour" src="/assets/intercity12/main/ICONSMENU/boi_icon.png" style="float:left;" title=""/></a>, <a href="/intercity-dolphin-cruise-tour/">
# <h2>Bay of Islands</h2>
# </a>, <a href="/intercity-dolphin-cruise-tour/"> </a>, <a href="/intercity-dolphin-cruise-tour/"></a>, <a href="/intercity-dolphin-cruise-tour/">Day trip from Auckland from $119*</a>, <a href="/the-lord-of-the-rings-film-locations/"><img alt="Lord of the Rings Tour" src="/assets/intercity12/main/ICONSMENU/lotr_thumb.jpg" style="float:left;" title=""/></a>, <a href="/the-lord-of-the-rings-film-locations/">
# <h2>LOTR Film Locations</h2>
# </a>, <a href="/the-lord-of-the-rings-film-locations/"> </a>, <a href="/the-lord-of-the-rings-film-locations/"></a>, <a href="/the-lord-of-the-rings-film-locations/">Discover the films' locations in NZ</a>, <a href="/Auckland-Morning-City-tour/"><img alt="Auckland City Sightseeing Tour" src="/assets/intercity12/main/auckland-city-sightseeing-tour-thumb.jpg" style="float:left;" title=""/></a>, <a href="/Auckland-Morning-City-tour/">
# <h2>Auckland City Tour</h2>
# </a>, <a href="/Auckland-Monring-City-tour/"> </a>, <a href="/Auckland-Morning-City-tour/"></a>, <a href="/Auckland-Morning-City-tour/">Half day city tours from $39*</a>, <a href="/hukafalls-jet/"><img alt="Huka Jet Tour" src="/assets/intercity12/main/ICONSMENU/huka_icon.png" style="float:left;" title=""/></a>, <a href="/hukafalls-jet/">
# <h2>Hukafalls Jet</h2>
# </a>, <a href="/hukafalls-jet/"> </a>, <a href="/hukafalls-jet/"></a>, <a href="/hukafalls-jet/">Daily from Taupo from $109*</a>, <a href="/tamaki-maori-village-experience/"><img alt="Tamaki Maori Village" src="/assets/intercity12/main/ICONSMENU/rotorua_tamaki_icon.jpg" style="float:left;" title=""/></a>, <a href="/tamaki-maori-village-experience/">
# <h2>Tamaki Māori Village</h2>
# </a>, <a href="/tamaki-maori-village-experience/"> </a>, <a href="/tamaki-maori-village-experience/"></a>, <a href="/tamaki-maori-village-experience/">Daily from Rotorua from $110*</a>, <a class="flyout-toggle" href="/#"><span></span></a>, <a href="/flexi-options/"><img alt="New Zealand Bus Tours and Passes" src="/assets/intercity12/main/ICONSMENU/flexible.jpg" style="float:left;"/></a>, <a href="/flexi-options/">
# <h2>Flexible Itinerary Options</h2>
# </a>, <a href="/flexi-options/"> </a>, <a href="/flexi-options/"></a>, <a href="/flexi-options/">Our most popular transport passes for independent travellers.  'Travel like a local' NZ's largest Hop-on/Hop-off network.  Total freedom + sightseeing &amp; activity options.</a>, <a href="/travel-pass/"><img alt="New Zealand Bus Pass" src="/assets/intercity12/main/ICONSMENU/fixed.jpg" style="float:left"/></a>, <a href="/travel-pass/">
# <h2>Fixed Itinerary Passes</h2>
# </a>, <a href="/travel-pass/"> </a>, <a href="/travel-pass/"></a>, <a href="/travel-pass/">Pre-planned transport passes for those wanting a set itinerary travel.  Choose from a range of passes including sightseeing tour options.</a>, <a href="/intercity-commuter/"><img alt="Auckland to Hamilton Bus Pass New Zealand" src="/assets/intercity12/main/ICONSMENU/commuter.jpg" style="float:left;"/></a>, <a href="/intercity-commuter/">Save up to 38%* on regular fares between Hamilton/Auckland.  Over 20 services per day between cities on NZ's #1 Bus Network.</a>, <a href="/student-bus-pass/"><img alt="Student Bus Pass New Zealand" src="/assets/intercity12/main/ICONSMENU/student-pass.jpg" style="float:left;"/></a>, <a href="/student-bus-pass/">
# <h2>Student Passes</h2>
# </a>, <a href="/student-bus-pass/"> </a>, <a href="/student-bus-pass/"></a>, <a href="/student-bus-pass/">Great savings for students! <br/> Passes available for Hawke's Bay, New Plymouth and Dunedin students.</a>, <a class="link" href="http://www.booking.com/index.html?aid=369493">Accommodation</a>, <a class="flyout-toggle" href="/#"><span></span></a>, <a class="stoppicker" data-stopfield-id="SectorSearchForm_Form_From" data-title="Travelling from" href="#" title="Choose a stop to travel from...">V</a>, <a class="stoppicker" data-stopfield-id="SectorSearchForm_Form_To" data-title="Travelling to" href="#" title="Choose a stop to travel to...">V</a>, <a href="#stoppickerdialog-main">Main Stops</a>, <a href="#stoppickerdialog-ni">North Island All Stops</a>, <a href="#stoppickerdialog-si">South Island All Stops</a>, <a data-stop-code="PIH" title="Maritime Building, Adjacent Wharf">Paihia</a>, <a data-stop-code="AKL" title="Sky City Coach Terminal, 102 Hobson Street">Auckland</a>, <a data-stop-code="AIR" title="Bus Stop 2008 International Terminal, Ray Emery Drive.">Auckland International Airport</a>, <a data-stop-code="MNK" title="Leyton Way near foodcourt">Manukau City</a>, <a data-stop-code="HLZ" title="Hamilton Transport Centre, Cnr Bryce &amp; Anglesea, Platforms A - D.">Hamilton</a>, <a data-stop-code="ROT" title="Tourism Rotorua, 1167 Fenton Street">Rotorua</a>, <a data-stop-code="TUO" title="Taupo Travel Centre, 16 Gascoigne Street">Taupo</a>, <a data-stop-code="GIS" title="Outside Gisborne I-Site, 209 Grey Street">Gisborne</a>, <a data-stop-code="NPE" title="135 Dalton St (Nearest Intersection - Station Street)">Napier</a>, <a data-stop-code="NPL" title="19 Ariki Street, New Plymouth">New Plymouth</a>, <a data-stop-code="PMR" title="Travel Centre Corner Pitt &amp; Main Streets">Palmerston Nth</a>, <a data-stop-code="WLG" title="Railway Station, Platform 9">Wellington</a>, <a data-stop-code="PCN" title="Outside Main Entrance of Interislander Ferry Terminal">Picton</a>, <a data-stop-code="NSN" title="Outside Travel Centre, 27 Bridge Street">Nelson</a>, <a data-stop-code="GRM" title="Greymouth Railway Station, 164 MacKay St">Greymouth</a>, <a data-stop-code="CHC" title="118 Bealey Ave (between Colombo St and Durham St intersections)">Christchurch</a>, <a data-stop-code="DUD" title="Ritchies/InterCity Travel, 7 Halsey Street, near the corner of Sturdee Street">Dunedin</a>, <a data-stop-code="ZQN" title="Athol Street in the middle of the car park">Queenstown</a>, <a data-stop-code="WHO" title="Franz Josef Bus Stop, Main Road">Franz Josef</a>, <a data-stop-code="MFN" title="Front Entrance of Visitors Centre, Milford Wharf">Milford Sound</a>, <a data-stop-code="IVC" title="Invercargill Information Centre Car Park, 108 Gala Street">Invercargill</a>, <a data-stop-code="ABF" href="#">Aberfeldy</a>, <a data-stop-code="AHT" href="#">Ahititi Turn Off</a>, <a data-stop-code="AKO" href="#">Akoranga (Auckland)</a>, <a data-stop-code="ALY" href="#">Albany (Auckland)</a>, <a data-stop-code="ACL" href="#">Anchor Lodge Backpackers (Coromandel)</a>, <a data-stop-code="ASH" href="#">Ashhurst</a>, <a data-stop-code="ATI" href="#">Atiamuri</a>, <a data-stop-code="AKL" href="#">Auckland - Central</a>, <a data-stop-code="ADA" href="#">Auckland Domestic Airport</a>, <a data-stop-code="AIR" href="#">Auckland International Airport</a>, <a data-stop-code="AVC" href="#">Auckland Vector Arena</a>, <a data-stop-code="AWH" href="#">Awahuri</a>, <a data-stop-code="AWK" href="#">Awakeri</a>, <a data-stop-code="AKN" href="#">Awakino</a>, <a data-stop-code="AAI" href="#">Awanui</a>, <a data-stop-code="MMB" href="#">Bayfair</a>, <a data-stop-code="BVW" href="#">Bayview</a>, <a data-stop-code="BBK" href="#">Bell Block</a>, <a data-stop-code="BOX" href="#">Bombay (Auckland)</a>, <a data-stop-code="BRY" href="#">Brynderwyn</a>, <a data-stop-code="BLS" href="#">Bulls</a>, <a data-stop-code="GBW" href="#">BW Campground (for Rhythm and Vines Festival - Gisborne)</a>, ...
# <div class="slideshow-text">
# <h1>Buy bus and ferry combos from <span class="price-highlight">$95*</span></h1>
# <p>Combine InterCity bus trips and Interislander passenger ferry trips on our new combo passes</p>
# <div class="grey-btn">Find Out More</div>
# </div>
# </a>, <a href="#" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - $1fare']);">
# <div class="slideshow-text">
# <h1>$1* fares with InterCity</h1>
# <p>Everyone loves a bargain!  <br/><br/>And we've got at least one $1* fare available on each and every InterCity® bus service. <br/><br/>*+ Booking Fee.</p>
# <!-- <div class="grey-btn">Find tours now</div> -->
# </div>
# </a>, <a href="/passes/flexi-options" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - flexiOptions']);">
# <div class="slideshow-text">
# <h1>NZ's National Bus Passes</h1>
# <p>See more of New Zealand! Travel on NZ's largest national network with one of our flexible bus pass options.</p>
# <div class="grey-btn">Search Passes Now</div>
# </div>
# </a>, <a href="/tours/" style="text-decoration:none"><span class="content-box-highlight-red"></span> Discounted tours from $105</a>, <a href="/tours/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Discounted tours from $105']);">Search New Zealand Tours</a>, <a href="http://www.booking.com/index.html?aid=369493" style="text-decoration:none"><span class="content-box-highlight-red"></span> Need Accommodation?</a>, <a href="http://www.booking.com/index.html?aid=369493" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Need Accommodation?']);">Search accommodation now</a>, <a href="travel-info/timetable/" style="text-decoration:none"><span class="content-box-highlight-red"></span> Find a bus stop</a>, <a href="travel-info/timetable/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Find a bus stop']);">Get more info</a>, <a href="/bus-to-auckland-airport" style="text-decoration:none"><span class="content-box-highlight-red"></span> Auckland Airport Connections</a>, <a href="/bus-to-auckland-airport" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Auckland Airport Connections']);">View Airport Connections</a>, <a href="http://www.milford-sound.co.nz/" style="text-decoration:none"><span class="content-box-highlight-red"></span> Featured Destination - Milford Sound</a>, <a href="http://www.milford-sound.co.nz/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Featured Destination - Milford Sound']);">Visit milford-sound.co.nz</a>, <a href="/passes/flexi-options/" style="text-decoration:none"><span class="content-box-highlight-red"></span> NZ Bus Passes from just $39</a>, <a href="/passes/flexi-options/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'NZ Bus Passes from just $39']);">Search NZ Bus Passes</a>, <a href="/about-us">About Us</a>, <a href="/about-us/media-releases">Media</a>, <a href="/privacy-policy">Privacy</a>, <a href="booking-agents/">Booking Agents</a>, <a href="/whatsnew/">What's New</a>, <a href="/help/">Site Map</a>, <a href="/managebooking/" onclick="_gaq.push(['_trackEvent', 'Footer Link', 'Go To', 'Manage my Booking']);">Manage my booking</a>, <a href="/frequently-asked-questions/">FAQs</a>, <a href="/delays-and-cancellations/">Delays &amp; Disruptions</a>, <a href="/terms-and-conditions">Terms &amp; Conditions</a>, <a href="/rewards">Freeway Login</a>, <a href="/about-us/affiliate/">Affiliate Programme</a>, <a href="/feedback">Feedback</a>, <a href="/feedback">Contact Us</a>, <a href="/tours">Tours</a>, <a href="http://www.greatsights.co.nz/" target="blank">Great Sights</a>, <a href="http://www.awesomenz.com/" target="blank">Awesome NZ</a>, <a href="http://www.dolphincruises.co.nz/" target="blank">Dolphin Cruise</a>, <a href="http://flexipass.intercity.co.nz/" target="blank">Flexipass</a>, <a href="http://www.flexitrips.co.nz" target="blank">Flexitrips</a>, <a href="http://travelpass.intercity.co.nz">TravelPass</a>, <a href="/passes/intercity-commuter/">InterCity Commuter</a>, <a href="/passes/student-bus-pass/">Student Pass</a>, <a href="http://www.facebook.com/intercity.coachlines" target="blank"><img alt="Facebook" class="left" height="27" src="assets/intercity12/main/ic_facebookIcon.png" title="" width="27"/></a>, <a href="http://www.twitter.com/InterCityBUS" target="blank"><img alt="Twitter" class="left" height="27" src="assets/intercity12/main/ic_twitterIcon.png" title="" width="26"/></a>, <a href="http://plus.google.com/100713504200361907253" target="blank"><img alt="Google+" class="left" height="27" src="assets/intercity12/main/ic_googleplusIcon.png" title="" width="27"/></a>]

# %%
print omgSite.title
# Out:
# <title>InterCity // Bus Tickets From $1 // NZ’s National Network // Bus Pass</title>

# %%
print omgSite.prettify
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <base href="http://www.intercity.co.nz/"/><!--[if lte IE 6]></base><![endif]-->
# <meta charset="utf-8"/>
# <title>InterCity // Bus Tickets From $1 // NZ’s National Network // Bus Pass</title>
# <meta content="New Zealand's most popular bus network. Bus tickets from $1 (+booking fee). Bus passes for backpackers. Book online - no credit card required. " name="description"/><meta content="" name="keywords"/>
# <link href="/assets/intercity12/main/favicon.ico" rel="shortcut icon"/>
# <style>
# 					/*#Header {background: transparent url('/assets/intercity/main/header5.jpg') no-repeat !important;}*/
# 				</style>
# <!-- -->
# <link href="http://www.intercity.co.nz/mysite/javascript/lib/jquery-ui-themes/custom/jquery-ui-1.8.21.custom.css?m=1369093914" rel="stylesheet" type="text/css"/>
# <link href="http://www.intercity.co.nz/mysite/javascript/lib/jquery-fancybox/jquery.fancybox-1.3.1.css?m=1369093915" rel="stylesheet" type="text/css"/>
# <link href="http://www.intercity.co.nz/mysite/css/iealert/style.css?m=1369093914" rel="stylesheet" type="text/css"/>
# <link href="http://www.intercity.co.nz/mysite/css/common.css?m=1369093914" rel="stylesheet" type="text/css"/>
# <link href="http://www.intercity.co.nz/themes/intercity12/css/reservations.css?m=1386294423" rel="stylesheet" type="text/css"/>
# <link href="http://www.intercity.co.nz/themes/intercity12/css/app.css?m=1386294417" rel="stylesheet" type="text/css"/>
# <link href="http://www.intercity.co.nz/themes/intercity12/css/typography.css?m=1386294418" rel="stylesheet" type="text/css"/>
# <link href="http://www.intercity.co.nz/bookingelements/css/StopPickerField.css?m=1339120101" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-1266228-1']);
# _gaq.push(['_setDomainName', '.intercity.co.nz']);
# _gaq.push(['_setAllowLinker', true]);
# _gaq.push(['_trackPageview']);
#
# (function() {
# 	var ga = document.createElement('script');
# 	ga.type = 'text/javascript';
# 	ga.async = true;
# 	ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 	var s = document.getElementsByTagName('script')[0];
# 	s.parentNode.insertBefore(ga, s);
# })();
#
# (function recordOutboundLink(link, category, action) {
#   try {
#     var myTracker=_gat._getTrackerByName();
#     _gaq.push(['myTracker._trackEvent', ' + category + ', ' + action + ']);
#     setTimeout('document.location = "' + link.href + '"', 100)
#   }catch(err){}
# })();
#
#
# </script>
# </head>
# <body class="typography home HomePage">
# <div class="row" id="Container">
# <div class="twenty columns" id="Main">
# <div class="row" id="Header">
# <div class="twenty columns">
# <a class="logo left" href="/" onclick="_gaq.push(['_trackEvent', 'HeaderLogo', 'Back Home', 'InterCity Logo']);"><img alt="iclogo.png" src="/assets/intercity12/main/iclogo.png"/></a>
# <h2 class="left">Low fares, everywhere, everyday.</h2>
# <ul class="header-link right"><li><a href="http://m.intercity.co.nz">Mobile Site</a></li>
# <li><a href="/info/about-us/">About Us</a></li>
# <li><a href="/contact-us" id="feedback">Contact Us</a></li>
# </ul>
# <div class="clear"></div>
# </div>
# </div>
# <div class="row" id="Navigation">
# <div class="twenty columns" id="Menu">
# <ul class="nav-bar">
# <li class="has-flyout">
# <a class="current" href="/">H</a>
# <a class="flyout-toggle" href="/#"><span></span></a>
# </li>
# <li class="has-flyout">
# <span class="has-a-submenu">Travel Info</span>
# <a class="flyout-toggle" href="/#"><span></span></a>
# <ul class="flyout">
# <!--
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/travel-info/route-map/">View the route map</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/travel-info/north-island-booking-agents/">Booking Agents</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/travel-info/child-fares/">Child Fares </a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/travel-info/frequently-asked-questions/">FAQ&#39;s</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/travel-info/delays-and-disruptions/">Delays / Disruptions</a>
#
#
# 								</li>
# 								</div>
# 							-->
# <div class="subMenuRightColumn"><div class="menu-section">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-timetable_icon2.png" title="" width="25"/> Timetables</h2>
# <ul><li><a href="/timetable">Timetables and Bus Stops</a></li>
# <li><a href="/route-map">Route Map</a></li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-changes_icon2.png" title="" width="25"/> Changes &amp; Refunds</h2>
# <ul><li><a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a></li>
# <li><a> </a></li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="28" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2828-fare_icon2.png" title="" width="28"/> Fares &amp; Bookings</h2>
# <ul><li><a href="/getting-a-1-fare">Getting a $1 Fare</a></li>
# <li><a href="/non-refundable-vs-flexible">Non Refundable vs Flexible Fares</a></li>
# <li><a href="/discount-bus-fares">Student,Backpacker &amp; Senior Fares</a></li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-luggage_icon2.png" title="" width="25"/> Luggage</h2>
# <ul><li><a href="/carryon-checked-luggage">Carry on and Checked Luggage</a></li>
# <li><a href="/oversized-items">Oversized Items/Bicycles</a></li>
# <li> </li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-agents_icon2.png" title="" width="25"/> Booking Agents</h2>
# <ul><li><a href="/north-island-booking-agents/">Find a North Island Agent</a></li>
# <li><a href="/south-island-booking-agents/">Find a South Island Agent</a></li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-delays_icon2.png" title="" width="25"/> Delays &amp; Disruptions</h2>
# <ul><li><a href="/delays-and-disruptions">View Current Disruptions</a></li>
# <li> </li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-special_assistance_icon2.png" title="" width="25"/> Special Assistance</h2>
# <ul><li><a href="/special-assistance">Special Needs and Assistance</a></li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-children_icon2.png" title="" width="25"/> Travelling with Children</h2>
# <ul><li><a href="/child-fares">Child Fares</a></li>
# <li><a href="http://www.intercity.co.nz/assets/file/intercityunaccompanied.pdf">Unaccompanied Minor Form</a></li>
# </ul></div>
# <div class="menu-section faq"><a href="/frequently-asked-questions/">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-faq_icon2.png" title="" width="25"/> Frequently Asked Questions</h2>
# </a></div>
# <div class="menu-section groupbooking"><a href="/group-bookings">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-groupbookings_icon2.png" title="" width="25"/> Group Bookings</h2>
# </a></div></div>
# </ul>
# </li>
# <li class="has-flyout">
# <span class="has-a-submenu">Manage Booking</span>
# <a class="flyout-toggle" href="/#"><span></span></a>
# <ul class="flyout">
# <!--
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/manage-booking/change-cancel-a-booking/">How to Modify/Cancel a Booking</a>
#
#
# 								</li>
# 								</div>
# 							-->
# <div class="subMenuRightColumn"><div class="menu-section">
# <h2><img alt="&gt;" src="/assets/intercity12/main/ICONSMENU/manage_icon2.png"/> Manage your booking</h2>
# <ul><li><a href="/change-cancel-a-booking">How To Change/Cancel a Booking</a></li>
# <li><a href="/managebooking">Login to Manage a booking</a></li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-changes_icon2.png" width="25"/> Changes &amp; Refunds</h2>
# <ul><li><a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a></li>
# </ul></div></div>
# </ul>
# </li>
# <li class="has-flyout">
# <span class="has-a-submenu">Frequent Travellers</span>
# <a class="flyout-toggle" href="/#"><span></span></a>
# <ul class="flyout">
# <!--
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/frequent-travellers/how-it-works/">How it Works</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/frequent-travellers/join-club-freeway/">Join Club Freeway</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/frequent-travellers/forgotpwd/">Club Password Reset</a>
#
#
# 								</li>
# 								</div>
# 							-->
# <div class="subMenuRightColumn"><div class="menu-section">
# <h2><img alt="&gt;" height="28" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2828-rewards_icon2.png" title="" width="28"/> FREEWAY Travel Rewards</h2>
# <ul><li><a href="/how-it-works">How it works </a></li>
# <li><a href="/about-earning-free-travel">Earning FREE Travel</a></li>
# <li><a href="/join-club-freeway">Join FREEWAY</a></li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="25" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-freewaymember_icon2.png" title="" width="25"/> FREEWAY Members</h2>
# <ul><li><a href="/rewards">Login to FREEWAY</a></li>
# <li><a href="/clubpasswordreset">Forgotten Password?</a></li>
# </ul></div>
# <div class="menu-section">
# <h2><img alt="&gt;" height="28" src="assets/intercity12/main/ICONSMENU/_resampled/resizedimage2828-cheapas_icon2.png" title="" width="28"/> Cheap-as Seats</h2>
# <ul><li><a href="/cheapas">Sign up for special offers</a></li>
# </ul></div></div>
# </ul>
# </li>
# <li class="has-flyout">
# <span class="has-a-submenu">Tours</span>
# <a class="flyout-toggle" href="/#"><span></span></a>
# <ul class="flyout">
# <!--
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/tours/intercity-hobbiton-excursion-auckland-to-auckland/">Hobbiton Excursion</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/tours/intercity-milford-sound-tour/">Milford Sound Tour</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/tours/intercity-dolphin-cruise-tour/">Dolphin Cruise Tour</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/tours/hukafalls-jet/">Hukafalls Jetboat Morning Tour (Return ex Taupo)</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/tours/the-lord-of-the-rings-film-locations/">LOTR Film Locations</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/tours/Auckland-Morning-City-tour/">Auckland Morning City Tour </a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/tours/tamaki-maori-village-experience/">Tamaki Maori Village Evening Experience</a>
#
#
# 								</li>
# 								</div>
# 							-->
# <div class="subMenuRightColumn"><div class="menu-section tours-sub"><a href="/intercity-milford-sound-tour/"><img alt="Milford Sound Bus Tour" src="/assets/intercity12/main/ICONSMENU/milford_icon.png" style="float:left;" title=""/></a>
# <div class="menu-dets" style="float:left;"><a href="/intercity-milford-sound-tour/">
# <h2>Milford Sound</h2>
# </a>
# <ul><a href="/intercity-milford-sound-tour/"> </a>
# <li><a href="/intercity-milford-sound-tour/"></a><a href="/intercity-milford-sound-tour/">Day trip from Queenstown from $119*</a></li>
# </ul></div>
# </div>
# <div class="menu-section tours-sub"><a href="/intercity-hobbiton-excursion-auckland-to-auckland/"><img alt="Hobbiton Movie Set Day Tour" src="/assets/intercity12/main/ICONSMENU/hobbiton_icon.png" style="float:left" title=""/></a>
# <div class="menu-dets" style="float:left;"><a href="/intercity-hobbiton-excursion-auckland-to-auckland/">
# <h2>Hobbiton Movie Set</h2>
# </a>
# <ul><a href="/intercity-hobbiton-excursion-auckland-to-auckland/"> </a>
# <li><a href="/intercity-hobbiton-excursion-auckland-to-auckland/"></a><a href="/intercity-hobbiton-excursion-auckland-to-auckland/">Day trip from Auckland from $139*</a></li>
# </ul></div>
# </div>
# <div class="menu-section tours-sub dart"><a href="/dart-river-jet/"><img alt="Dart River Jet Tour" src="/assets/intercity12/main/ICONSMENU/Dart-River_icon.png" style="float:left;" title=""/></a>
# <div class="menu-dets" style="float:left;"><a href="/dart-river-jet/">
# <h2>Dart River Jet</h2>
# </a>
# <ul><a href="/dart-river-jet/"> </a>
# <li><a href="/dart-river-jet/"></a><a href="/dart-river-jet/">Dart River Jet Tour Ex Q'tn from $219*</a></li>
# </ul></div>
# </div>
# <div class="menu-section tours-sub boi"><a href="/tours/waitomo-caves-tour/"><img alt="Waitomo Caves Day Tour" src="assets/intercity12/main/ICONSMENU/waitomo_icon.png" style="float:left;" title=""/></a>
# <div class="menu-dets" style="float:left;"><a href="/tours/waitomo-caves-tour/">
# <h2>Waitomo Caves Tour</h2>
# </a>
# <ul><a href="/tours/waitomo-caves-tour/"> </a>
# <li><a href="/tours/waitomo-caves-tour/"></a><a href="/tours/waitomo-caves-tour/">Day trips to Waitomo Caves From $139*</a></li>
# </ul></div>
# </div>
# <div class="menu-section tours-sub boi"><a href="/intercity-dolphin-cruise-tour/"><img alt="Bay of Islands Day Tour" src="/assets/intercity12/main/ICONSMENU/boi_icon.png" style="float:left;" title=""/></a>
# <div class="menu-dets" style="float:left;"><a href="/intercity-dolphin-cruise-tour/">
# <h2>Bay of Islands</h2>
# </a>
# <ul><a href="/intercity-dolphin-cruise-tour/"> </a>
# <li><a href="/intercity-dolphin-cruise-tour/"></a><a href="/intercity-dolphin-cruise-tour/">Day trip from Auckland from $119*</a></li>
# </ul></div>
# </div>
# <div class="menu-section tours-sub film_locations"><a href="/the-lord-of-the-rings-film-locations/"><img alt="Lord of the Rings Tour" src="/assets/intercity12/main/ICONSMENU/lotr_thumb.jpg" style="float:left;" title=""/></a>
# <div class="menu-dets" style="float:left;"><a href="/the-lord-of-the-rings-film-locations/">
# <h2>LOTR Film Locations</h2>
# </a>
# <ul><a href="/the-lord-of-the-rings-film-locations/"> </a>
# <li><a href="/the-lord-of-the-rings-film-locations/"></a><a href="/the-lord-of-the-rings-film-locations/">Discover the films' locations in NZ</a></li>
# </ul></div>
# </div>
# <div class="menu-section tours-sub AucklandCityTour"><a href="/Auckland-Morning-City-tour/"><img alt="Auckland City Sightseeing Tour" src="/assets/intercity12/main/auckland-city-sightseeing-tour-thumb.jpg" style="float:left;" title=""/></a>
# <div class="menu-dets" style="float:left;"><a href="/Auckland-Morning-City-tour/">
# <h2>Auckland City Tour</h2>
# </a>
# <ul><a href="/Auckland-Monring-City-tour/"> </a>
# <li><a href="/Auckland-Morning-City-tour/"></a><a href="/Auckland-Morning-City-tour/">Half day city tours from $39*</a></li>
# </ul></div>
# </div>
# <div class="menu-section tours-sub huka"><a href="/hukafalls-jet/"><img alt="Huka Jet Tour" src="/assets/intercity12/main/ICONSMENU/huka_icon.png" style="float:left;" title=""/></a>
# <div class="menu-dets" style="float:left;"><a href="/hukafalls-jet/">
# <h2>Hukafalls Jet</h2>
# </a>
# <ul><a href="/hukafalls-jet/"> </a>
# <li><a href="/hukafalls-jet/"></a><a href="/hukafalls-jet/">Daily from Taupo from $109*</a></li>
# </ul></div>
# </div>
# <div class="menu-section tours-sub tamaki"><a href="/tamaki-maori-village-experience/"><img alt="Tamaki Maori Village" src="/assets/intercity12/main/ICONSMENU/rotorua_tamaki_icon.jpg" style="float:left;" title=""/></a>
# <div class="menu-dets" style="float:left;"><a href="/tamaki-maori-village-experience/">
# <h2>Tamaki Māori Village</h2>
# </a>
# <ul><a href="/tamaki-maori-village-experience/"> </a>
# <li><a href="/tamaki-maori-village-experience/"></a><a href="/tamaki-maori-village-experience/">Daily from Rotorua from $110*</a></li>
# </ul></div>
# </div></div>
# </ul>
# </li>
# <li class="has-flyout">
# <span class="has-a-submenu">New Zealand Bus Passes</span>
# <a class="flyout-toggle" href="/#"><span></span></a>
# <ul class="flyout">
# <!--
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/passes/flexi-options/">Flexi Options</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/passes/travel-pass/">Travel Pass</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/passes/intercity-commuter/">InterCity Commuter</a>
#
#
# 								</li>
# 								</div>
#
# 								<div class="sub-menu-block">
# 								<li>
#
# 										<a href="/passes/student-bus-pass/">Student Pass </a>
#
#
# 								</li>
# 								</div>
# 							-->
# <div class="subMenuRightColumn"><div class="menu-section pass-sub clearfix"><a href="/flexi-options/"><img alt="New Zealand Bus Tours and Passes" src="/assets/intercity12/main/ICONSMENU/flexible.jpg" style="float:left;"/></a>
# <div class="menu-dets" style="float:left;"><a href="/flexi-options/">
# <h2>Flexible Itinerary Options</h2>
# </a>
# <ul><a href="/flexi-options/"> </a>
# <li><a href="/flexi-options/"></a><a href="/flexi-options/">Our most popular transport passes for independent travellers.  'Travel like a local' NZ's largest Hop-on/Hop-off network.  Total freedom + sightseeing &amp; activity options.</a></li>
# </ul></div>
# </div>
# <div class="menu-section pass-sub clearfix"><a href="/travel-pass/"><img alt="New Zealand Bus Pass" src="/assets/intercity12/main/ICONSMENU/fixed.jpg" style="float:left"/></a>
# <div class="menu-dets" style="float:left;"><a href="/travel-pass/">
# <h2>Fixed Itinerary Passes</h2>
# </a>
# <ul><a href="/travel-pass/"> </a>
# <li><a href="/travel-pass/"></a><a href="/travel-pass/">Pre-planned transport passes for those wanting a set itinerary travel.  Choose from a range of passes including sightseeing tour options.</a></li>
# </ul></div>
# </div>
# <div class="menu-section pass-sub huka clearfix"><a href="/intercity-commuter/"><img alt="Auckland to Hamilton Bus Pass New Zealand" src="/assets/intercity12/main/ICONSMENU/commuter.jpg" style="float:left;"/></a>
# <div class="menu-dets" style="float:left;">
# <h2>InterCity Commuter</h2>
# <ul><li><a href="/intercity-commuter/">Save up to 38%* on regular fares between Hamilton/Auckland.  Over 20 services per day between cities on NZ's #1 Bus Network.</a></li>
# </ul></div>
# </div>
# <div class="menu-section pass-sub boi"><a href="/student-bus-pass/"><img alt="Student Bus Pass New Zealand" src="/assets/intercity12/main/ICONSMENU/student-pass.jpg" style="float:left;"/></a>
# <div class="menu-dets" style="float:left;"><a href="/student-bus-pass/">
# <h2>Student Passes</h2>
# </a>
# <ul><a href="/student-bus-pass/"> </a>
# <li><a href="/student-bus-pass/"></a><a href="/student-bus-pass/">Great savings for students! <br/> Passes available for Hawke's Bay, New Plymouth and Dunedin students.</a></li>
# </ul></div>
# </div></div>
# </ul>
# </li>
# <li class="has-flyout">
# <a class="link" href="http://www.booking.com/index.html?aid=369493">Accommodation</a>
# <a class="flyout-toggle" href="/#"><span></span></a>
# </li>
# <!-- HIDING SEARCH BAR FOR PRESENT TIME -->
# <!-- <li class="search-bar">
# 			 <form action="#" method="Get">
# 			 <input type="textarea" name="enter-search">
# 			 <input type="submit" value="">
# 			 </form>
# 			 </li> -->
# </ul>
# <!--<div class="search-bar">
# 		<form action="#" method="Get">
# 			<input type=textarea name=enter-search>
# 			<input type=Submit value="">
# 		</form>
# 	</div>-->
# </div>
# </div>
# <div class="row" id="ResCartSummary">
# <div class="typography ">
# <div class="row" id="Container">
# <div class="twenty columns">
# <div class="NoCart"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="sidebar row" id="Layout">
# <div class="six columns" id="Sidebar">
# <p style="display: none;">home</p>
# <div id="accordion">
# <h2>Search Timetables &amp; Fares</h2>
# <div class="SearchForm">
# <p class="sidebar-blurb">Type in your origin &amp; destination below<br/>OR select from the drop down.</p>
# <form action="/search-results/Form" class="sectorsearchform narrow" enctype="application/x-www-form-urlencoded" id="SectorSearchForm_Form" method="post">
# <p class="message " id="SectorSearchForm_Form_error" style="display: none"></p>
# <fieldset>
# <div class="field h5optionset isReturnTrip nolabel" data-role="fieldcontain" id="OneWayOrReturn"><div class="middleColumn"><ul class="optionset isReturnTrip nolabel" data-role="controlgroup" data-type="horizontal" id="SectorSearchForm_Form_OneWayOrReturn"><li class="radio odd valOneWay"><input checked="checked" class="radio" id="SectorSearchForm_Form_OneWayOrReturn_OneWay" name="OneWayOrReturn" type="radio" value="OneWay"/><label for="SectorSearchForm_Form_OneWayOrReturn_OneWay">One-Way</label></li><li class="radio even valReturn"><input class="radio" id="SectorSearchForm_Form_OneWayOrReturn_Return" name="OneWayOrReturn" type="radio" value="Return"/><label for="SectorSearchForm_Form_OneWayOrReturn_Return">Return</label></li></ul></div></div>
# <div class="field fieldgroup FromStop stopPicker nolabel" id="FromfromPicker"><div class="middleColumn"><div class="fieldgroup"><div class="fieldgroupField"><div class="From leftlabel"><label class="leftlabel" for="SectorSearchForm_Form_From">From</label><input autocomplete="on" class="text StopName" id="SectorSearchForm_Form_From" name="From" placeholder="From" required="required" type="text" value=""/></div></div><div class="fieldgroupField"><a class="stoppicker" data-stopfield-id="SectorSearchForm_Form_From" data-title="Travelling from" href="#" title="Choose a stop to travel from...">V</a></div></div></div></div>
# <div class="field fieldgroup ToStop stopPicker nolabel" id="TotoPicker"><div class="middleColumn"><div class="fieldgroup"><div class="fieldgroupField"><div class="To leftlabel"><label class="leftlabel" for="SectorSearchForm_Form_To">To</label><input autocomplete="on" class="text StopName" id="SectorSearchForm_Form_To" name="To" placeholder="To" required="required" type="text" value=""/></div></div><div class="fieldgroupField"><a class="stoppicker" data-stopfield-id="SectorSearchForm_Form_To" data-title="Travelling to" href="#" title="Choose a stop to travel to...">V</a></div></div></div></div>
# <div class="field h5input datePicker" id="Date_Travel"><label class="left" for="SectorSearchForm_Form_Date_Travel">Departure Date</label><div class="middleColumn"><input autocomplete="off" class="date text" id="SectorSearchForm_Form_Date_Travel" juiconfig='{"buttonImage":"\/assets\/reservations\/button_calender.png","buttonImageOnly":"true","dateFormat":"dd\/mm\/yy","locale":"en-GB","minDate":"+0d","showOn":"both"}' min="2013-12-06" name="Date_Travel" type="date" value="2013-12-07"/></div></div>
# <div class="field h5input datePicker" id="Date_Return"><label class="left" for="SectorSearchForm_Form_Date_Return">Return Date</label><div class="middleColumn"><input autocomplete="off" class="date text" id="SectorSearchForm_Form_Date_Return" juiconfig='{"buttonImage":"\/assets\/reservations\/button_calender.png","buttonImageOnly":"true","dateFormat":"dd\/mm\/yy","locale":"en-GB","minDate":"+0d","showOn":"both"}' name="Date_Return" type="date" value="2013-12-13"/></div></div>
# <div class="PaxComp">
# <h3 id="SectorSearchForm_Form_Pax">Passengers</h3>
# <div class="field fieldgroup nolabel" id="ADCHGA"><div class="middleColumn"><div class="fieldgroup"><div class="fieldgroupField"><label for="SectorSearchForm_Form_AD">Adult</label>
# <select class=" disctype" id="SectorSearchForm_Form_AD" name="AD"><option value="">0</option><option value="1AD">1</option><option value="2AD">2</option><option value="3AD">3</option><option value="4AD">4</option><option value="5AD">5</option><option value="6AD">6</option><option value="7AD">7</option><option value="8AD">8</option><option value="9AD">9</option><option value="10AD">10</option></select></div><div class="fieldgroupField"><label for="SectorSearchForm_Form_CH">Child (3-12 yrs)</label>
# <select class=" disctype" id="SectorSearchForm_Form_CH" name="CH"><option value="">0</option><option value="1CH">1</option><option value="2CH">2</option><option value="3CH">3</option><option value="4CH">4</option><option value="5CH">5</option><option value="6CH">6</option><option value="7CH">7</option><option value="8CH">8</option><option value="9CH">9</option><option value="10CH">10</option></select></div><div class="fieldgroupField"><label for="SectorSearchForm_Form_GA">Golden Age (60+)</label>
# <select class=" disctype" id="SectorSearchForm_Form_GA" name="GA"><option value="">0</option><option value="1GA">1</option><option value="2GA">2</option><option value="3GA">3</option><option value="4GA">4</option><option value="5GA">5</option><option value="6GA">6</option><option value="7GA">7</option><option value="8GA">8</option><option value="9GA">9</option><option value="10GA">10</option></select></div></div></div></div>
# <p class="ShowDiscTypes">Other fare types </p>
# <div class="field fieldgroup extraPaxTypes nolabel" id="STBPIN"><div class="middleColumn"><div class="fieldgroup"><div class="fieldgroupField"><label for="SectorSearchForm_Form_ST">Student (13+)</label>
# <select class=" disctype" id="SectorSearchForm_Form_ST" name="ST"><option value="">0</option><option value="1ST">1</option><option value="2ST">2</option><option value="3ST">3</option><option value="4ST">4</option><option value="5ST">5</option><option value="6ST">6</option><option value="7ST">7</option><option value="8ST">8</option><option value="9ST">9</option><option value="10ST">10</option></select></div><div class="fieldgroupField"><label for="SectorSearchForm_Form_BP">Backpacker (Valid ID)</label>
# <select class=" disctype" id="SectorSearchForm_Form_BP" name="BP"><option value="">0</option><option value="1BP">1</option><option value="2BP">2</option><option value="3BP">3</option><option value="4BP">4</option><option value="5BP">5</option><option value="6BP">6</option><option value="7BP">7</option><option value="8BP">8</option><option value="9BP">9</option><option value="10BP">10</option></select></div><div class="fieldgroupField"><label for="SectorSearchForm_Form_IN">Infant (0-2 yrs no seat)</label>
# <select class=" disctype" id="SectorSearchForm_Form_IN" name="IN"><option value="">0</option><option value="1IN">1</option><option value="2IN">2</option><option value="3IN">3</option><option value="4IN">4</option><option value="5IN">5</option><option value="6IN">6</option><option value="7IN">7</option><option value="8IN">8</option><option value="9IN">9</option><option value="10IN">10</option></select></div></div></div></div>
# </div>
# <div class="field formaction " id="action_search"><label class="left" for="SectorSearchForm_Form_action_search">Search</label><div class="middleColumn"><input class="action " id="SectorSearchForm_Form_action_search" name="action_search" title="Search" type="submit" value="Search"/></div></div>
# <div id="stoppickerdialog">
# <ul>
# <li><a href="#stoppickerdialog-main">Main Stops</a></li>
# <li><a href="#stoppickerdialog-ni">North Island All Stops</a></li>
# <li><a href="#stoppickerdialog-si">South Island All Stops</a></li>
# </ul>
# <div id="stoppickerdialog-main">
# <div class="stoppickerdialog-col leftcol">
# <h3 title="Most Popular stops in the North Island">North Island </h3>
# <a data-stop-code="PIH" title="Maritime Building, Adjacent Wharf">Paihia</a>
# <a data-stop-code="AKL" title="Sky City Coach Terminal, 102 Hobson Street">Auckland</a>
# <a data-stop-code="AIR" title="Bus Stop 2008 International Terminal, Ray Emery Drive.">Auckland International Airport</a>
# <a data-stop-code="MNK" title="Leyton Way near foodcourt">Manukau City</a>
# <a data-stop-code="HLZ" title="Hamilton Transport Centre, Cnr Bryce &amp; Anglesea, Platforms A - D.">Hamilton</a>
# <a data-stop-code="ROT" title="Tourism Rotorua, 1167 Fenton Street">Rotorua</a>
# <a data-stop-code="TUO" title="Taupo Travel Centre, 16 Gascoigne Street">Taupo</a>
# <a data-stop-code="GIS" title="Outside Gisborne I-Site, 209 Grey Street">Gisborne</a>
# <a data-stop-code="NPE" title="135 Dalton St (Nearest Intersection - Station Street)">Napier</a>
# <a data-stop-code="NPL" title="19 Ariki Street, New Plymouth">New Plymouth</a>
# <a data-stop-code="PMR" title="Travel Centre Corner Pitt &amp; Main Streets">Palmerston Nth</a>
# <a data-stop-code="WLG" title="Railway Station, Platform 9">Wellington</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <h3 title="Most Popular stops in the South Island">South Island </h3>
# <a data-stop-code="PCN" title="Outside Main Entrance of Interislander Ferry Terminal">Picton</a>
# <a data-stop-code="NSN" title="Outside Travel Centre, 27 Bridge Street">Nelson</a>
# <a data-stop-code="GRM" title="Greymouth Railway Station, 164 MacKay St">Greymouth</a>
# <a data-stop-code="CHC" title="118 Bealey Ave (between Colombo St and Durham St intersections)">Christchurch</a>
# <a data-stop-code="DUD" title="Ritchies/InterCity Travel, 7 Halsey Street, near the corner of Sturdee Street">Dunedin</a>
# <a data-stop-code="ZQN" title="Athol Street in the middle of the car park">Queenstown</a>
# <a data-stop-code="WHO" title="Franz Josef Bus Stop, Main Road">Franz Josef</a>
# <a data-stop-code="MFN" title="Front Entrance of Visitors Centre, Milford Wharf">Milford Sound</a>
# <a data-stop-code="IVC" title="Invercargill Information Centre Car Park, 108 Gala Street">Invercargill</a>
# </div>
# </div>
# <div id="stoppickerdialog-ni">
# <div class="stoppickerdialog-letter">
# <h3>A</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="ABF" href="#">Aberfeldy</a>
# <a data-stop-code="AHT" href="#">Ahititi Turn Off</a>
# <a data-stop-code="AKO" href="#">Akoranga (Auckland)</a>
# <a data-stop-code="ALY" href="#">Albany (Auckland)</a>
# <a data-stop-code="ACL" href="#">Anchor Lodge Backpackers (Coromandel)</a>
# <a data-stop-code="ASH" href="#">Ashhurst</a>
# <a data-stop-code="ATI" href="#">Atiamuri</a>
# <a data-stop-code="AKL" href="#">Auckland - Central</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="ADA" href="#">Auckland Domestic Airport</a>
# <a data-stop-code="AIR" href="#">Auckland International Airport</a>
# <a data-stop-code="AVC" href="#">Auckland Vector Arena</a>
# <a data-stop-code="AWH" href="#">Awahuri</a>
# <a data-stop-code="AWK" href="#">Awakeri</a>
# <a data-stop-code="AKN" href="#">Awakino</a>
# <a data-stop-code="AAI" href="#">Awanui</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>B</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="MMB" href="#">Bayfair</a>
# <a data-stop-code="BVW" href="#">Bayview</a>
# <a data-stop-code="BBK" href="#">Bell Block</a>
# <a data-stop-code="BOX" href="#">Bombay (Auckland)</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="BRY" href="#">Brynderwyn</a>
# <a data-stop-code="BLS" href="#">Bulls</a>
# <a data-stop-code="GBW" href="#">BW Campground (for Rhythm and Vines Festival - Gisborne)</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>C</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="CAB" href="#">Cable Bay</a>
# <a data-stop-code="CBC" href="#">Cambridge</a>
# <a data-stop-code="WPJ" href="#">Cats Pajamas Backpackers (Whitianga)</a>
# <a data-stop-code="CLV" href="#">Clive</a>
# <a data-stop-code="COP" href="#">Coopers Beach</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="COG" href="#">Coroglen</a>
# <a data-stop-code="CML" href="#">Coromandel</a>
# <a data-stop-code="CMP" href="#">Coromandel Kapanga Road</a>
# <a data-stop-code="CTB" href="#">Coromandel Town Backpackers (Coromandel)</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>D</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="DVK" href="#">Dannevirke</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="TDO" href="#">Dinos (Tokoroa)</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>E</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="EDG" href="#">Edgecumbe</a>
# <a data-stop-code="EGV" href="#">Egmont Village</a>
# <a data-stop-code="EMJ" href="#">Eight Mile Junction</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="EKT" href="#">Eketahuna</a>
# <a data-stop-code="ELT" href="#">Eltham</a>
# <a data-stop-code="ESK" href="#">Eskdale</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>F</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="FNR" href="#">Featherston</a>
# <a data-stop-code="FLG" href="#">Feilding</a>
# <a data-stop-code="FTZ" href="#">Fitzroy</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="FLT" href="#">Flat Hills Tea Rooms</a>
# <a data-stop-code="FXN" href="#">Foxton</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>G</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="GCF" href="#">Gateway Cafe (Kaiwaka)</a>
# <a data-stop-code="GIS" href="#">Gisborne</a>
# <a data-stop-code="ARP" href="#">Glenview Farm Hostel (Tangoio)</a>
# <a data-stop-code="GSP" href="#">Golden Springs</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="GTN" href="#">Greerton</a>
# <a data-stop-code="GRT" href="#">Greytown</a>
# <a data-stop-code="GUM" href="#">Gumboot Manor Restaurant Taihape</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>H</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="HLZ" href="#">Hamilton - Central</a>
# <a data-stop-code="HGT" href="#">Hangatiki</a>
# <a data-stop-code="CHW" href="#">Hannafords Wharf (Coromandel)</a>
# <a data-stop-code="HST" href="#">Hastings</a>
# <a data-stop-code="HWA" href="#">Hawera</a>
# <a data-stop-code="HKI" href="#">Hikuai</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="HKR" href="#">Hikurangi</a>
# <a data-stop-code="HLC" href="#">Hillcrest (Hamilton)</a>
# <a data-stop-code="HMT" href="#">Himatangi</a>
# <a data-stop-code="HUK" href="#">Hukerenui</a>
# <a data-stop-code="HVL" href="#">Hunterville</a>
# <a data-stop-code="HLY" href="#">Huntly</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>I</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="IGD" href="#">Inglewood</a>
# <a data-stop-code="INL" href="#">Inland Rd</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="IWT" href="#">Iwitahi</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>J</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="JVL" href="#">Johnsonville (Wellington)</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="WCJ" href="#">Juno Hall</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>K</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="KAE" href="#">Kaeo</a>
# <a data-stop-code="KHE" href="#">Kahoe</a>
# <a data-stop-code="KAI" href="#">Kai Iwi</a>
# <a data-stop-code="KOH" href="#">Kaikohe</a>
# <a data-stop-code="KAT" href="#">Kaitaia</a>
# <a data-stop-code="KWK" href="#">Kaiwaka</a>
# <a data-stop-code="KRM" href="#">Kakaramea</a>
# <a data-stop-code="KKT" href="#">Kakatahi</a>
# <a data-stop-code="KAM" href="#">Kamo</a>
# <a data-stop-code="KAR" href="#">Karapiro</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="KTK" href="#">Katikati</a>
# <a data-stop-code="KAK" href="#">Kawakawa</a>
# <a data-stop-code="KAW" href="#">Kawerau</a>
# <a data-stop-code="KER" href="#">Kerikeri</a>
# <a data-stop-code="KIH" href="#">Kihikihi</a>
# <a data-stop-code="KHK" href="#">Kohukohu</a>
# <a data-stop-code="KOP" href="#">Kopu</a>
# <a data-stop-code="KOT" href="#">Kotemaori</a>
# <a data-stop-code="KUO" href="#">Kuaotunu Turn Off</a>
# <a data-stop-code="KTR" href="#">Kutarere</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>L</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="LAL" href="#">Lake Alice</a>
# <a data-stop-code="LVN" href="#">Levin</a>
# <a data-stop-code="LFD" href="#">Lichfield</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="LIN" href="#">Linton</a>
# <a data-stop-code="LID" href="#">Lions Den</a>
# <a data-stop-code="LKM" href="#">Lower Kaimai</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>M</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="MHN" href="#">Mahoenui</a>
# <a data-stop-code="MKA" href="#">Makaraka</a>
# <a data-stop-code="MMK" href="#">Mamaku</a>
# <a data-stop-code="MNA" href="#">Mana (Wellington)</a>
# <a data-stop-code="MRT" href="#">Mana Retreat Centre</a>
# <a data-stop-code="MAA" href="#">Manaia</a>
# <a data-stop-code="MGK" href="#">Mangaweka</a>
# <a data-stop-code="MNG" href="#">Mangonui</a>
# <a data-stop-code="MNK" href="#">Manukau City (Auckland)</a>
# <a data-stop-code="MNT" href="#">Manutahi</a>
# <a data-stop-code="MKE" href="#">Manutuke</a>
# <a data-stop-code="MPU" href="#">Mapiu</a>
# <a data-stop-code="MUA" href="#">Maramarua</a>
# <a data-stop-code="MTN" href="#">Marton</a>
# <a data-stop-code="MSY" href="#">Massey University (Palmerston Nth)</a>
# <a data-stop-code="MRO" href="#">Masterton</a>
# <a data-stop-code="MKH" href="#">Matakohe</a>
# <a data-stop-code="MAM" href="#">Matamata</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="MMU" href="#">Matamau</a>
# <a data-stop-code="MTG" href="#">Matarangi Turn Off</a>
# <a data-stop-code="MWI" href="#">Matawai</a>
# <a data-stop-code="MAX" href="#">Maxwell</a>
# <a data-stop-code="MID" href="#">Midhurst</a>
# <a data-stop-code="MIS" href="#">Mission Bay (Lake Taupo)</a>
# <a data-stop-code="MOE" href="#">Moerewa</a>
# <a data-stop-code="MKU" href="#">Mokau</a>
# <a data-stop-code="MRR" href="#">Morere Hot Springs</a>
# <a data-stop-code="MOV" href="#">Morrinsville</a>
# <a data-stop-code="MPA" href="#">Motuoapa</a>
# <a data-stop-code="LTP" href="#">Motutere Bay</a>
# <a data-stop-code="MVY" href="#">Mountain Valley</a>
# <a data-stop-code="NWC" href="#">Mt Bruce National Wildlife Centre</a>
# <a data-stop-code="MMN" href="#">Mt Maunganui</a>
# <a data-stop-code="MVW" href="#">Mt View</a>
# <a data-stop-code="MRW" href="#">Muriwai</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>N</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="NPE" href="#">Napier</a>
# <a data-stop-code="NPA" href="#">Napier Airport</a>
# <a data-stop-code="NAT" href="#">National Park</a>
# <a data-stop-code="NPL" href="#">New Plymouth</a>
# <a data-stop-code="NBH" href="#">New Plymouth Boys High</a>
# <a data-stop-code="NGR" href="#">Ngarua</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="NGA" href="#">Ngaruawahia</a>
# <a data-stop-code="NON" href="#">Ngongotaha</a>
# <a data-stop-code="NBY" href="#">Normanby</a>
# <a data-stop-code="NWD" href="#">Norsewood</a>
# <a data-stop-code="NHK" href="#">Nuhaka</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>O</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="OAK" href="#">Oakleigh</a>
# <a data-stop-code="OHW" href="#">Ohaeawai</a>
# <a data-stop-code="OKN" href="#">Ohakune</a>
# <a data-stop-code="OHP" href="#">Ohaupo</a>
# <a data-stop-code="OGT" href="#">Ohingaiti</a>
# <a data-stop-code="OHE" href="#">Ohope</a>
# <a data-stop-code="OHR" href="#">Ohura Turn Off</a>
# <a data-stop-code="OKR" href="#">Okahukura</a>
# <a data-stop-code="OKF" href="#">Okere Falls</a>
# <a data-stop-code="OMP" href="#">Omapere</a>
# <a data-stop-code="WOB" href="#">On the Beach Backpackers (Whitianga)</a>
# <a data-stop-code="OGU" href="#">Ongarue Turn Off</a>
# <a data-stop-code="OPN" href="#">Opononi</a>
# <a data-stop-code="OPW" href="#">Opononi Wharf</a>
# <a data-stop-code="OYH" href="#">Opononi YHA</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="OPO" href="#">Opotiki</a>
# <a data-stop-code="OPT" href="#">Opoutere</a>
# <a data-stop-code="OPU" href="#">Opua Hill</a>
# <a data-stop-code="OKK" href="#">Orakei Korako</a>
# <a data-stop-code="OWA" href="#">Orewa (Auckland)</a>
# <a data-stop-code="OMD" href="#">Ormond</a>
# <a data-stop-code="ORT" href="#">Oruaiti</a>
# <a data-stop-code="OTI" href="#">Otaika</a>
# <a data-stop-code="OTK" href="#">Otaki</a>
# <a data-stop-code="OTN" href="#">Otane</a>
# <a data-stop-code="OTW" href="#">Otangiwai Turn-off</a>
# <a data-stop-code="OTO" href="#">Otoko (Poverty Bay)</a>
# <a data-stop-code="OKO" href="#">Otoko (Wanganui)</a>
# <a data-stop-code="OHA" href="#">Otorohanga</a>
# <a data-stop-code="OWH" href="#">Owhango</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>P</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="BBP" href="#">Pacific International Hotel Management School (Bell Block)</a>
# <a data-stop-code="PAE" href="#">Paekakariki (Wellington)</a>
# <a data-stop-code="PGR" href="#">Paengaroa</a>
# <a data-stop-code="POA" href="#">Paeroa</a>
# <a data-stop-code="PAH" href="#">Pahiatua</a>
# <a data-stop-code="PIH" href="#">Paihia (Bay of Islands)</a>
# <a data-stop-code="PMR" href="#">Palmerston North</a>
# <a data-stop-code="PAK" href="#">Papakura (Auckland)</a>
# <a data-stop-code="PPM" href="#">Papamoa</a>
# <a data-stop-code="PPR" href="#">Paparoa</a>
# <a data-stop-code="PPT" href="#">Papatoetoe (Auckland)</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="PPQ" href="#">Paraparaumu (Wellington)</a>
# <a data-stop-code="PAT" href="#">Patea</a>
# <a data-stop-code="PIO" href="#">Piopio</a>
# <a data-stop-code="PIK" href="#">Piriaka</a>
# <a data-stop-code="PLM" href="#">Plimmerton (Wellington)</a>
# <a data-stop-code="POK" href="#">Pokeno (Auckland)</a>
# <a data-stop-code="PRO" href="#">Porirua (Wellington)</a>
# <a data-stop-code="PUH" href="#">Puhoi</a>
# <a data-stop-code="PKB" href="#">Pukerua Bay (Wellington)</a>
# <a data-stop-code="PUT" href="#">Putaruru</a>
# <a data-stop-code="PTR" href="#">Putorino</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>R</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="RAE" href="#">Raetihi</a>
# <a data-stop-code="RSP" href="#">Rainbow Springs (Rotorua)</a>
# <a data-stop-code="RRR" href="#">Rangiriri</a>
# <a data-stop-code="RGT" href="#">Rangitaiki</a>
# <a data-stop-code="RAN" href="#">Ratana Turn Off</a>
# <a data-stop-code="RPG" href="#">Raupunga</a>
# <a data-stop-code="RRM" href="#">Raurimu</a>
# <a data-stop-code="REP" href="#">Reporoa Turn Off</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="RAV" href="#">Rhythm &amp; Vines Festival Entrance (Gisborne)</a>
# <a data-stop-code="RTI" href="#">Rotoiti</a>
# <a data-stop-code="ROM" href="#">Rotoma</a>
# <a data-stop-code="ROT" href="#">Rotorua</a>
# <a data-stop-code="ROA" href="#">Rotorua Airport</a>
# <a data-stop-code="RAK" href="#">Ruakaka</a>
# <a data-stop-code="RKH" href="#">Rukuhia</a>
# <a data-stop-code="RUS" href="#">Russell (Bay of Islands)</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>S</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="SAN" href="#">Sanson</a>
# <a data-stop-code="SBT" href="#">Sea Breeze Holiday Park</a>
# <a data-stop-code="SHN" href="#">Shannon</a>
# <a data-stop-code="SHP" href="#">SheepWorld (near Warkworth)</a>
# <a data-stop-code="SKG" href="#">Skyline Gondola (Rotorua)</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="SFM" href="#">St Marys Diocesan School (Taranaki)</a>
# <a data-stop-code="SPC" href="#">St Peters School (Cambridge)</a>
# <a data-stop-code="SFD" href="#">Stratford</a>
# <a data-stop-code="TMS" href="#">Sunkist Backpackers Lodge (Thames)</a>
# <a data-stop-code="SYC" href="#">Sycamore Lodge (Gisborne)</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>T</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="TPE" href="#">Taihape</a>
# <a data-stop-code="TPA" href="#">Taipa</a>
# <a data-stop-code="TRU" href="#">Tairua</a>
# <a data-stop-code="TKP" href="#">Takapau</a>
# <a data-stop-code="TIO" href="#">Tangoio</a>
# <a data-stop-code="TGN" href="#">Tangowahine</a>
# <a data-stop-code="TPP" href="#">Tapapa</a>
# <a data-stop-code="TAP" href="#">Tapu</a>
# <a data-stop-code="TRW" href="#">Tarawera</a>
# <a data-stop-code="TAR" href="#">Tariki</a>
# <a data-stop-code="TMN" href="#">Taumarunui</a>
# <a data-stop-code="TPR" href="#">Taupiri</a>
# <a data-stop-code="TUO" href="#">Taupo</a>
# <a data-stop-code="TRG" href="#">Tauranga</a>
# <a data-stop-code="TUR" href="#">Tauriko</a>
# <a data-stop-code="TRH" href="#">Te Aroha</a>
# <a data-stop-code="TUT" href="#">Te Aute</a>
# <a data-stop-code="TAW" href="#">Te Awamutu</a>
# <a data-stop-code="TEH" href="#">Te Hana</a>
# <a data-stop-code="THT" href="#">Te Haroto</a>
# <a data-stop-code="THO" href="#">Te Horo (Wellington)</a>
# <a data-stop-code="TEK" href="#">Te Karaka</a>
# <a data-stop-code="TKX" href="#">Te Kawa Crossroads</a>
# <a data-stop-code="TEA" href="#">Te Kouma Turn Off</a>
# <a data-stop-code="TKT" href="#">Te Kuiti</a>
# <a data-stop-code="TEM" href="#">Te Mata</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="TNG" href="#">Te Ngae</a>
# <a data-stop-code="TPH" href="#">Te Pohue</a>
# <a data-stop-code="TOI" href="#">Te Poi</a>
# <a data-stop-code="TPI" href="#">Te Puia</a>
# <a data-stop-code="TPK" href="#">Te Puke</a>
# <a data-stop-code="TEP" href="#">Te Puna</a>
# <a data-stop-code="TPU" href="#">Te Puru</a>
# <a data-stop-code="TRI" href="#">Te Rangiita</a>
# <a data-stop-code="TRP" href="#">Te Rapa</a>
# <a data-stop-code="TKO" href="#">Te Teko</a>
# <a data-stop-code="TMZ" href="#">Thames</a>
# <a data-stop-code="TBA" href="#">The Big Apple (Otorohanga)</a>
# <a data-stop-code="CHT" href="#">The Chateau (Whakapapa)</a>
# <a data-stop-code="THB" href="#">Thorntons Bay</a>
# <a data-stop-code="TDW" href="#">Tidewater Tourist Park YHA (Coromandel)</a>
# <a data-stop-code="TIR" href="#">Tirau</a>
# <a data-stop-code="TKM" href="#">Tokomaru</a>
# <a data-stop-code="TOK" href="#">Tokoroa</a>
# <a data-stop-code="TGP" href="#">Tongaporutu</a>
# <a data-stop-code="TTN" href="#">Totara North</a>
# <a data-stop-code="TOW" href="#">Towai</a>
# <a data-stop-code="TUL" href="#">Tui Lodge</a>
# <a data-stop-code="TRK" href="#">Turakina</a>
# <a data-stop-code="TGI" href="#">Turangi</a>
# <a data-stop-code="TCV" href="#">Turtlecove Accommodation</a>
# <a data-stop-code="TTR" href="#">Tutira</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>U</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="URN" href="#">Urenui</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="URT" href="#">Uruti</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>W</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="WAH" href="#">Waihi</a>
# <a data-stop-code="WBI" href="#">Waihi Beach Island View</a>
# <a data-stop-code="WHB" href="#">Waihi Beach Reserve</a>
# <a data-stop-code="WAE" href="#">Waikanae (Wellington)</a>
# <a data-stop-code="HLU" href="#">Waikato University (Hamilton)</a>
# <a data-stop-code="WKW" href="#">Waikawau</a>
# <a data-stop-code="WMM" href="#">Waimamaku</a>
# <a data-stop-code="WTN" href="#">Waimate North</a>
# <a data-stop-code="WNW" href="#">Waingawa</a>
# <a data-stop-code="WKP" href="#">Waioeka Pa</a>
# <a data-stop-code="WIO" href="#">Waiomu</a>
# <a data-stop-code="WTP" href="#">Waiotapu</a>
# <a data-stop-code="WIR" href="#">Waiouru</a>
# <a data-stop-code="WAP" href="#">Waipapa</a>
# ...
# <a data-stop-code="TIU" href="#">Timaru</a>
# <a data-stop-code="TIN" href="#">Tinwald</a>
# <a data-stop-code="TRM" href="#">Tiromoana</a>
# <a data-stop-code="NTM" href="#">Trailways Motor Inn</a>
# <a data-stop-code="TUM" href="#">Tua Marina</a>
# <a data-stop-code="TWZ" href="#">Twizel</a>
# </div>
# </div>
# <div class="stoppickerdialog-letter">
# <h3>W</h3>
# <div class="stoppickerdialog-col leftcol">
# <a data-stop-code="WPS" href="#">Waihi Prep School (South Island)</a>
# <a data-stop-code="WHL" href="#">Waihola</a>
# <a data-stop-code="WIK" href="#">Waikari</a>
# <a data-stop-code="WKO" href="#">Waikouaiti</a>
# <a data-stop-code="WKU" href="#">Waikuku</a>
# <a data-stop-code="WMT" href="#">Waimate</a>
# <a data-stop-code="WET" href="#">Waimate Turn Off</a>
# <a data-stop-code="WAI" href="#">Waipahi</a>
# <a data-stop-code="WPA" href="#">Waipara</a>
# <a data-stop-code="WTH" href="#">Waitahuna</a>
# <a data-stop-code="WTA" href="#">Waitati</a>
# <a data-stop-code="WKF" href="#">Wakefield</a>
# </div>
# <div class="stoppickerdialog-col rightcol">
# <a data-stop-code="WKA" href="#">Wanaka</a>
# <a data-stop-code="WRD" href="#">Ward</a>
# <a data-stop-code="WDK" href="#">Washdyke</a>
# <a data-stop-code="WSZ" href="#">Westport</a>
# <a data-stop-code="WSI" href="#">Westport i-SITE</a>
# <a data-stop-code="WWL" href="#">Westwood Lodge</a>
# <a data-stop-code="WTO" href="#">Whataroa</a>
# <a data-stop-code="WCH" href="#">Winchester</a>
# <a data-stop-code="WIN" href="#">Winton</a>
# <a data-stop-code="WDB" href="#">Woodbourne (Blenheim Airport)</a>
# <a data-stop-code="WDD" href="#">Woodend</a>
# <a data-stop-code="WDL" href="#">Woodlands</a>
# </div>
# </div>
# </div>
# </div>
# <div class="clear"><!-- --></div>
# </fieldset>
# </form>
# </div>
# <h2>Manage My Booking</h2>
# <div class="mbForm">
# <p>To amend an existing fare please enter booking reference &amp; email address.</p>
# <form action="https://www.intercity.co.nz/managebooking/ResLoginForm" class="LoginRes" enctype="application/x-www-form-urlencoded" id="ICGLoginResForm_ResLoginForm" method="post">
# <p class="message " id="ICGLoginResForm_ResLoginForm_error" style="display: none"></p>
# <fieldset>
# <div class="field CompositeField nolabel">
# <div class="field h5input " id="Email"><label class="left" for="ICGLoginResForm_ResLoginForm_Email">Email address used to book</label><div class="middleColumn"><input autocomplete="on" class="text Email" id="ICGLoginResForm_ResLoginForm_Email" name="Email" placeholder="Email" title="Email" type="email" value=""/></div></div>
# <div class="field h5input " id="PNR"><label class="left" for="ICGLoginResForm_ResLoginForm_PNR">Booking Reference</label><div class="middleColumn"><input autocomplete="off" class="text PNR" id="ICGLoginResForm_ResLoginForm_PNR" name="PNR" placeholder="Booking reference" title="Booking reference" type="text" value=""/></div></div>
# </div>
# <div class="clear"><!-- --></div>
# </fieldset>
# <div class="Actions">
# <input class="action Login" id="ICGLoginResForm_ResLoginForm_action_loginRes" name="action_loginRes" title="Login" type="submit" value="Login"/>
# </div>
# </form>
# </div>
# <h2>Got a Pass? Book Your Travel Here</h2>
# <div class="passForm">
# <p>Enter your pass number &amp; access code below to book travel &amp; manage your pass.</p>
# <form action="https://www.intercity.co.nz/managebooking/PassLoginForm" class="LoginPass" enctype="application/x-www-form-urlencoded" id="ICGLoginPassForm_PassLoginForm" method="post">
# <p class="message " id="ICGLoginPassForm_PassLoginForm_error" style="display: none"></p>
# <fieldset>
# <div class="field CompositeField nolabel">
# <div class="field h5input " id="PassNo"><label class="left" for="ICGLoginPassForm_PassLoginForm_PassNo">Pass Number</label><div class="middleColumn"><input autocomplete="off" class="text PassNo" id="ICGLoginPassForm_PassLoginForm_PassNo" name="PassNo" placeholder="Pass Number" title="Pass Number" type="text" value=""/></div></div>
# <div class="field h5input " id="AccessCode"><label class="left" for="ICGLoginPassForm_PassLoginForm_AccessCode">Access Code</label><div class="middleColumn"><input autocomplete="off" class="text PassAccess" id="ICGLoginPassForm_PassLoginForm_AccessCode" name="AccessCode" placeholder="Access Code" title="Access Code" type="text" value=""/></div></div>
# </div>
# <div class="clear"><!-- --></div>
# </fieldset>
# <div class="Actions">
# <input class="action Login" id="ICGLoginPassForm_PassLoginForm_action_loginPass" name="action_loginPass" title="Login" type="submit" value="Login"/>
# </div>
# </form>
# </div>
# <h2>Freeway Club Member? Login Here</h2>
# <div class="mbForm clubForm">
# <p>Enter your Freeway number &amp; password below to manage your bookings.</p>
# <form action="https://www.intercity.co.nz/managebooking/ClubMemberLoginForm" class="LoginClub" enctype="application/x-www-form-urlencoded" id="ICGLoginClubForm_ClubMemberLoginForm" method="post">
# <p class="message " id="ICGLoginClubForm_ClubMemberLoginForm_error" style="display: none"></p>
# <fieldset>
# <div class="field CompositeField nolabel">
# <div class="field h5input " id="ClubMemberCode"><label class="left" for="ICGLoginClubForm_ClubMemberLoginForm_ClubMemberCode">Freeway Number</label><div class="middleColumn"><input autocomplete="off" class="text CmbCode" id="ICGLoginClubForm_ClubMemberLoginForm_ClubMemberCode" name="ClubMemberCode" placeholder="Freeway Number" title="Freeway Number" type="text" value=""/></div></div>
# <div class="field h5input " id="Password"><label class="left" for="ICGLoginClubForm_ClubMemberLoginForm_Password">Password</label><div class="middleColumn"><input autocomplete="off" class="text Password" id="ICGLoginClubForm_ClubMemberLoginForm_Password" name="Password" placeholder="Password" title="Password" type="password" value=""/></div></div>
# </div>
# <div class="clear"><!-- --></div>
# </fieldset>
# <div class="Actions">
# <input class="action Login" id="ICGLoginClubForm_ClubMemberLoginForm_action_loginClub" name="action_loginClub" title="Login" type="submit" value="Login"/>
# </div>
# </form>
# </div>
# </div>
# <div id="Hitwise" style="text-align: center;">
# </div>
# </div>
# <div class="fourteen columns last">
# <div id="HomePage">
# <div class="new-slideshow" id="slideshow">
# <ul class="slideshow-nav">
# <li data-id="743">1</li><li data-id="969">2</li><li data-id="973">3</li>
# </ul>
# <div class="slideshow-slides">
# <div class="slideshow-slide first" data-id="743">
# <img alt="Ferry combo passes" class="first image" height="288" src="/assets/intercity12/Promo-Pages/ic_interislander_slider.jpg" width="700"/>
# <a href="/bus-and-ferry-combos/" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - ferrycombos']);">
# <div class="slideshow-text">
# <h1>Buy bus and ferry combos from <span class="price-highlight">$95*</span></h1>
# <p>Combine InterCity bus trips and Interislander passenger ferry trips on our new combo passes</p>
# <div class="grey-btn">Find Out More</div>
# </div>
# </a>
# </div>
# <div class="slideshow-slide " data-id="969">
# <img alt="" class=" image" height="288" src="/assets/intercity12/slideshow/dollarfares-slider.jpg" width="700"/>
# <a href="#" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - $1fare']);">
# <div class="slideshow-text">
# <h1>$1* fares with InterCity</h1>
# <p>Everyone loves a bargain!  <br/><br/>And we've got at least one $1* fare available on each and every InterCity® bus service. <br/><br/>*+ Booking Fee.</p>
# <!-- <div class="grey-btn">Find tours now</div> -->
# </div>
# </a>
# </div>
# <div class="slideshow-slide " data-id="973">
# <img alt="" class="last image" height="288" src="/assets/intercity12/slideshow/passes-slider.jpg" width="700"/>
# <a href="/passes/flexi-options" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - flexiOptions']);">
# <div class="slideshow-text">
# <h1>NZ's National Bus Passes</h1>
# <p>See more of New Zealand! Travel on NZ's largest national network with one of our flexible bus pass options.</p>
# <div class="grey-btn">Search Passes Now</div>
# </div>
# </a>
# </div>
# </div>
# </div>
# <div class="twenty columns"></div>
# <div class="row">
# <div class=" promo ten columns ">
# <div class="content-box ">
# <p class="content-box-tagline"><a href="/tours/" style="text-decoration:none"><span class="content-box-highlight-red"></span> Discounted tours from $105</a></p>
# <div class="content-box-thumbnail"><img alt="ic_hukajet_thumb.jpg" src="/assets/intercity12/Promo-Pages/ic_hukajet_thumb.jpg"/></div>
# <p class="content-box-description">Great value tours to Huka Falls, Milford Sound, Hobbiton and more. Seats sell fast!</p>
# <div class="content-box-textlink"><a href="/tours/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Discounted tours from $105']);">Search New Zealand Tours</a></div>
# </div>
# </div>
# <div class=" promo ten columns content-box-right">
# <div class="content-box content-box-right">
# <p class="content-box-tagline"><a href="http://www.booking.com/index.html?aid=369493" style="text-decoration:none"><span class="content-box-highlight-red"></span> Need Accommodation?</a></p>
# <div class="content-box-thumbnail"><img alt="New Zealand Accommodation" src="/assets/intercity12/main/bus-and-beds.jpg"/></div>
# <p class="content-box-description">Search &amp; book NZ’s biggest range of accommodation with Best Rates Guaranteed.</p>
# <div class="content-box-textlink"><a href="http://www.booking.com/index.html?aid=369493" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Need Accommodation?']);">Search accommodation now</a></div>
# </div>
# </div>
# <div class=" promo ten columns ">
# <div class="content-box ">
# <p class="content-box-tagline"><a href="travel-info/timetable/" style="text-decoration:none"><span class="content-box-highlight-red"></span> Find a bus stop</a></p>
# <div class="content-box-thumbnail"><img alt="ic_bussstopsign98.jpg" src="/assets/intercity12/Promo-Pages/ic_bussstopsign98.jpg"/></div>
# <p class="content-box-description">Find bus stop locations around New Zealand and see timetable information.</p>
# <div class="content-box-textlink"><a href="travel-info/timetable/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Find a bus stop']);">Get more info</a></div>
# </div>
# </div>
# <div class=" promo ten columns content-box-right">
# <div class="content-box content-box-right">
# <p class="content-box-tagline"><a href="/bus-to-auckland-airport" style="text-decoration:none"><span class="content-box-highlight-red"></span> Auckland Airport Connections</a></p>
# <div class="content-box-thumbnail"><img alt="ic_airport_bus.jpg" src="/assets/intercity12/main/ic_airport_bus.jpg"/></div>
# <p class="content-box-description">View connections to and from the airport from locations across the North Island.</p>
# <div class="content-box-textlink"><a href="/bus-to-auckland-airport" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Auckland Airport Connections']);">View Airport Connections</a></div>
# </div>
# </div>
# <div class=" promo ten columns ">
# <div class="content-box ">
# <p class="content-box-tagline"><a href="http://www.milford-sound.co.nz/" style="text-decoration:none"><span class="content-box-highlight-red"></span> Featured Destination - Milford Sound</a></p>
# <div class="content-box-thumbnail"><img alt="milford sound promo tile" src="/assets/intercity12/main/milford-sound-promo-tile.jpg"/></div>
# <p class="content-box-description">Take an unforgettable journey into this breathtaking region - a must-see destination.</p>
# <div class="content-box-textlink"><a href="http://www.milford-sound.co.nz/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Featured Destination - Milford Sound']);">Visit milford-sound.co.nz</a></div>
# </div>
# </div>
# <div class=" promo ten columns content-box-right">
# <div class="content-box content-box-right">
# <p class="content-box-tagline"><a href="/passes/flexi-options/" style="text-decoration:none"><span class="content-box-highlight-red"></span> NZ Bus Passes from just $39</a></p>
# <div class="content-box-thumbnail"><img alt="backpacker new zealand" src="/assets/Uploads/backpacker-new-zealand.jpg"/></div>
# <p class="content-box-description">Looking for a way to explore NZ? InterCity passes offer great savings on travel.</p>
# <div class="content-box-textlink"><a href="/passes/flexi-options/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'NZ Bus Passes from just $39']);">Search NZ Bus Passes</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="row" id="Footer">
# <div class="footer-content twenty columns">
# <div class="footer-column left">
# <h3>About InterCity</h3>
# <p><a href="/about-us">About Us</a> . <a href="/about-us/media-releases">Media</a>. <a href="/privacy-policy">Privacy</a> . <a href="booking-agents/">Booking Agents</a> . <a href="/whatsnew/">What's New</a> . <a href="/help/">Site Map</a> </p>
# <h3>Get Info</h3>
# <p><a href="/managebooking/" onclick="_gaq.push(['_trackEvent', 'Footer Link', 'Go To', 'Manage my Booking']);">Manage my booking</a> . <a href="/frequently-asked-questions/">FAQs</a> . <a href="/delays-and-cancellations/">Delays &amp; Disruptions</a> . <a href="/terms-and-conditions">Terms &amp; Conditions</a></p>
# <h3>Get Onboard</h3>
# <p><a href="/rewards">Freeway Login</a> . <a href="/about-us/affiliate/">Affiliate Programme</a> . <a href="/feedback">Feedback</a> . <a href="/feedback">Contact Us</a></p>
# </div>
# <div class="footer-column right">
# <h3>Tours</h3>
# <p> <a href="/tours">Tours</a> . <a href="http://www.greatsights.co.nz/" target="blank">Great Sights</a> . <a href="http://www.awesomenz.com/" target="blank">Awesome NZ</a> . <a href="http://www.dolphincruises.co.nz/" target="blank">Dolphin Cruise</a></p>
# <h3>Passes</h3>
# <p><a href="http://flexipass.intercity.co.nz/" target="blank">Flexipass</a> . <a href="http://www.flexitrips.co.nz" target="blank">Flexitrips</a> . <a href="http://travelpass.intercity.co.nz">TravelPass</a> . <a href="/passes/intercity-commuter/">InterCity Commuter</a> . <a href="/passes/student-bus-pass/">Student Pass</a></p>
# <h3>Connect</h3>
# <div class="social-media">
# <p><a href="http://www.facebook.com/intercity.coachlines" target="blank"><img alt="Facebook" class="left" height="27" src="assets/intercity12/main/ic_facebookIcon.png" title="" width="27"/></a><a href="http://www.twitter.com/InterCityBUS" target="blank"><img alt="Twitter" class="left" height="27" src="assets/intercity12/main/ic_twitterIcon.png" title="" width="26"/></a><a href="http://plus.google.com/100713504200361907253" target="blank"><img alt="Google+" class="left" height="27" src="assets/intercity12/main/ic_googleplusIcon.png" title="" width="27"/></a>Copyright © 2012 InterCity Group (NZ) Ltd.</p>
# </div>
# </div>
# </div>
# </div>
# <script src="http://www.intercity.co.nz/assets/intercity12/js/jslibs.js?m=1386109965" type="text/javascript"></script><script src="http://www.intercity.co.nz/assets/intercity12/js/global.js?m=1386109965" type="text/javascript"></script><script src="http://www.intercity.co.nz/mysite/javascript/iealert.min.js?m=1369093915" type="text/javascript"></script><script src="http://www.intercity.co.nz/mysite/javascript/page.js?m=1376345437" type="text/javascript"></script><script src="http://www.intercity.co.nz/assets/intercity12/js/intercity12.js?m=1386109965" type="text/javascript"></script><script src="http://www.intercity.co.nz/themes/intercity12/javascripts/theme.js?m=1385067882" type="text/javascript"></script><script src="http://www.intercity.co.nz/bookingelements/javascript/SectorSearchForm.js?m=1368669239" type="text/javascript"></script><script src="http://www.intercity.co.nz/assets/_stops/stop_autocomplete_field.js?m=1383165215" type="text/javascript"></script><script src="http://www.intercity.co.nz/bookingelements/javascript/StopPickerField.js?m=1345523838" type="text/javascript"></script><script type="text/javascript">//<![CDATA[
# intercity.stopautocomplete('SectorSearchForm_Form_From');
#
# //]]></script><script type="text/javascript">//<![CDATA[
# intercity.stopautocomplete('SectorSearchForm_Form_To');
#
# //]]></script></body>
# </html>
# >

# %%
print loadSite.url
# Out:
# http://www.intercity.co.nz/

# %%
beaut = BeautifulSoup(loadSite)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-c6fc29c577a6> in <module>()
# ----> 1 beaut = BeautifulSoup(loadSite)
#
# /usr/lib/python2.7/dist-packages/bs4/__init__.pyc in __init__(self, markup, features, builder, parse_only, from_encoding, **kwargs)
#     167         (self.markup, self.original_encoding, self.declared_html_encoding,
#     168          self.contains_replacement_characters) = (
# --> 169             self.builder.prepare_markup(markup, from_encoding))
#     170
#     171         try:
#
# /usr/lib/python2.7/dist-packages/bs4/builder/_lxml.pyc in prepare_markup(self, markup, user_specified_encoding, document_declared_encoding)
#      70
#      71         try_encodings = [user_specified_encoding, document_declared_encoding]
# ---> 72         dammit = UnicodeDammit(markup, try_encodings, is_html=True)
#      73         return (dammit.markup, dammit.original_encoding,
#      74                 dammit.declared_html_encoding,
#
# /usr/lib/python2.7/dist-packages/bs4/dammit.pyc in __init__(self, markup, override_encodings, smart_quotes_to, is_html)
#     201
#     202         new_markup, document_encoding, sniffed_encoding = \
# --> 203             self._detectEncoding(markup, is_html)
#     204         self.markup = new_markup
#     205
#
# /usr/lib/python2.7/dist-packages/bs4/dammit.pyc in _detectEncoding(self, xml_data, is_html)
#     370         except:
#     371             xml_encoding_match = None
# --> 372         xml_encoding_match = xml_encoding_re.match(xml_data)
#     373         if not xml_encoding_match and is_html:
#     374             xml_encoding_match = html_meta_re.search(xml_data)
#
# TypeError: expected string or buffer

# %%
reTweetz = open('testing.txt', 'w')
reTweetz.write('Fixed request')
reTweetz.close()

# %%
daTweetz = open('testing.txt', 'r')

daTweetz.read()
# Out:
# 'Fixed request'

# %%
print diemLink
# Out:
# None

# %%
for data in loadSite:
    mixData = BeautifulSoup(data)
    diemLink = mixData.a
    print diemLink
    seioLink = mixData.findAll('a')
    print seioLink
    print(mixData.get_text())
# Out:
# None
# []
#
#
#
#
# None
# []
# w.intercity.co.nz/">
#
# InterCity // Bus Ticket
# None
# []
# s From $1 // NZâs National Network // Bus Pass
#
#
#
# None
# []
# ar bus network. Bus tickets from $1 (+booking fee). Bus passes for backpackers. Book online - no credit card required. " />
# None
# []
# name="keywords" content="" />
#
#
#
# None
# []
#
# 					/*#Header {background: transparent url('/assets/intercity/main/header5.jpg') no-repeat !important;}*/
# 				<
# None
# []
# /style>
#
#
#
#
#
#
#
# None
# []
# ipt/lib/jquery-ui-themes/custom/jquery-ui-1.8.21.custom.css?m=1369093914" />
#
# None
# []
# /www.intercity.co.nz/mysite/javascript/lib/jquery-fancybox/jquery.fancybox-1.3.1.css?m=1369093915" />
#
# None
# []
# e="text/css" href="http://www.intercity.co.nz/mysite/css/iealert/style.css?m=1369093914" />
#
# None
# []
# s" href="http://www.intercity.co.nz/mysite/css/common.css?m=1369093914" />
#
# None
# []
# ww.intercity.co.nz/themes/intercity12/css/reservations.css?m=1386294423" />
#
# None
# []
# www.intercity.co.nz/themes/intercity12/css/app.css?m=1386294417" />
#
# None
# []
# rcity.co.nz/themes/intercity12/css/typography.css?m=1386294418" />
#
# None
# []
# city.co.nz/bookingelements/css/StopPickerField.css?m=1339120101" />
#
# var _gaq = _gaq || [];
# _ga
# None
# []
# q.push(['_setAccount', 'UA-1266228-1']);
# _gaq.push(['_setDomainName', '.intercity.co.nz']);
# _gaq.push(['_setAllowLinker', true
# None
# []
# ]);
# _gaq.push(['_trackPageview']);
#
# (function() {
# 	var ga = document.createElement('script');
# 	ga.type = 'text/javascript'
# None
# []
# ;
# 	ga.async = true;
# 	ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.co
# None
# []
# m/ga.js';
# 	var s = document.getElementsByTagName('script')[0];
# 	s.parentNode.insertBefore(ga, s);
# })();
#
# (function recordO
# None
# []
# utboundLink(link, category, action) {
#   try {
#     var myTracker=_gat._getTrackerByName();
#     _gaq.push(['myTracker._trackEve
# None
# []
# nt', ' + category + ', ' + action + ']);
#     setTimeout('document.location = "' + link.href + '"', 100)
#   }catch(err){}
# })();
# None
# []
#
#
# <a class="logo l" href="/"></a>
# [<a class="logo l" href="/"></a>]
# lass="twenty columns">
#
#
#
#
# None
# []
# eft" onClick="_gaq.push(['_trackEvent', 'HeaderLogo', 'Back Home', 'InterCity Logo']);">
# None
# []
# o.png" alt="iclogo.png" />
# 	Low fares, everywhere, everyday.
#
# <a href="/info/about-us/">About Us</a>
# [<a href="/info/about-us/">About Us</a>, <a href="" id="feedback"></a>]
# a href="http://m.intercity.co.nz">Mobile Site
# About Us
#
# None
# []
# ="/contact-us">Contact Us
#
#
#
# None
# []
# row">
#
#
#
#
# <a class="current" href="/">H</a>
# [<a class="current" href="/">H</a>, <a class="flyout-toggle" href="/#"><span></span></a>]
# H
#
#
# <a class="flyout-toggle" href="/#"><span></span></a>
# [<a class="flyout-toggle" href="/#"><span></span></a>]
# s="has-flyout">
#
# 						Travel Info
#
# None
# []
# pan>
#
#
#
# <a href="/travel-info/route-map/">View the route map</a>
# [<a href="/travel-info/route-map/">View the route map</a>]
# View the route map
#
# <a href="/travel-info/north-island-booking-agents/">Booking Agents</a>
# [<a href="/travel-info/north-island-booking-agents/">Booking Agents</a>]
# class="sub-menu-block">
#
# Booking Agents
# None
# []
# /a>
#
#
#
#
#
#
#
#
# <a href="/travel-info/child-fares/">Child Fares </a>
# [<a href="/travel-info/child-fares/">Child Fares </a>]
# Child Fares
#
# <a href="/travel-info/frequently-asked-questions/">FAQ's</a>
# [<a href="/travel-info/frequently-asked-questions/">FAQ's</a>]
# lass="sub-menu-block">
#
# FAQ's
#
# None
# []
#
#
# None
# []
# href="/travel-info/delays-and-disruptions/">Delays / Disruptions
#
#
#
#
# 							-->
#
# None
# []
#
#
# <a href="/timetable">Tim</a>
# [<a href="/timetable">Tim</a>]
# izedimage2525-timetable_icon2.png" alt=">" width="25" height="25" title=""/> Timetables
# Tim
# <a href="/route-map">Route Map</a>
# [<a href="/route-map">Route Map</a>]
# etables and Bus Stops
# Route Map
#
#
# None
# []
# assets/intercity12/main/ICONSMENU/_resampled/resizedimage2525-changes_icon2.png" alt=">" width="25" height="25" title=""/> Ch
# <a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a>
# [<a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a>, <a>Â </a>]
# anges & Refunds
# Changes, Cancellations & Refunds
# Â
# None
# []
#
# <a href="/getting-a-1-fare">Getting a $1 Fare</a>
# [<a href="/getting-a-1-fare">Getting a $1 Fare</a>]
# ng" alt=">" width="28" height="28" title=""/> Fares & Bookings
# Getting a $1 Fare
# None
# []
#
# None
# []
# Student,Backpacker & Senior Fares
#
#
#
# <a href=""></a>
# [<a href=""></a>]
# SMENU/_resampled/resizedimage2525-luggage_icon2.png" alt=">" width="25" height="25" title=""/> Luggage
#
# <a href="/oversized-items">Oversized Items/Bicycles</a>
# [<a href="/oversized-items">Oversized Items/Bicycles</a>]
# /carryon-checked-luggage">Carry on and Checked Luggage
# Oversized Items/Bicycles
# None
# []
# Â
#
#
# <a href="/north-island-booking-agents"></a>
# [<a href="/north-island-booking-agents"></a>]
# agents_icon2.png" alt=">" width="25" height="25" title=""/> Booking Agents
#
# <a href="/south-island-booking-agents/">Find a South Island Agent</a>
# [<a href="/south-island-booking-agents/">Find a South Island Agent</a>]
# /">Find a North Island Agent
# Find a South Island Agent
#
# None
# []
#
#
# <a href="/delays-and-disruptions">View Current Disr</a>
# [<a href="/delays-and-disruptions">View Current Disr</a>]
# gt;" width="25" height="25" title=""/> Delays & Disruptions
# View Current Disr
# None
# []
# uptions
# Â
#
#
# <a hr=""></a>
# [<a hr=""></a>]
# esizedimage2525-special_assistance_icon2.png" alt=">" width="25" height="25" title=""/> Special Assistance
#
# None
# []
# ef="/special-assistance">Special Needs and Assistance
#
#
#
# None
# []
# city12/main/ICONSMENU/_resampled/resizedimage2525-children_icon2.png" alt=">" width="25" height="25" title=""/> Travelling wi
# <a href="/child-fares">Child Fares</a>
# [<a href="/child-fares">Child Fares</a>, <a href="http://www.intercity.co.nz/assets/file/interci"></a>]
# th Children
# Child Fares
#
# <a href="/frequently-asked-ques"></a>
# [<a href="/frequently-asked-ques"></a>]
# tyunaccompanied.pdf">Unaccompanied Minor Form
#
#
# None
# []
# tions/">
#
# <a href="/group-bookings">
# <h></h></a>
# [<a href="/group-bookings">
# <h></h></a>]
# ="25" title=""/> Frequently Asked Questions
#
#
#
# None
# []
# 2>
# None
# []
# "25" title=""/> Group Bookings
#
#
#
#
#
#
#
# <a class="flyout-toggle" href="/#"><span></span></a>
# [<a class="flyout-toggle" href="/#"><span></span></a>]
# Manage Booking
#
#
# None
# []
# ul class="flyout">
#
# None
# []
# ng/change-cancel-a-booking/">How to Modify/Cancel a Booking
#
#
#
#
# 							-->
#
# None
# []
#
#
# <a href="/change-cancel-a-booking">How To Change/Cancel a Booking</a>
# [<a href="/change-cancel-a-booking">How To Change/Cancel a Booking</a>, <a></a>]
# alt=">"/> Manage your booking
# How To Change/Cancel a Booking
#
# None
# []
# href="/managebooking">Login to Manage a booking
#
#
#
# None
# []
# /main/ICONSMENU/_resampled/resizedimage2525-changes_icon2.png" alt=">" width="25" height="25"/> Changes & Refunds
#
# <a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a>
# [<a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a>]
# l>Changes, Cancellations & Refunds
#
# <a cla="" href="/#"></a>
# [<a cla="" href="/#"></a>]
# i>
#
#
# Frequent Travellers
#
# None
# []
# ss="flyout-toggle">
#
#
# <a href="/frequent-travellers/how-it-works/">How it Works</a>
# [<a href="/frequent-travellers/how-it-works/">How it Works</a>]
#
# How it Works
#
#
# None
# []
#
#
# None
# []
# -club-freeway/">Join Club Freeway
#
#
#
#
#
#
# <a href="/frequent-travellers/forgotpwd/">Club Password Reset</a>
# [<a href="/frequent-travellers/forgotpwd/">Club Password Reset</a>]
# ">
#
# Club Password Reset
#
# None
# []
#
#
# None
# []
# city12/main/ICONSMENU/_resampled/resizedimage2828-rewards_icon2.png" alt=">" width="28" height="28" title=""/> FREEWAY Travel
# <a href="/how-it-works">How it works </a>
# [<a href="/how-it-works">How it works </a>, <a href="/about-earning-free-travel">Earning FREE Trave</a>]
# Rewards
# How it works
# Earning FREE Trave
# <a href="/join-club-freeway">Join FREEWAY</a>
# [<a href="/join-club-freeway">Join FREEWAY</a>]
# l
# Join FREEWAY
#
#
# None
# []
# tercity12/main/ICONSMENU/_resampled/resizedimage2525-freewaymember_icon2.png" alt=">" width="25" height="25" title=""/> FREEW
# <a href="/rewards">Login to FREEWAY</a>
# [<a href="/rewards">Login to FREEWAY</a>, <a href="/clubpasswordreset">Forgotten Password?</a>]
# AY Members
# Login to FREEWAY
# Forgotten Password?
# None
# []
# i>
#
#
#
# <a href="/cheapas">Sign up for special offers</a>
# [<a href="/cheapas">Sign up for special offers</a>]
# on2.png" alt=">" width="28" height="28" title=""/> Cheap-as Seats
# Sign up for special offers
# None
# []
# /a>
#
#
#
#
#
#
#
# <a class="flyout-toggle" href="/#"><span></span></a>
# [<a class="flyout-toggle" href="/#"><span></span></a>]
# nu">Tours
#
#
#
# <a href="/tours/intercity-hobbiton-excursion-auckland-to-"></a>
# [<a href="/tours/intercity-hobbiton-excursion-auckland-to-"></a>]
#
#
#
# None
# []
# auckland/">Hobbiton Excursion
#
#
#
#
#
#
#
# <a href="/tours/intercity-milford-sound-tour/">Milford Sound Tour</a>
# [<a href="/tours/intercity-milford-sound-tour/">Milford Sound Tour</a>]
#
# Milford Sound Tour
#
# None
# []
#
#
# None
# []
# ity-dolphin-cruise-tour/">Dolphin Cruise Tour
#
#
#
#
#
#
# <a href="/tours/hukafalls-jet/">Hukafalls Jetboat Morning Tour (Return ex Tau</a>
# [<a href="/tours/hukafalls-jet/">Hukafalls Jetboat Morning Tour (Return ex Tau</a>]
# b-menu-block">
#
# Hukafalls Jetboat Morning Tour (Return ex Tau
# None
# []
# po)
#
#
#
#
#
#
#
#
# <a href="/tours/the-lord-of-the-rings-film-locations/">LOTR Film Locations</a>
# [<a href="/tours/the-lord-of-the-rings-film-locations/">LOTR Film Locations</a>]
# LOTR Film Locations
#
# <a href="/tours/Auckland-Morning-City-t"></a>
# [<a href="/tours/Auckland-Morning-City-t"></a>]
# /div>
#
#
#
#
# None
# []
# our/">Auckland Morning City Tour
#
#
#
#
#
#
# <a href="/tours/tamaki-maori-village-experience/">Tamaki Maori Village Evening Experience</a>
# [<a href="/tours/tamaki-maori-village-experience/">Tamaki Maori Village Evening Experience</a>]
# ">
#
# Tamaki Maori Village Evening Experience
# None
# []
#
#
# <a href="/intercity-milford-sound-tour/"><img src="/assets/intercity12/main/ICONSMENU/milford_ico" style="float:left;"/></a>
# [<a href="/intercity-milford-sound-tour/"><img src="/assets/intercity12/main/ICONSMENU/milford_ico" style="float:left;"/></a>]
# tours-sub">
# <a href="/intercity-milford-sound-"></a>
# [<a href="/intercity-milford-sound-"></a>]
# n.png" alt="Milford Sound Bus Tour" title=""/>
#
# <a href="/intercity-milford-sound-tour/"> </a>
# [<a href="/intercity-milford-sound-tour/"> </a>, <a href="/intercity-milford-sound-to"></a>]
# tour/">
# Milford Sound
#
#
# <a href="/intercity-milford-sound-tour/">Day trip from Queenstown from $119*</a>
# [<a href="/intercity-milford-sound-tour/">Day trip from Queenstown from $119*</a>]
# ur/"/>Day trip from Queenstown from $119*
#
# <a href="/intercity-hobbiton-excursion-auckland-to-auckland/"><img src="/assets/intercity1" style="float:left"/></a>
# [<a href="/intercity-hobbiton-excursion-auckland-to-auckland/"><img src="/assets/intercity1" style="float:left"/></a>]
# section tours-sub">
# None
# []
# 2/main/ICONSMENU/hobbiton_icon.png" alt="Hobbiton Movie Set Day Tour" title=""/>
#
# <a href="/intercity-hobbiton-excursion-auckland-to-auckland/">
# <h2>Hobbiton Movie Set</h2>
# </a>
# [<a href="/intercity-hobbiton-excursion-auckland-to-auckland/">
# <h2>Hobbiton Movie Set</h2>
# </a>, <a href="/intercity-hobbito"></a>]
#
# Hobbiton Movie Set
#
#
# <a href="/intercity-hobbiton-excursion-auckland-to-auckland/"></a>
# [<a href="/intercity-hobbiton-excursion-auckland-to-auckland/"></a>, <a href="/intercity-"></a>]
# n-excursion-auckland-to-auckland/">
#
# None
# []
# hobbiton-excursion-auckland-to-auckland/">Day trip from Auckland from $139*
#
#
#
# <a href="/dart-river-jet/"><img src="/assets/intercity12/main/ICONSMENU/Dart-River_icon.png" style="float:left;"/></a>
# [<a href="/dart-river-jet/"><img src="/assets/intercity12/main/ICONSMENU/Dart-River_icon.png" style="float:left;"/></a>]
# tours-sub dart">
# <a href="/dart-river-jet/">
# <h2>Dart River</h2></a>
# [<a href="/dart-river-jet/">
# <h2>Dart River</h2></a>]
# " alt="Dart River Jet Tour" title=""/>
#
# Dart River
# <a href="/dart-river-jet/"> </a>
# [<a href="/dart-river-jet/"> </a>, <a href="/dart-river-jet/"></a>, <a href="/dart-river-jet/">Dart River Jet T</a>]
# Jet
#
#
# Dart River Jet T
# <a href="/tours/waitomo-caves-tour/"></a>
# [<a href="/tours/waitomo-caves-tour/"></a>]
# our Ex Q'tn from $219*
#
#
#
# None
# []
#
#
# <a href="/tours/waitomo-caves-tour/">
# <h2>Waitomo Caves Tour</h2>
# </a>
# [<a href="/tours/waitomo-caves-tour/">
# <h2>Waitomo Caves Tour</h2>
# </a>, <a href="/t"></a>]
# iv style="float:left;" class="menu-dets">
# Waitomo Caves Tour
#
#
# <a href="/tours/waitomo-caves-tour/"></a>
# [<a href="/tours/waitomo-caves-tour/"></a>, <a href="/tours/waitomo-caves-tour/">Day trips to Wait</a>]
# ours/waitomo-caves-tour/">
# Day trips to Wait
# <a href="/intercity-dolphin-cruise-tour"></a>
# [<a href="/intercity-dolphin-cruise-tour"></a>]
# omo Caves From $139*
#
#
#
# None
# []
# /">
#
# <a href="/intercity-dolphin-cruise-tour/">
# <h2>Bay of Islands</h2>
# </a>
# [<a href="/intercity-dolphin-cruise-tour/">
# <h2>Bay of Islands</h2>
# </a>, <a href=""></a>]
# div style="float:left;" class="menu-dets">
# Bay of Islands
#
#
# <a href="/intercity-dolphin-cruise-tour/"></a>
# [<a href="/intercity-dolphin-cruise-tour/"></a>, <a href="/intercity-dolphin-cruise-tour/"></a>]
# /intercity-dolphin-cruise-tour/">
#
# <a href="/the-l"></a>
# [<a href="/the-l"></a>]
# Day trip from Auckland from $119*
#
#
#
# None
# []
# ord-of-the-rings-film-locations/">
# <a href="/the-lord-of-the-rings-film-locations/">
# <h2></h2></a>
# [<a href="/the-lord-of-the-rings-film-locations/">
# <h2></h2></a>]
# the Rings Tour" title=""/>
#
#
# <a href="/the-lord-of-the-rings-film-locations/"> </a>
# [<a href="/the-lord-of-the-rings-film-locations/"> </a>, <a href="/the-lord-of-the-rings-fi"></a>]
# LOTR Film Locations
#
#
#
# <a href="/the-lord-of-the-rings-film-locations/">Discover the films' locations in NZ</a>
# [<a href="/the-lord-of-the-rings-film-locations/">Discover the films' locations in NZ</a>]
# lm-locations/"/>Discover the films' locations in NZ
#
# <a href="/Auckland-Morning-City-tour/"><img src="/asse" style="float:left;"/></a>
# [<a href="/Auckland-Morning-City-tour/"><img src="/asse" style="float:left;"/></a>]
#
# None
# []
# ts/intercity12/main/auckland-city-sightseeing-tour-thumb.jpg" alt="Auckland City Sightseeing Tour" title=""/>
#
# <a href="/Auckland-Morning-City-tour/">
# <h2>Auckland City Tour</h2>
# </a>
# [<a href="/Auckland-Morning-City-tour/">
# <h2>Auckland City Tour</h2>
# </a>, <a href="/Auckland-Mo"></a>]
# oat:left;" class="menu-dets">
# Auckland City Tour
#
#
# <a href="/Auckland-Morning-City-tour/"></a>
# [<a href="/Auckland-Morning-City-tour/"></a>, <a href="/Auckland-Morning-City-tour/">Half day city tours f</a>]
# nring-City-tour/">
# Half day city tours f
# <a href="/hukafalls-jet/"><img style="float:left;"/></a>
# [<a href="/hukafalls-jet/"><img style="float:left;"/></a>]
# rom $39*
#
#
#
# None
# []
# src="/assets/intercity12/main/ICONSMENU/huka_icon.png" alt="Huka Jet Tour" title=""/>
#
# <a href="/hukafalls-jet/">
# <h2>Hukafalls Jet</h2>
# </a>
# [<a href="/hukafalls-jet/">
# <h2>Hukafalls Jet</h2>
# </a>, <a href="/hukafalls-jet/"> </a>, <a href="/hukafalls-jet/"></a>]
# dets">
# Hukafalls Jet
#
#
#
# <a href="/hukafalls-jet/">Daily from Taupo from $109*</a>
# [<a href="/hukafalls-jet/">Daily from Taupo from $109*</a>, <a></a>]
# >Daily from Taupo from $109*
#
# None
# []
# href="/tamaki-maori-village-experience/">
# <a href="/tamaki-maori-village-experien"></a>
# [<a href="/tamaki-maori-village-experien"></a>]
# pg" alt="Tamaki Maori Village" title=""/>
#
# <a href="/tamaki-maori-village-experience/"> </a>
# [<a href="/tamaki-maori-village-experience/"> </a>, <a href="/tamaki-maori-vill"></a>]
# ce/">
# Tamaki MÄori Village
#
#
# <a href="/tamaki-maori-village-experience/">Daily from Rotorua from $110*</a>
# [<a href="/tamaki-maori-village-experience/">Daily from Rotorua from $110*</a>]
# age-experience/"/>Daily from Rotorua from $110*
#
# None
# []
#
#
# <a class="flyout-toggle" href="/#"><span></span></a>
# [<a class="flyout-toggle" href="/#"><span></span></a>]
# pan>
#
#
#
# <a href="/passes/flexi-options/">Flexi Options</a>
# [<a href="/passes/flexi-options/">Flexi Options</a>]
# lass="sub-menu-block">
#
# Flexi Options
#
# None
# []
#
#
# None
# []
# travel-pass/">Travel Pass
#
#
#
#
#
#
#
# <a href="/passes/intercity-commuter/">InterCity Commuter</a>
# [<a href="/passes/intercity-commuter/">InterCity Commuter</a>]
#
# InterCity Commuter
#
#
# None
# []
#
#
# None
# []
# >Student Pass
#
#
#
#
# 							-->
#
# <a href="/flexi-options/"><img src="/assets/intercity12/main/ICONSMENU/flex" style="float:left;"/></a>
# [<a href="/flexi-options/"><img src="/assets/intercity12/main/ICONSMENU/flex" style="float:left;"/></a>]
# "menu-section pass-sub clearfix">
# <a href="/flexi-options/">
# <h2></h2></a>
# [<a href="/flexi-options/">
# <h2></h2></a>]
# ible.jpg" alt="New Zealand Bus Tours and Passes"/>
#
#
# <a href="/flexi-options/"> </a>
# [<a href="/flexi-options/"> </a>, <a href="/flexi-options/"></a>, <a href="/flexi-options"></a>]
# >Flexible Itinerary Options
#
#
#
# None
# []
# /">Our most popular transport passes for independent travellers.  'Travel like a local' NZ's largest Hop-on/Hop-off network.  To
# <a hre=""></a>
# [<a hre=""></a>]
# tal freedom + sightseeing & activity options.
#
#
#
# None
# []
# f="/travel-pass/">
#
# <a href="/travel-pass/">
# <h2>Fixed Itinerary Passes</h2>
# </a>
# [<a href="/travel-pass/">
# <h2>Fixed Itinerary Passes</h2>
# </a>, <a href="/travel-pass"></a>]
# iv class="menu-dets" style="float:left;">
# Fixed Itinerary Passes
#
#
# <a href="/travel-pass/"></a>
# [<a href="/travel-pass/"></a>, <a href="/travel-pass/">Pre-planned transport passes for those wanting a set itinerary tra</a>]
# /">
# Pre-planned transport passes for those wanting a set itinerary tra
# None
# []
# vel.  Choose from a range of passes including sightseeing tour options.
#
#
#
# <a href="/intercity-commuter/"><img src="/assets/intercity12/main/ICONSMENU/commuter.jp" style="float:left;"/></a>
# [<a href="/intercity-commuter/"><img src="/assets/intercity12/main/ICONSMENU/commuter.jp" style="float:left;"/></a>]
# s-sub huka clearfix">
# None
# []
# g" alt="Auckland to Hamilton Bus Pass New Zealand"/>
#
# InterCity Commuter
# <a href="/intercity-commuter/">Save up to 38%* on regular fares between Hamilton/Auckland.  Over 20 services per day be</a>
# [<a href="/intercity-commuter/">Save up to 38%* on regular fares between Hamilton/Auckland.  Over 20 services per day be</a>]
# Save up to 38%* on regular fares between Hamilton/Auckland.  Over 20 services per day be
# <a href="/student-bus-pa"></a>
# [<a href="/student-bus-pa"></a>]
# tween cities on NZ's #1 Bus Network.
#
#
#
# None
# []
# ss/">
# <a href="/student-bus-pass/">
# <h2>Student Passes</h2>
# </a>
# [<a href="/student-bus-pass/">
# <h2>Student Passes</h2>
# </a>, <a href="/student-bus"></a>]
#
# Student Passes
#
#
# <a href="/student-bus-pass/"></a>
# [<a href="/student-bus-pass/"></a>, <a href="/student-bus-pass/">Great savings for students! <br/> Passes available </a>]
# -pass/">
# Great savings for students!  Passes available
# None
# []
# for Hawke's Bay, New Plymouth and Dunedin students.
#
#
#
#
#
#
#
# <a class="link" href="http://www.booking.com/index.html?aid=369493">Accommodation</a>
# [<a class="link" href="http://www.booking.com/index.html?aid=369493">Accommodation</a>, <a></a>]
# class="has-flyout">
#
# 					Accommodation
#
# None
# []
# href="/#" class="flyout-toggle">
#
#
# None
# []
#
#
#
#
# None
# []
# submit" value="">
#
# 			  -->
#
#
#
# None
# []
# nput type=textarea name=enter-search>
#
#
# 	-->
#
#
#
#
#
# None
# []
#
#
#
#
# None
# []
# div class="twenty columns">
#
#
#
# None
# []
# id="Layout" class="sidebar row">
#
# home
#
# None
# []
# v id="accordion">
# 		Search Timetables & Fares
#
# Type in your or
# None
# []
# igin & destination belowOR select from the drop down.
#
# None
# []
# rm" method="post" enctype="application/x-www-form-urlencoded" class="sectorsearchform narrow">
#
#
#
# None
# []
# error" class="message " style="display: none">
#
#
# None
# []
# lass="field h5optionset  isReturnTrip nolabel">
# None
# []
# tionset  isReturnTrip nolabel" data-role="controlgroup" data-type="horizontal">
# None
# []
# io" id="SectorSearchForm_Form_OneWayOrReturn_OneWay" name="OneWayOrReturn" type="radio" value="OneWay" checked="checked" />
# None
# []
# l for="SectorSearchForm_Form_OneWayOrReturn_OneWay">One-Way
# None
# []
# ="SectorSearchForm_Form_OneWayOrReturn_Return" name="OneWayOrReturn" type="radio" value="Return" />
# None
# []
# Form_OneWayOrReturn_Return">Return
#
#
# None
# []
# p stopPicker nolabel">
# None
# []
# >From
# None
# []
# Form_Form_From" name="From" value="" autocomplete="on" required="required" placeholder="From" />
# <a class="stoppicker" data-stopfield-id="SectorSearchForm_Form_From" data-title="Travelling from" href="#" title="Choos"></a>
# [<a class="stoppicker" data-stopfield-id="SectorSearchForm_Form_From" data-title="Travelling from" href="#" title="Choos"></a>]
# upField">
# None
# []
# e a stop to travel from...' >V
#
#
# None
# []
# nolabel">
# None
# []
# "leftlabel" for="SectorSearchForm_Form_To">To
# <a cla="" href="#"></a>
# [<a cla="" href="#"></a>]
# ="To" value="" autocomplete="on" required="required" placeholder="To" />
# None
# []
# ss='stoppicker' data-stopfield-id='SectorSearchForm_Form_To' data-title='Travelling to' title='Choose a stop to travel to...' >V
# None
# []
#
# None
# []
# Form_Form_Date_Travel">Departure Date
# None
# []
# _Form_Date_Travel" name="Date_Travel" value="2013-12-07" autocomplete="off" min="2013-12-06" juiConfig="{"buttonImage"
# None
# []
# :"\/assets\/reservations\/button_calender.png","buttonImageOnly":"true","dateFormat":&qu
# None
# []
# ot;dd\/mm\/yy","locale":"en-GB","minDate":"+0d","showOn":"both"
# None
# []
# }" />
#
#
# None
# []
# ate_Return">Return Date
# None
# []
# urn" name="Date_Return" value="2013-12-13" autocomplete="off" juiConfig="{"buttonImage":"\/assets\/reservations\/
# None
# []
# button_calender.png","buttonImageOnly":"true","dateFormat":"dd\/mm\/yy","local
# None
# []
# e":"en-GB","minDate":"+0d","showOn":"both"}" />
#
#
#
#
# None
# []
#
# Passengers
#
# None
# []
# olabel">Adu
# None
# []
# lt
# 01
# None
# []
# ption>2345
# None
# []
# ption value="6AD">6789
# None
# []
# lue="10AD">10Child (3-12 yrs)
# None
# []
# 01
# None
# []
# ion value="2CH">2345
# None
# []
# e="6CH">6789
# None
# []
# >10Golden Age (60+)
#
# None
# []
# lass=" disctype" id="SectorSearchForm_Form_GA" name="GA">01
# None
# []
# "2GA">23456
# None
# []
# /option>78910
# None
# []
# n>
#
# 			Other fare types
#
# None
# []
# ldgroup  extraPaxTypes nolabel">
# None
# []
# rSearchForm_Form_ST">Student (13+)
# 0
# None
# []
# /option>1234
# None
# []
# 5678
# None
# []
# value="9ST">910
# None
# []
# orm_BP">Backpacker (Valid ID)
# 0
# None
# []
# on>1234
# None
# []
# on value="5BP">5678
# None
# []
# ="9BP">910
# None
# []
# N">Infant (0-2 yrs no seat)
# 0
# None
# []
# >1234
# None
# []
# value="5IN">5678
# None
# []
# 9IN">910
#
# None
# []
# s="field formaction  ">Search
# None
# []
# put class="action " id="SectorSearchForm_Form_action_search" type="submit" name="action_search" value="Search" title="Search" />
# None
# []
#
# <a href="#stoppickerdialog-si">South Island All Stops</a>
# [<a href="#stoppickerdialog-si">South Island All Stops</a>]
# stoppickerdialog-ni'>North Island All Stops
# 		South Island All Stops
#
# None
# []
#
#
#
# <a data-stop-code="PIH" title="Maritime Building, Adjacent Wharf">Paihia</a>
# [<a data-stop-code="PIH" title="Maritime Building, Adjacent Wharf">Paihia</a>, <a data-stop-code="AKL" t=""></a>]
# and">North Island
# Paihia
#
# <a data-stop-code="AIR" title="Bus Stop 2008 International Termi"></a>
# [<a data-stop-code="AIR" title="Bus Stop 2008 International Termi"></a>]
# itle="Sky City Coach Terminal, 102 Hobson Street">Auckland
#
# <a data-stop-code="MNK" title="Leyton Way near foodcourt">Manukau Cit</a>
# [<a data-stop-code="MNK" title="Leyton Way near foodcourt">Manukau Cit</a>]
# nal, Ray Emery Drive.">Auckland International Airport
# Manukau Cit
# <a data-stop-code="HLZ" title="Hamilton Transport Centre, Cnr Bryce &amp; Anglesea, Platforms A - D.">Hamilton</a>
# [<a data-stop-code="HLZ" title="Hamilton Transport Centre, Cnr Bryce &amp; Anglesea, Platforms A - D.">Hamilton</a>, <a dat=""></a>]
# y
# Hamilton
#
# <a data-stop-code="TUO" title="Taupo Travel Centre, "></a>
# [<a data-stop-code="TUO" title="Taupo Travel Centre, "></a>]
# a-stop-code="ROT"  title="Tourism Rotorua, 1167 Fenton Street">Rotorua
#
# <a data-stop-code="GIS" title="Outside Gisborne I-Site, 209 Grey Street">Gisborne</a>
# [<a data-stop-code="GIS" title="Outside Gisborne I-Site, 209 Grey Street">Gisborne</a>, <a data-st=""></a>]
# 16 Gascoigne Street">Taupo
# Gisborne
#
# <a data-stop-code="NPL" title="19 Ariki"></a>
# [<a data-stop-code="NPL" title="19 Ariki"></a>]
# op-code="NPE"  title="135 Dalton St (Nearest Intersection - Station Street)">Napier
#
# <a data-stop-code="PMR" title="Travel Centre Corner Pitt &amp; Main Streets">Palmerston</a>
# [<a data-stop-code="PMR" title="Travel Centre Corner Pitt &amp; Main Streets">Palmerston</a>]
# Street, New Plymouth">New Plymouth
# Palmerston
# <a data-stop-code="WLG" title="Railway Station, Platform 9">Wellington</a>
# [<a data-stop-code="WLG" title="Railway Station, Platform 9">Wellington</a>]
# Nth
# Wellington
#
# <a data-stop-code="PCN" title="Outside Main Ent"></a>
# [<a data-stop-code="PCN" title="Outside Main Ent"></a>]
# ghtcol">
#
# South Island
#
# <a data-stop-code="NSN" title="Outside Travel Centre, 27 Bridge Street">Nelso</a>
# [<a data-stop-code="NSN" title="Outside Travel Centre, 27 Bridge Street">Nelso</a>]
# rance of Interislander Ferry Terminal">Picton
# Nelso
# <a data-stop-code="GRM" title="Greymouth Railway Station, 164 MacKay St">Greymouth</a>
# [<a data-stop-code="GRM" title="Greymouth Railway Station, 164 MacKay St">Greymouth</a>, <a data-stop-code="CHC" title="11"></a>]
# n
# Greymouth
#
# <a data-stop-code="DUD" title="Ritchies/InterCi"></a>
# [<a data-stop-code="DUD" title="Ritchies/InterCi"></a>]
# 8 Bealey Ave (between Colombo St and Durham St intersections)">Christchurch
#
# <a data-stop-code="ZQN" title="Athol Street in the m"></a>
# [<a data-stop-code="ZQN" title="Athol Street in the m"></a>]
# ty Travel, 7 Halsey Street, near the corner of Sturdee Street">Dunedin
#
# <a data-stop-code="WHO" title="Franz Josef Bus Stop, Main Road">Franz Josef</a>
# [<a data-stop-code="WHO" title="Franz Josef Bus Stop, Main Road">Franz Josef</a>, <a data-s=""></a>]
# iddle of the car park">Queenstown
# Franz Josef
#
# <a data-stop-code="IVC" title="Inver"></a>
# [<a data-stop-code="IVC" title="Inver"></a>]
# top-code="MFN"  title="Front Entrance of Visitors Centre, Milford Wharf">Milford Sound
#
# None
# []
# cargill Information Centre Car Park, 108 Gala Street">Invercargill
#
#
#
#
#
#
#
#
# <a data="" href="#"></a>
# [<a data="" href="#"></a>]
#
# A
#
#
# <a data-stop-code="AHT" href="#">Ahititi Turn Off</a>
# [<a data-stop-code="AHT" href="#">Ahititi Turn Off</a>, <a data-st="" href="#"></a>]
# -stop-code="ABF">Aberfeldy
#
# 						Ahititi Turn Off
#
# <a data-stop-code="ALY" href="#">Albany (Auckland)</a>
# [<a data-stop-code="ALY" href="#">Albany (Auckland)</a>, <a href="#"></a>]
# op-code="AKO">Akoranga (Auckland)
#
# 						Albany (Auckland)
#
# <a data-stop-code="ASH" href="#">Ashhurst</a>
# [<a data-stop-code="ASH" href="#">Ashhurst</a>]
# data-stop-code="ACL">Anchor Lodge Backpackers (Coromandel)
#
# 						Ashhurst
#
# <a data-stop-code="ATI" href="#">Atiamuri</a>
# [<a data-stop-code="ATI" href="#">Atiamuri</a>, <a data-stop-code="AKL" href="#">Auckland - Central</a>]
# Atiamuri
# Auckland - Central
#
# None
# []
#
#
# None
# []
# alog-col rightcol">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <a data-stop-code="ADA" href="#">Auckland Domestic Airport</a>
# [<a data-stop-code="ADA" href="#">Auckland Domestic Airport</a>, <a data-stop-code="AIR" href="#">Auckland Int</a>]
# Auckland Domestic Airport
# Auckland Int
# <a data-stop-code="AVC" href="#">Auckland Vector Arena</a>
# [<a data-stop-code="AVC" href="#">Auckland Vector Arena</a>, <a data-stop-="" href="#"></a>]
# ernational Airport
#
# 						Auckland Vector Arena
#
# <a data-stop-code="AWK" href="#">Awakeri</a>
# [<a data-stop-code="AWK" href="#">Awakeri</a>, <a data-stop-code="AKN" href="#">Awa</a>]
# code="AWH">Awahuri
#
# 						Awakeri
# Awa
# <a data-stop-code="AAI" href="#">Awanui</a>
# [<a data-stop-code="AAI" href="#">Awanui</a>]
# kino
#
# 						Awanui
#
# <a data-stop-code="MMB" href="#">Bayfair</a>
# [<a data-stop-code="MMB" href="#">Bayfair</a>]
# etter">
# 				B
#
# Bayfair
#
# <a data-stop-code="BVW" href="#">Bayview</a>
# [<a data-stop-code="BVW" href="#">Bayview</a>, <a data-stop-code="BBK" href="#">Bell Block</a>]
# Bayview
# Bell Block
#
# <a data-stop-code="BOX" href="#">Bombay (Auckland)</a>
# [<a data-stop-code="BOX" href="#">Bombay (Auckland)</a>]
# Bombay (Auckland)
#
# <a data-stop-code="BRY" href="#"></a>
# [<a data-stop-code="BRY" href="#"></a>]
# toppickerdialog-col rightcol">
#
#
#
#
#
#
#
#
#
#
# <a data-stop-code="BLS" href="#">Bulls</a>
# [<a data-stop-code="BLS" href="#">Bulls</a>, <a data-stop-code="GBW" href="#">BW Campground</a>]
# Brynderwyn
#
# 						Bulls
# BW Campground
# None
# []
# (for Rhythm and Vines Festival - Gisborne)
#
#
#
#
#
# C
# None
# []
#
#
# <a data-stop-code="WPJ" href="#">Cats Pajamas Backpackers (Whitianga)</a>
# [<a data-stop-code="WPJ" href="#">Cats Pajamas Backpackers (Whitianga)</a>]
# ref='#' data-stop-code="CBC">Cambridge
#
# 						Cats Pajamas Backpackers (Whitianga)
# <a data-stop-code="CLV" href="#">Clive</a>
# [<a data-stop-code="CLV" href="#">Clive</a>, <a data-stop-code="COP" href="#">Coopers Beach</a>]
# Clive
# Coopers Beach
#
# None
# []
#
#
# <a data-stop-code="COG" href="#">Coroglen</a>
# [<a data-stop-code="COG" href="#">Coroglen</a>, <a d="" href="#"></a>]
# Coroglen
#
# <a data-stop-code="CMP" href="#">Coromandel Kapanga Road</a>
# [<a data-stop-code="CMP" href="#">Coromandel Kapanga Road</a>, <a href=""></a>]
# ata-stop-code="CML">Coromandel
#
# 						Coromandel Kapanga Road
#
# None
# []
# '#' data-stop-code="CTB">Coromandel Town Backpackers (Coromandel)
#
#
#
#
#
# <a data-stop-code="DVK" href="#">Dannevir</a>
# [<a data-stop-code="DVK" href="#">Dannevir</a>]
# log-letter">
# 				D
#
# Dannevir
# <a data-s="" href="#"></a>
# [<a data-s="" href="#"></a>]
# ke
#
#
#
#
#
#
# None
# []
# top-code="TDO">Dinos (Tokoroa)
#
#
#
#
#
# E
#
# <a data-stop-code="EDG" href="#">Edgecumbe</a>
# [<a data-stop-code="EDG" href="#">Edgecumbe</a>, <a data-="" href="#"></a>]
# v class="stoppickerdialog-col leftcol">
#
# 						Edgecumbe
#
# <a data-stop-code="EMJ" href="#">Eight Mile Junction</a>
# [<a data-stop-code="EMJ" href="#">Eight Mile Junction</a>]
# stop-code="EGV">Egmont Village
#
# 						Eight Mile Junction
#
# None
# []
#
#
# <a data-stop-code="EKT" href="#">Eketahuna</a>
# [<a data-stop-code="EKT" href="#">Eketahuna</a>, <a data-stop-code="ELT" href="#">Eltham</a>, <a href="#"></a>]
# Eketahuna
# Eltham
#
# None
# []
# ' data-stop-code="ESK">Eskdale
#
#
#
#
#
# F
#
# <a data-stop-code="FNR" href="#">Featherston</a>
# [<a data-stop-code="FNR" href="#">Featherston</a>, <a dat="" href="#"></a>]
# v class="stoppickerdialog-col leftcol">
#
# 						Featherston
#
# <a data-stop-code="FTZ" href="#">Fitzroy</a>
# [<a data-stop-code="FTZ" href="#">Fitzroy</a>]
# a-stop-code="FLG">Feilding
#
# 						Fitzroy
#
# <a data-stop-code="" href="#"></a>
# [<a data-stop-code="" href="#"></a>]
# v>
#
#
# <a data-stop-code="FXN" href="#">Foxton</a>
# [<a data-stop-code="FXN" href="#">Foxton</a>]
# ="FLT">Flat Hills Tea Rooms
#
# 						Foxton
#
# <a data-stop-c="" href="#"></a>
# [<a data-stop-c="" href="#"></a>]
# ass="stoppickerdialog-letter">
# 				G
#
#
# <a data-stop-code="GIS" href="#">Gisborne</a>
# [<a data-stop-code="GIS" href="#">Gisborne</a>, <a data-stop="" href="#"></a>]
# ode="GCF">Gateway Cafe (Kaiwaka)
#
# 						Gisborne
#
# <a data-stop-code="GSP" href="#">Golden Springs</a>
# [<a data-stop-code="GSP" href="#">Golden Springs</a>]
# -code="ARP">Glenview Farm Hostel (Tangoio)
#
# 						Golden Springs
#
# None
# []
#
#
# <a data-stop-code="GTN" href="#">Greerton</a>
# [<a data-stop-code="GTN" href="#">Greerton</a>, <a data-stop-code="GRT" href="#">Greytown</a>]
# Greerton
# Greytown
#
# <a data-stop-code="GUM" href="#">Gumboot Manor Restaurant Taihape</a>
# [<a data-stop-code="GUM" href="#">Gumboot Manor Restaurant Taihape</a>]
# Gumboot Manor Restaurant Taihape
#
# <a data-stop-code="HL" href="#"></a>
# [<a data-stop-code="HL" href="#"></a>]
# oppickerdialog-letter">
# 				H
#
#
# <a data-stop-code="HGT" href="#">Hangatiki</a>
# [<a data-stop-code="HGT" href="#">Hangatiki</a>, <a data-stop-code="CHW" href="#"></a>]
# Z">Hamilton - Central
#
# 						Hangatiki
#
# <a data-stop-code="HST" href="#">Hastings</a>
# [<a data-stop-code="HST" href="#">Hastings</a>, <a data-stop-="" href="#"></a>]
# ">Hannafords Wharf (Coromandel)
#
# 						Hastings
#
# <a data-stop-code="HKI" href="#">Hikuai</a>
# [<a data-stop-code="HKI" href="#">Hikuai</a>]
# code="HWA">Hawera
#
# 						Hikuai
#
# None
# []
#
#
# <a data-stop-code="HKR" href="#">Hikurangi</a>
# [<a data-stop-code="HKR" href="#">Hikurangi</a>, <a da="" href="#"></a>]
# Hikurangi
#
# <a data-stop-code="HMT" href="#">Himatangi</a>
# [<a data-stop-code="HMT" href="#">Himatangi</a>, <a d="" href="#"></a>]
# ta-stop-code="HLC">Hillcrest (Hamilton)
#
# 						Himatangi
#
# <a data-stop-code="HVL" href="#">Hunterville</a>
# [<a data-stop-code="HVL" href="#">Hunterville</a>, <a data-stop="" href="#"></a>]
# ata-stop-code="HUK">Hukerenui
#
# 						Hunterville
#
# None
# []
# -code="HLY">Huntly
#
#
#
#
#
# I
#
# <a data-stop-code="IGD" href="#">Inglewood</a>
# [<a data-stop-code="IGD" href="#">Inglewood</a>, <a data-stop-code="I" href="#"></a>]
# ppickerdialog-col leftcol">
#
# 						Inglewood
#
# None
# []
# NL">Inland Rd
#
#
#
#
#
#
# <a data-stop-code="IWT" href="#">Iwitahi</a>
# [<a data-stop-code="IWT" href="#">Iwitahi</a>]
# Iwitahi
#
#
# <a data-stop-code="JVL" href="#">Johnsonville (Wellington)</a>
# [<a data-stop-code="JVL" href="#">Johnsonville (Wellington)</a>]
# 3>J
#
# Johnsonville (Wellington)
# <a data-stop-="" href="#"></a>
# [<a data-stop-="" href="#"></a>]
# a>
#
#
#
#
#
#
# None
# []
# code="WCJ">Juno Hall
#
#
#
#
#
# K
#
# <a data-stop-code="KAE" href="#">Kaeo</a>
# [<a data-stop-code="KAE" href="#">Kaeo</a>, <a data-stop-code="KHE" href="#"></a>]
# toppickerdialog-col leftcol">
#
# 						Kaeo
#
# <a data-stop-code="KAI" href="#">Kai Iwi</a>
# [<a data-stop-code="KAI" href="#">Kai Iwi</a>, <a data-stop-code="KOH" href="#">Kaikohe</a>]
# >Kahoe
#
# 						Kai Iwi
# Kaikohe
#
# <a data-stop-code="KAT" href="#">Kaitaia</a>
# [<a data-stop-code="KAT" href="#">Kaitaia</a>, <a data-stop-code="KWK" href="#">Kaiwaka</a>, <a hr=""></a>]
# Kaitaia
# Kaiwaka
#
# <a data-stop-code="KKT" href="#">Kakatahi</a>
# [<a data-stop-code="KKT" href="#">Kakatahi</a>, <a data="" href="#"></a>]
# ef='#' data-stop-code="KRM">Kakaramea
#
# 						Kakatahi
#
# <a data-stop-code="KAR" href="#">Karapiro</a>
# [<a data-stop-code="KAR" href="#">Karapiro</a>]
# -stop-code="KAM">Kamo
#
# 						Karapiro
#
# None
# []
#
#
# None
# []
# rdialog-col rightcol">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <a data-stop-code="KTK" href="#">Katikati</a>
# [<a data-stop-code="KTK" href="#">Katikati</a>, <a data-stop-code="KAK" href="#"></a>]
# Katikati
#
# <a data-stop-code="KAW" href="#">Kawerau</a>
# [<a data-stop-code="KAW" href="#">Kawerau</a>, <a data-stop-code="KER" href="#">Kerikeri</a>]
# Kawakawa
#
# 						Kawerau
# Kerikeri
#
# <a data-stop-code="KIH" href="#">Kihikihi</a>
# [<a data-stop-code="KIH" href="#">Kihikihi</a>, <a data-stop-code="KHK" href="#">Kohukohu</a>]
# Kihikihi
# Kohukohu
#
# <a data-stop-code="KOP" href="#">Kopu</a>
# [<a data-stop-code="KOP" href="#">Kopu</a>, <a data-stop-code="KOT" href="#">Kotemaori</a>, <a dat="" href="#"></a>]
# Kopu
# Kotemaori
#
# <a data-stop-code="KTR" href="#">Kutarere</a>
# [<a data-stop-code="KTR" href="#">Kutarere</a>]
# a-stop-code="KUO">Kuaotunu Turn Off
#
# 						Kutarere
#
# <a d="" href="#"></a>
# [<a d="" href="#"></a>]
#
# L
#
#
# <a data-stop-code="LVN" href="#">Levin</a>
# [<a data-stop-code="LVN" href="#">Levin</a>, <a data-stop-code="" href="#"></a>]
# ata-stop-code="LAL">Lake Alice
#
# 						Levin
#
# None
# []
# ="LFD">Lichfield
#
#
#
#
#
#
#
#
#
#
# <a data-stop-code="LIN" href="#">Linton</a>
# [<a data-stop-code="LIN" href="#">Linton</a>, <a data-stop-co="" href="#"></a>]
# Linton
#
# <a data-stop-code="LKM" href="#">Lower Kaimai</a>
# [<a data-stop-code="LKM" href="#">Lower Kaimai</a>]
# de="LID">Lions Den
#
# 						Lower Kaimai
#
# <a data-stop-code="" href="#"></a>
# [<a data-stop-code="" href="#"></a>]
# ="stoppickerdialog-letter">
# 				M
#
#
# <a data-stop-code="MKA" href="#">Makaraka</a>
# [<a data-stop-code="MKA" href="#">Makaraka</a>, <a data-stop-code="MMK" href="#">Mamak</a>]
# ="MHN">Mahoenui
#
# 						Makaraka
# Mamak
# <a data-stop-code="MNA" href="#">Mana (Wellington)</a>
# [<a data-stop-code="MNA" href="#">Mana (Wellington)</a>, <a data-stop-code="MRT" href="#">Mana Retre</a>]
# u
#
# 						Mana (Wellington)
# Mana Retre
# <a data-stop-code="MAA" href="#">Manaia</a>
# [<a data-stop-code="MAA" href="#">Manaia</a>, <a data-stop-code="MGK" href="#">Mangaweka</a>]
# at Centre
#
# 						Manaia
# Mangaweka
# <a data-stop-code="MNG" href="#">Mangonui</a>
# [<a data-stop-code="MNG" href="#">Mangonui</a>, <a data-stop-code="MNK" href="#">Manukau City (Auckland)</a>]
# Mangonui
# Manukau City (Auckland)
# <a data-stop-code="MNT" href="#">Manutahi</a>
# [<a data-stop-code="MNT" href="#">Manutahi</a>, <a data-stop-code="MKE" href="#">Manutuke</a>]
# /a>
#
# 						Manutahi
# Manutuke
#
# <a data-stop-code="MPU" href="#">Mapiu</a>
# [<a data-stop-code="MPU" href="#">Mapiu</a>, <a data-stop-code="MUA" href="#">Maramarua</a>, <a href="#"></a>]
# Mapiu
# Maramarua
#
# <a data-stop-code="MSY" href="#">Massey University (Palmerston Nth)</a>
# [<a data-stop-code="MSY" href="#">Massey University (Palmerston Nth)</a>]
# ' data-stop-code="MTN">Marton
#
# 						Massey University (Palmerston Nth)
#
# <a data-stop-code="MRO" href="#">Masterton</a>
# [<a data-stop-code="MRO" href="#">Masterton</a>, <a data-stop-code="MKH" href="#">Matakohe</a>, <a href=""></a>]
# Masterton
# Matakohe
#
# None
# []
# #' data-stop-code="MAM">Matamata
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# None
# []
#
# None
# []
#
#
# None
# []
#
# <a data-stop-code="MMU" href="#">Matamau</a>
# [<a data-stop-code="MMU" href="#">Matamau</a>, <a da="" href="#"></a>]
# Matamau
#
# <a data-stop-code="MWI" href="#">Matawai</a>
# [<a data-stop-code="MWI" href="#">Matawai</a>, <a data-="" href="#"></a>]
# ta-stop-code="MTG">Matarangi Turn Off
#
# 						Matawai
#
# <a data-stop-code="MID" href="#">Midhurst</a>
# [<a data-stop-code="MID" href="#">Midhurst</a>, <a data-stop-code="MI" href="#"></a>]
# stop-code="MAX">Maxwell
#
# 						Midhurst
#
# <a data-stop-code="MOE" href="#">Moerewa</a>
# [<a data-stop-code="MOE" href="#">Moerewa</a>, <a data-stop-code="" href="#"></a>]
# S">Mission Bay (Lake Taupo)
#
# 						Moerewa
#
# <a data-stop-code="MRR" href="#">Morere Hot Springs</a>
# [<a data-stop-code="MRR" href="#">Morere Hot Springs</a>, <a data-stop-code="MOV" href="#"></a>]
# "MKU">Mokau
#
# 						Morere Hot Springs
#
# <a data-stop-code="MPA" href="#">Motuoapa</a>
# [<a data-stop-code="MPA" href="#">Motuoapa</a>, <a data-stop-code="LTP" href="#">Motuter</a>]
# >Morrinsville
#
# 						Motuoapa
# Motuter
# <a data-stop-code="MVY" href="#">Mountain Valley</a>
# [<a data-stop-code="MVY" href="#">Mountain Valley</a>, <a data-stop-code="NWC" href="#">Mt Bruce</a>]
# e Bay
#
# 						Mountain Valley
# Mt Bruce
# <a data-stop-code="MMN" href="#">Mt Maunganui</a>
# [<a data-stop-code="MMN" href="#">Mt Maunganui</a>, <a data-stop-co="" href="#"></a>]
# National Wildlife Centre
#
# 						Mt Maunganui
#
# <a data-stop-code="MRW" href="#">Muriwai</a>
# [<a data-stop-code="MRW" href="#">Muriwai</a>]
# de="MVW">Mt View
#
# 						Muriwai
#
# <a data-stop-code="NPE" href="#"></a>
# [<a data-stop-code="NPE" href="#"></a>]
# ickerdialog-letter">
# 				N
#
#
# <a data-stop-code="NPA" href="#">Napier Airport</a>
# [<a data-stop-code="NPA" href="#">Napier Airport</a>, <a data-stop-code="NAT" href="#">National</a>]
# Napier
#
# 						Napier Airport
# National
# <a data-stop-code="NPL" href="#">New Plymouth</a>
# [<a data-stop-code="NPL" href="#">New Plymouth</a>, <a data-stop-code="NBH" href="#">New Plymout</a>]
# Park
#
# 						New Plymouth
# New Plymout
# <a data-stop-code="NGR" href="#">Ngarua</a>
# [<a data-stop-code="NGR" href="#">Ngarua</a>]
# h Boys High
#
# 						Ngarua
#
# None
# []
#
#
# <a data-stop-code="NGA" href="#">Ngaruawahia</a>
# [<a data-stop-code="NGA" href="#">Ngaruawahia</a>, <a data-stop-code="NON" href="#"></a>]
# Ngaruawahia
#
# <a data-stop-code="NBY" href="#">Normanby</a>
# [<a data-stop-code="NBY" href="#">Normanby</a>, <a data-stop-code="NWD" href="#">Norsewoo</a>]
# ">Ngongotaha
#
# 						Normanby
# Norsewoo
# <a data-stop-code="NHK" href="#">Nuhaka</a>
# [<a data-stop-code="NHK" href="#">Nuhaka</a>]
# d
#
# 						Nuhaka
#
# <a data-stop-code="OAK" href="#">Oakleigh</a>
# [<a data-stop-code="OAK" href="#">Oakleigh</a>]
# er">
# 				O
#
# Oakleigh
# <a data-stop-code="OHW" href="#">Ohaeawai</a>
# [<a data-stop-code="OHW" href="#">Ohaeawai</a>, <a data-stop-code="OKN" href="#">Ohakune</a>, <a h=""></a>]
# Ohaeawai
# Ohakune
#
# <a data-stop-code="OGT" href="#">Ohingaiti</a>
# [<a data-stop-code="OGT" href="#">Ohingaiti</a>, <a data-="" href="#"></a>]
# ref='#' data-stop-code="OHP">Ohaupo
#
# 						Ohingaiti
#
# <a data-stop-code="OHR" href="#">Ohura Turn Off</a>
# [<a data-stop-code="OHR" href="#">Ohura Turn Off</a>, <a data-stop-code="" href="#"></a>]
# stop-code="OHE">Ohope
#
# 						Ohura Turn Off
#
# <a data-stop-code="OKF" href="#">Okere Falls</a>
# [<a data-stop-code="OKF" href="#">Okere Falls</a>, <a data-stop-code="OMP" href="#">O</a>]
# ="OKR">Okahukura
#
# 						Okere Falls
# O
# <a data-stop-code="WOB" href="#">On the Beach Backpackers (Whitianga)</a>
# [<a data-stop-code="WOB" href="#">On the Beach Backpackers (Whitianga)</a>, <a data-st="" href="#"></a>]
# mapere
#
# 						On the Beach Backpackers (Whitianga)
#
# <a data-stop-code="OPN" href="#">Opononi</a>
# [<a data-stop-code="OPN" href="#">Opononi</a>, <a data-stop-co="" href="#"></a>]
# op-code="OGU">Ongarue Turn Off
#
# 						Opononi
#
# <a data-stop-code="OYH" href="#">Opononi YHA</a>
# [<a data-stop-code="OYH" href="#">Opononi YHA</a>]
# de="OPW">Opononi Wharf
#
# 						Opononi YHA
#
# None
# []
#
# None
# []
#
#
# None
# []
#
# <a data-stop-code="OPO" href="#">Opotiki</a>
# [<a data-stop-code="OPO" href="#">Opotiki</a>, <a data-stop-code="" href="#"></a>]
# Opotiki
#
# <a data-stop-code="OPU" href="#">Opua Hill</a>
# [<a data-stop-code="OPU" href="#">Opua Hill</a>, <a data-stop-code="OKK" href="#">Orakei</a>]
# OPT">Opoutere
#
# 						Opua Hill
# Orakei
# <a data-stop-code="OWA" href="#">Orewa (Auckland)</a>
# [<a data-stop-code="OWA" href="#">Orewa (Auckland)</a>, <a data-stop-code="OMD" href="#">Ormon</a>]
# Korako
#
# 						Orewa (Auckland)
# Ormon
# <a data-stop-code="ORT" href="#">Oruaiti</a>
# [<a data-stop-code="ORT" href="#">Oruaiti</a>, <a data-stop-code="OTI" href="#">Otaika</a>]
# d
#
# 						Oruaiti
# Otaika
#
# <a data-stop-code="OTK" href="#">Otaki</a>
# [<a data-stop-code="OTK" href="#">Otaki</a>, <a data-stop-code="OTN" href="#">Otane</a>, <a dat="" href="#"></a>]
# Otaki
# Otane
#
# <a data-stop-code="OTO" href="#">Otoko (Poverty Bay)</a>
# [<a data-stop-code="OTO" href="#">Otoko (Poverty Bay)</a>, <a hre=""></a>]
# a-stop-code="OTW">Otangiwai Turn-off
#
# 						Otoko (Poverty Bay)
#
# <a data-stop-code="OHA" href="#">Otorohanga</a>
# [<a data-stop-code="OHA" href="#">Otorohanga</a>, <a href=""></a>]
# f='#' data-stop-code="OKO">Otoko (Wanganui)
#
# 						Otorohanga
#
# None
# []
# '#' data-stop-code="OWH">Owhango
#
#
#
#
#
# P
#
# <a data-stop-code="BBP" href="#">Pacific International Hotel Management Sc</a>
# [<a data-stop-code="BBP" href="#">Pacific International Hotel Management Sc</a>]
# div class="stoppickerdialog-col leftcol">
#
# 						Pacific International Hotel Management Sc
# <a data-stop-code="PAE" href="#">Paekakariki (Wellington)</a>
# [<a data-stop-code="PAE" href="#">Paekakariki (Wellington)</a>, <a data-sto="" href="#"></a>]
# hool (Bell Block)
#
# 						Paekakariki (Wellington)
#
# <a data-stop-code="POA" href="#">Paeroa</a>
# [<a data-stop-code="POA" href="#">Paeroa</a>, <a data-stop-code="PAH" href="#"></a>]
# p-code="PGR">Paengaroa
#
# 						Paeroa
#
# <a data-stop-code="PIH" href="#">Paihia (Bay of Islands)</a>
# [<a data-stop-code="PIH" href="#">Paihia (Bay of Islands)</a>, <a data-stop-code="PM" href="#"></a>]
# Pahiatua
#
# 						Paihia (Bay of Islands)
#
# <a data-stop-code="PAK" href="#">Papakura (Auckland)</a>
# [<a data-stop-code="PAK" href="#">Papakura (Auckland)</a>, <a data-stop-c="" href="#"></a>]
# R">Palmerston North
#
# 						Papakura (Auckland)
#
# <a data-stop-code="PPR" href="#">Paparoa</a>
# [<a data-stop-code="PPR" href="#">Paparoa</a>, <a data-stop-code="PPT" href="#">Papa</a>]
# ode="PPM">Papamoa
#
# 						Paparoa
# Papa
# None
# []
# toetoe (Auckland)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# None
# []
#
#
# None
# []
#
# <a data-stop-code="PPQ" href="#">Paraparaumu (Wellington)</a>
# [<a data-stop-code="PPQ" href="#">Paraparaumu (Wellington)</a>, <a data-stop-code="PAT" href="#">Patea</a>]
# Paraparaumu (Wellington)
# Patea
#
# <a data-stop-code="PIO" href="#">Piopio</a>
# [<a data-stop-code="PIO" href="#">Piopio</a>, <a data-stop-code="PIK" href="#">Piriaka</a>, <a d="" href="#"></a>]
# Piopio
# Piriaka
#
# <a data-stop-code="POK" href="#">Pokeno (Auckland)</a>
# [<a data-stop-code="POK" href="#">Pokeno (Auckland)</a>]
# ata-stop-code="PLM">Plimmerton (Wellington)
#
# 						Pokeno (Auckland)
#
# <a data-stop-code="PUH" href="#">Puhoi</a>
# [<a data-stop-code="PUH" href="#">Puhoi</a>, <a h=""></a>]
# a href='#' data-stop-code="PRO">Porirua (Wellington)
#
# 						Puhoi
#
# <a data-stop-code="PUT" href="#">Putaruru</a>
# [<a data-stop-code="PUT" href="#">Putaruru</a>]
# ref='#' data-stop-code="PKB">Pukerua Bay (Wellington)
#
# 						Putaruru
#
# <a data-stop-code="PTR" href="#">Putorino</a>
# [<a data-stop-code="PTR" href="#">Putorino</a>]
# Putorino
#
# R
# <a data-stop-code="RAE" href="#">Raetihi</a>
# [<a data-stop-code="RAE" href="#">Raetihi</a>, <a href=""></a>]
# h3>
#
# Raetihi
#
# <a data-stop-code="RRR" href="#">Rangiriri</a>
# [<a data-stop-code="RRR" href="#">Rangiriri</a>, <a></a>]
# '#' data-stop-code="RSP">Rainbow Springs (Rotorua)
#
# 						Rangiriri
#
# <a data-stop-code="RAN" href="#">Ratana Turn Off</a>
# [<a data-stop-code="RAN" href="#">Ratana Turn Off</a>, <a hr=""></a>]
# href='#' data-stop-code="RGT">Rangitaiki
#
# 						Ratana Turn Off
#
# <a data-stop-code="RRM" href="#">Raurimu</a>
# [<a data-stop-code="RRM" href="#">Raurimu</a>, <a data-s="" href="#"></a>]
# ef='#' data-stop-code="RPG">Raupunga
#
# 						Raurimu
#
# None
# []
# top-code="REP">Reporoa Turn Off
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# None
# []
#
#
# <a data-stop-code="RAV" href="#">Rhythm &amp; Vines Festival Entran</a>
# [<a data-stop-code="RAV" href="#">Rhythm &amp; Vines Festival Entran</a>]
# Rhythm & Vines Festival Entran
# <a data-stop-code="RTI" href="#">Rotoiti</a>
# [<a data-stop-code="RTI" href="#">Rotoiti</a>, <a data-stop-code="ROM" href="#">Rotoma</a>]
# ce (Gisborne)
#
# 						Rotoiti
# Rotoma
# <a data-stop-code="ROT" href="#">Rotorua</a>
# [<a data-stop-code="ROT" href="#">Rotorua</a>, <a data-stop-code="ROA" href="#">Rotorua Airport</a>]
# a>
#
# 						Rotorua
# Rotorua Airport
#
# <a data-stop-code="RAK" href="#">Ruakaka</a>
# [<a data-stop-code="RAK" href="#">Ruakaka</a>, <a data-stop-code="RKH" href="#">Rukuhia</a>, <a hr=""></a>]
# Ruakaka
# Rukuhia
#
# None
# []
# ef='#' data-stop-code="RUS">Russell (Bay of Islands)
#
#
#
#
#
#
# <a data-stop-code="SAN" href="#">Sanson</a>
# [<a data-stop-code="SAN" href="#">Sanson</a>]
# S
#
# Sanson
#
# <a data-stop-code="SBT" href="#">Sea Breeze Holiday Park</a>
# [<a data-stop-code="SBT" href="#">Sea Breeze Holiday Park</a>, <a data-stop-code="SHN" href="#">Shannon</a>]
# Sea Breeze Holiday Park
# Shannon
#
# <a data-stop-code="SHP" href="#">SheepWorld (near Warkworth)</a>
# [<a data-stop-code="SHP" href="#">SheepWorld (near Warkworth)</a>, <a data-stop-code="SKG" href="#">Skyline Gondol</a>]
# SheepWorld (near Warkworth)
# Skyline Gondol
# None
# []
# a (Rotorua)
# ...
# ol">
#
# 						Seddon
# Spring Creek
#
# <a data-stop-code="STA" href="#">St Andrews</a>
# [<a data-stop-code="STA" href="#">St Andrews</a>, <a data-stop-code="SAC" href="#">St Andrews College (Christch</a>]
# St Andrews
# St Andrews College (Christch
# None
# []
# urch)
#
#
#
#
#
#
#
#
#
#
# <a data-stop-code="SBC" href="#">St Bedes College (Papanui)</a>
# [<a data-stop-code="SBC" href="#">St Bedes College (Papanui)</a>, <a></a>]
# St Bedes College (Papanui)
#
# <a data-stop-code="STK" href="#">Stoke</a>
# [<a data-stop-code="STK" href="#">Stoke</a>]
# href='#' data-stop-code="SMC">St Margarets College (Christchurch)
#
# 						Stoke
#
# None
# []
#
#
# <a data-stop-code="TAN" href="#">Tahunanui</a>
# [<a data-stop-code="TAN" href="#">Tahunanui</a>, <a data-stop-code="KTF" href="#">Takaka</a>]
# ">
#
# 						Tahunanui
# Takaka
#
# <a data-stop-code="TRS" href="#">Tarras</a>
# [<a data-stop-code="TRS" href="#">Tarras</a>, <a data-stop-code="TAS" href="#">Tasman</a>, <a da="" href="#"></a>]
# Tarras
# Tasman
#
# <a data-stop-code="TEU" href="#">Te Anau</a>
# [<a data-stop-code="TEU" href="#">Te Anau</a>, <a d="" href="#"></a>]
# ta-stop-code="NTT">Tasman Bay Backpackers
#
# 						Te Anau
#
# <a data-stop-code="TPO" href="#">Tekapo</a>
# [<a data-stop-code="TPO" href="#">Tekapo</a>, <a href=""></a>]
# ata-stop-code="FWH">Te Weheka Inn (Fox Glacier)
#
# 						Tekapo
#
# None
# []
# '#' data-stop-code="TMP">Templeton
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# None
# []
#
#
# <a data-stop-code="TMK" href="#">T</a>
# [<a data-stop-code="TMK" href="#">T</a>]
# T
# <a data-stop-code="WTM" href="#">Terrace Motel (Franz Jozef)</a>
# [<a data-stop-code="WTM" href="#">Terrace Motel (Franz Jozef)</a>, <a data-stop-code="Z" href="#"></a>]
# emuka
#
# 						Terrace Motel (Franz Jozef)
#
# <a data-stop-code="TIU" href="#">Timaru</a>
# [<a data-stop-code="TIU" href="#">Timaru</a>, <a data-stop-code="" href="#"></a>]
# QT">The Station (Queenstown)
#
# 						Timaru
#
# <a data-stop-code="TRM" href="#">Tiromoana</a>
# [<a data-stop-code="TRM" href="#">Tiromoana</a>, <a data-stop-code="NTM" href="#">Trailw</a>]
# "TIN">Tinwald
#
# 						Tiromoana
# Trailw
# <a data-stop-code="TUM" href="#">Tua Marina</a>
# [<a data-stop-code="TUM" href="#">Tua Marina</a>, <a data-stop-code="TWZ" href="#">Twize</a>]
# ays Motor Inn
#
# 						Tua Marina
# Twize
# None
# []
# l
#
#
#
#
#
# W
#
# <a data-stop-code="WPS" href="#">Waihi Prep School (South Island)</a>
# [<a data-stop-code="WPS" href="#">Waihi Prep School (South Island)</a>, <a data-stop-c="" href="#"></a>]
# leftcol">
#
# 						Waihi Prep School (South Island)
#
# <a data-stop-code="WIK" href="#">Waikari</a>
# [<a data-stop-code="WIK" href="#">Waikari</a>, <a data-stop-code="WKO" href="#">Waik</a>]
# ode="WHL">Waihola
#
# 						Waikari
# Waik
# <a data-stop-code="WKU" href="#">Waikuku</a>
# [<a data-stop-code="WKU" href="#">Waikuku</a>, <a data-stop-code="WMT" href="#">Waimate</a>]
# ouaiti
#
# 						Waikuku
# Waimate
#
# <a data-stop-code="WET" href="#">Waimate Turn Off</a>
# [<a data-stop-code="WET" href="#">Waimate Turn Off</a>, <a data-stop-code="WAI" href="#">Waipahi</a>]
# Waimate Turn Off
# Waipahi
#
# <a data-stop-code="WPA" href="#">Waipara</a>
# [<a data-stop-code="WPA" href="#">Waipara</a>, <a data-stop-code="WTH" href="#">Waitahuna</a>, <a href=""></a>]
# Waipara
# Waitahuna
#
# <a data-stop-code="WKF" href="#">Wakefield</a>
# [<a data-stop-code="WKF" href="#">Wakefield</a>]
# '#' data-stop-code="WTA">Waitati
#
# 						Wakefield
#
# None
# []
#
# None
# []
#
#
# <a data-stop-code="" href="#"></a>
# [<a data-stop-code="" href="#"></a>]
#
# <a data-stop-code="WRD" href="#">Ward</a>
# [<a data-stop-code="WRD" href="#">Ward</a>, <a data-stop-code="WDK" href="#">Washdyke</a>]
# "WKA">Wanaka
#
# 						Ward
# Washdyke
# <a data-stop-code="WSZ" href="#">Westport</a>
# [<a data-stop-code="WSZ" href="#">Westport</a>, <a data-stop-code="WSI" href="#">Westport i-SITE</a>]
# Westport
# Westport i-SITE
#
# <a data-stop-code="WWL" href="#">Westwood Lodge</a>
# [<a data-stop-code="WWL" href="#">Westwood Lodge</a>, <a data-stop-code="WTO" href="#">Whataroa</a>]
# Westwood Lodge
# Whataroa
#
# <a data-stop-code="WCH" href="#">Winchester</a>
# [<a data-stop-code="WCH" href="#">Winchester</a>, <a data-stop-code="WIN" href="#">Winton</a>, <a href="#"></a>]
# Winchester
# Winton
#
# <a data-stop-code="WDD" href="#">Woodend</a>
# [<a data-stop-code="WDD" href="#">Woodend</a>, <a></a>]
# ' data-stop-code="WDB">Woodbourne (Blenheim Airport)
#
# 						Woodend
#
# None
# []
# href='#' data-stop-code="WDL">Woodlands
#
#
#
#
#
#
#
#
#
# None
# []
# >
#
#
#
#
#
#
#
#
# 		Manage My Booking
#
# To amend an existing fare pl
# None
# []
# ease enter booking reference & email address.
#
# None
# []
# y.co.nz/managebooking/ResLoginForm" method="post" enctype="application/x-www-form-urlencoded" class="LoginRes">
#
#
#
# None
# []
# ginResForm_ResLoginForm_error" class="message " style="display: none">
#
#
# None
# []
# Field  nolabel">
#
# Email addr
# None
# []
# ess used to book
# None
# []
# name="Email" value="" autocomplete="on" placeholder="Email" title="Email" />
#
#
# None
# []
# Booking Reference
# None
# []
# class="text PNR" id="ICGLoginResForm_ResLoginForm_PNR" name="PNR" value="" autocomplete="off" placeholder="Booking reference" t
# None
# []
# itle="Booking reference" />
#
#
#
#
#
#
# None
# []
#
# None
# []
# gin" title="Login" />
#
#
#
#
#
#
#
#
# 		Got a Pass? Book Your Travel Here
#
# None
# []
# Enter your pass number & access code below to book travel & manage your pass.
#
# None
# []
# m_PassLoginForm" action="https://www.intercity.co.nz/managebooking/PassLoginForm" method="post" enctype="application/x-www-form-
# None
# []
# urlencoded" class="LoginPass">
#
#
#
#
# None
# []
#
#
#
# None
# []
# or="ICGLoginPassForm_PassLoginForm_PassNo">Pass Number
# None
# []
# d="ICGLoginPassForm_PassLoginForm_PassNo" name="PassNo" value="" autocomplete="off" placeholder="Pass Number" title="Pass Number
# None
# []
# " />
#
#
# None
# []
# ">Access Code
# None
# []
# essCode" name="AccessCode" value="" autocomplete="off" placeholder="Access Code" title="Access Code" />
#
#
#
#
# None
# []
#
#
#
# None
# []
# _PassLoginForm_action_loginPass" type="submit" name="action_loginPass" value="Login" title="Login" />
#
#
#
#
#
#
#
#
# None
# []
#
#
# None
# []
# word below to manage your bookings.
#
# None
# []
# z/managebooking/ClubMemberLoginForm" method="post" enctype="application/x-www-form-urlencoded" class="LoginClub">
#
#
#
# None
# []
# LoginClubForm_ClubMemberLoginForm_error" class="message " style="display: none">
#
#
# None
# []
# CompositeField  nolabel">
#
#
# None
# []
# LoginForm_ClubMemberCode">Freeway Number
# None
# []
# ubForm_ClubMemberLoginForm_ClubMemberCode" name="ClubMemberCode" value="" autocomplete="off" placeholder="Freeway Number" title=
# None
# []
# "Freeway Number" />
#
#
# None
# []
# oginForm_Password">Password
# None
# []
# lubMemberLoginForm_Password" name="Password" value="" autocomplete="off" placeholder="Password" title="Password" />
#
# None
# []
#
#
# None
# []
# oginClubForm_ClubMemberLoginForm_action_loginClub" type="submit" name="action_loginClub" value="Login" title="Login" />
#
#
# None
# []
# v>
#
#
#
#
#
#
#
#
#
#
#
#
# None
# []
# s="fourteen columns last">
#
#
#
#
#
# None
# []
# ss="slideshow-nav">
# 			123
#
# None
# []
# ow-slides">
#
#
#
# <a href="/bus-and-ferry-comb"></a>
# [<a href="/bus-and-ferry-comb"></a>]
# islander_slider.jpg" width="700" height="288" alt="Ferry combo passes" class="first image" />
#
# None
# []
# os/" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - ferrycombos']);">
#
#
# None
# []
# 1>Buy bus and ferry combos from $95*
# Combine InterCity bus trips and Interislander
# None
# []
# passenger ferry trips on our new combo passes
# Find Out More
#
# None
# []
# div class="slideshow-slide " data-id="969">
#
# <a href="#" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - "></a>
# [<a href="#" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - "></a>]
# ight="288" alt="" class=" image" />
#
# None
# []
# $1fare']);">
#
# $1* fares with InterCity
# Everyone loves a bargain!  And we've go
# None
# []
# t at least one $1* fare available on each and every InterCity速 bus service. *+ Booking Fee.
#
# None
# []
# -btn">Find tours now -->
#
#
#
#
#
#
# <a href="/passes/flex"></a>
# [<a href="/passes/flex"></a>]
# ssets/intercity12/slideshow/passes-slider.jpg" width="700" height="288" alt="" class="last image" />
#
# None
# []
# i-options" onclick="_gaq.push(['_trackEvent', 'HP Slider', 'Find Out More', 'Slide - flexiOptions']);">
#
# None
# []
# xt">
# NZ's National Bus Passes
# See more of New Zealand! Travel on NZ's largest national network with one of our flexi
# None
# []
# ble bus pass options.
# Search Passes Now
#
# None
# []
#
#
#
#
# <a href="/tours/" style="text-decoration:none"><span class="content-box-highlight-red"></span></a>
# [<a href="/tours/" style="text-decoration:none"><span class="content-box-highlight-red"></span></a>]
# ">
#
# None
# []
# > Discounted tours from $105
#
# None
# []
# /ic_hukajet_thumb.jpg" alt="ic_hukajet_thumb.jpg" />
# 					Great value tours to Huka Fa
# <a href="/tours/" onclick=""></a>
# [<a href="/tours/" onclick=""></a>]
# lls, Milford Sound, Hobbiton and more. Seats sell fast!
#
# None
# []
# "_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Discounted tours from $105']);">Search New Zealand Tours
#
# None
# []
#
#
# <a href="http://www.booking.com/index.html?aid=369493" style="text-decoration:none"><span c=""></span></a>
# [<a href="http://www.booking.com/index.html?aid=369493" style="text-decoration:none"><span c=""></span></a>]
#
# None
# []
# lass="content-box-highlight-red"> Need Accommodation?
#
# None
# []
# s/intercity12/main/bus-and-beds.jpg" alt="New Zealand Accommodation" />
# 					Search &a
# <a href=""></a>
# [<a href=""></a>]
# mp; book NZâs biggest range of accommodation with Best Rates Guaranteed.
#
# None
# []
# ="http://www.booking.com/index.html?aid=369493" onClick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Need Accommodat
# None
# []
# ion?']);">Search accommodation now
#
#
#
#
#
# <a href="travel-info/timetable/" style="text-decoration:none"><span class="c"></span></a>
# [<a href="travel-info/timetable/" style="text-decoration:none"><span class="c"></span></a>]
# ontent-box  ">
#
# None
# []
# ontent-box-highlight-red"> Find a bus stop
#
# None
# []
# 12/Promo-Pages/ic_bussstopsign98.jpg" alt="ic_bussstopsign98.jpg" />
# 					Find bus sto
# <a href="travel-info"></a>
# [<a href="travel-info"></a>]
# p locations around New Zealand and see timetable information.
#
# None
# []
# /timetable/" onClick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Find a bus stop']);">Get more info
#
# None
# []
#
#
# <a href="/bus-to-auckland-airport" style="text-decoration:none"><span class="content-box-hig"></span></a>
# [<a href="/bus-to-auckland-airport" style="text-decoration:none"><span class="content-box-hig"></span></a>]
#
# None
# []
# hlight-red"> Auckland Airport Connections
#
# None
# []
# 2/main/ic_airport_bus.jpg" alt="ic_airport_bus.jpg" />
# 					View connections to and fr
# <a href="/bus-to-auckland-a"></a>
# [<a href="/bus-to-auckland-a"></a>]
# om the airport from locations across the North Island.
#
# None
# []
# irport" onClick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Auckland Airport Connections']);">View Airport Connecti
# None
# []
# ons
#
#
#
#
#
#
# <a href="http://www.milford-sound.co.nz/" style="text-decoration:none"><span class="content-box-highlight-r"></span></a>
# [<a href="http://www.milford-sound.co.nz/" style="text-decoration:none"><span class="content-box-highlight-r"></span></a>]
# content-box-tagline">
# None
# []
# ed"> Featured Destination - Milford Sound
# None
# []
# 2/main/milford-sound-promo-tile.jpg" alt="milford sound promo tile" />
# 					Take an un
# <a hre=""></a>
# [<a hre=""></a>]
# forgettable journey into this breathtaking region - a must-see destination.
#
# None
# []
# f="http://www.milford-sound.co.nz/" onClick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'Featured Destination - Milf
# None
# []
# ord Sound']);">Visit milford-sound.co.nz
#
#
#
#
# <a href="/passes/flexi-options/" sty=""></a>
# [<a href="/passes/flexi-options/" sty=""></a>]
# ht">
#
#
# None
# []
# le="text-decoration:none"> NZ Bus Passes from just $39
#
# None
# []
# ="content-box-thumbnail">
#
# None
# []
# ass="content-box-description">Looking for a way to explore NZ? InterCity passes offer great savings on travel.
#
# <a href="/passes/flexi-options/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'N"></a>
# [<a href="/passes/flexi-options/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'N"></a>]
# class="content-box-textlink">
# None
# []
# Z Bus Passes from just $39']);">Search NZ Bus Passes
#
#
#
#
#
#
#
#
#
# None
# []
#
#
# <a href="/about-us">About Us</a>
# [<a href="/about-us">About Us</a>, <a href="/about-us/media-releas"></a>]
# class="footer-column left">
# 		About InterCity
# About Us .
# <a href="/privacy-policy">Privacy</a>
# [<a href="/privacy-policy">Privacy</a>, <a href="booking-agents/">Booking Agents</a>, <a href="/whatsnew/">What'</a>]
# es">Media. Privacy . Booking Agents . What'
# <a href="/help/">Site Map</a>
# [<a href="/help/">Site Map</a>, <a href="/managebooking/" onclick="_gaq.push(['_trackE"></a>]
# s New . Site Map
# Get Info
#
# <a href="/frequently-asked-questions/">FAQs</a>
# [<a href="/frequently-asked-questions/">FAQs</a>]
# vent', 'Footer Link', 'Go To', 'Manage my Booking']);">Manage my booking . FAQs .
# <a href="/delays-and-cancellations/">Delays &amp; Disruptions</a>
# [<a href="/delays-and-cancellations/">Delays &amp; Disruptions</a>, <a href="/terms-and-conditions">Terms &amp; Conditions</a>]
# Delays & Disruptions . Terms & Conditions
#
# <a href="/rewards">Freeway Login</a>
# [<a href="/rewards">Freeway Login</a>, <a href="/about-us/affiliate/">Affiliate Programme</a>, <a hre=""></a>]
# h3>Get Onboard
# 		Freeway Login . Affiliate Programme .
# <a href="/feedback">Contact Us</a>
# [<a href="/feedback">Contact Us</a>]
# f="/feedback">Feedback . Contact Us
#
# Tours
# <a href="/tours">Tours</a>
# [<a href="/tours">Tours</a>, <a href="http://www.greatsights.co.nz/" target="blank">Great Sights</a>, <a href="http:/"></a>]
# 3>
# 		 Tours . Great Sights .
# <a href="http://www.dolphincruises.co.nz/" target="blank">Dolphin Cruise</a>
# [<a href="http://www.dolphincruises.co.nz/" target="blank">Dolphin Cruise</a>]
# /www.awesomenz.com/" target="blank">Awesome NZ . Dolphin Cruise
# <a href="http://flexipass.intercity.co.nz/" target="blank">Flexipass</a>
# [<a href="http://flexipass.intercity.co.nz/" target="blank">Flexipass</a>, <a href="http://www.fl"></a>]
# >
# Passes
# Flexipass .
# <a href="http://travelpass.intercity.co.nz">TravelPass</a>
# [<a href="http://travelpass.intercity.co.nz">TravelPass</a>, <a href="/passes/in"></a>]
# exitrips.co.nz" target="blank">Flexitrips . TravelPass .
# <a href="/passes/student-bus-pass/">Student Pass</a>
# [<a href="/passes/student-bus-pass/">Student Pass</a>]
# tercity-commuter/">InterCity Commuter . Student Pass
# Connect
#
# <a href="http://www.facebook.com/intercity.coachlines" target="blank"><img class="left" src="assets"/></a>
# [<a href="http://www.facebook.com/intercity.coachlines" target="blank"><img class="left" src="assets"/></a>]
# class="social-media">
#
# <a href="http://www.twitter.com/Inter"></a>
# [<a href="http://www.twitter.com/Inter"></a>]
# /intercity12/main/ic_facebookIcon.png" alt="Facebook" width="27" height="27" title=""/>
# None
# []
# CityBUS" target="blank">
# <a href="http://plus.google.com/100713504200361907253" target="blank"><img class="left" src="assets/intercity12/ma"/></a>
# [<a href="http://plus.google.com/100713504200361907253" target="blank"><img class="left" src="assets/intercity12/ma"/></a>]
# title=""/>
# None
# []
# in/ic_googleplusIcon.png" alt="Google+" width="27" height="27" title=""/>Copyright ÂŠ 2012 InterCity Group (NZ) Ltd.
#
# None
# []
#
#
# None
# []
# ty12/js/jslibs.js?m=1386109965">
# None
# []
# obal.js?m=1386109965">
# None
# []
# =1369093915"></s
# None
# []
# cript>
# None
# []
# >
# None
# []
# script type="text/javascript" src="http://www.intercity.co.nz/bookingelements/javascript/SectorSearchForm.js?m=1368669239">
# None
# []
# ipt></scri
# None
# []
# pt></
# None
# []
# script>//<![CDATA[
# intercity.stopautocomplete('SectorSearchForm_Form_From');
#
# //]]>
# None
# []
# pt type="text/javascript">//

# %%
mixOpen = open('outputz', 'r')
mixOpen.read()
# Out:
# ''

# %%
# %%bash
# git add .
# git commit -m daTweetz
# Out:
# [master 0099175] daTweetz
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# %%bash
# git push https://github.com/wcmckee/intercity
# Out:
# warning: push.default is unset; its implicit value is changing in
# Git 2.0 from 'matching' to 'simple'. To squelch this message
# and maintain the current behavior after the default changes, use:
#
#   git config --global push.default matching
#
# To squelch this message and adopt the new behavior now, use:
#
#   git config --global push.default simple
#
# See 'git help config' and search for 'push.default' for further information.
# (the 'simple' mode was introduced in Git 1.7.11. Use the similar mode
# 'current' instead of 'simple' if you sometimes use older versions of Git)
#
# To https://github.com/wcmckee/intercity
#    f2777fc..0099175  master -> master

# %%
testing = []

# %%
testing.append(daTweetz)

# %%
print testing
# Out:
# [<open file 'testing.txt', mode 'r' at 0x2955e40>]

# %%
for site in loadSite:

# %%
for site in loadSite:
    daLink = []
    dafile = open('output', 'w')
    daLink.append(site)
    inter = BeautifulSoup(site)
    daLink.append(inter)
    geter = inter.text
    daLink.append(geter)
    beuLink = BeautifulSoup(daLink[0])
    print beuLink.a
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <a class="logo l" href="/"></a>
# None
# None
# <a href="/info/about-us/">About Us</a>
# None
# None
# <a class="current" href="/">H</a>
# <a class="flyout-toggle" href="/#"><span></span></a>
# None
# <a href="/travel-info/route-map/">View the route map</a>
# <a href="/travel-info/north-island-booking-agents/">Booking Agents</a>
# None
# <a href="/travel-info/child-fares/">Child Fares </a>
# <a href="/travel-info/frequently-asked-questions/">FAQ's</a>
# None
# None
# None
# <a href="/timetable">Tim</a>
# <a href="/route-map">Route Map</a>
# None
# <a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a>
# None
# <a href="/getting-a-1-fare">Getting a $1 Fare</a>
# None
# None
# <a href=""></a>
# <a href="/oversized-items">Oversized Items/Bicycles</a>
# None
# <a href="/north-island-booking-agents"></a>
# <a href="/south-island-booking-agents/">Find a South Island Agent</a>
# None
# <a href="/delays-and-disruptions">View Current Disr</a>
# None
# <a hr=""></a>
# None
# None
# <a href="/child-fares">Child Fares</a>
# <a href="/frequently-asked-ques"></a>
# None
# <a href="/group-bookings">
# <h></h></a>
# None
# None
# <a class="flyout-toggle" href="/#"><span></span></a>
# None
# None
# None
# <a href="/change-cancel-a-booking">How To Change/Cancel a Booking</a>
# None
# None
# <a href="/changes-and-refunds">Changes, Cancellations &amp; Refunds</a>
# <a cla="" href="/#"></a>
# None
# <a href="/frequent-travellers/how-it-works/">How it Works</a>
# None
# None
# <a href="/frequent-travellers/forgotpwd/">Club Password Reset</a>
# None
# None
# <a href="/how-it-works">How it works </a>
# <a href="/join-club-freeway">Join FREEWAY</a>
# None
# <a href="/rewards">Login to FREEWAY</a>
# None
# <a href="/cheapas">Sign up for special offers</a>
# None
# <a class="flyout-toggle" href="/#"><span></span></a>
# <a href="/tours/intercity-hobbiton-excursion-auckland-to-"></a>
# None
# <a href="/tours/intercity-milford-sound-tour/">Milford Sound Tour</a>
# None
# None
# <a href="/tours/hukafalls-jet/">Hukafalls Jetboat Morning Tour (Return ex Tau</a>
# None
# <a href="/tours/the-lord-of-the-rings-film-locations/">LOTR Film Locations</a>
# <a href="/tours/Auckland-Morning-City-t"></a>
# None
# <a href="/tours/tamaki-maori-village-experience/">Tamaki Maori Village Evening Experience</a>
# None
# <a href="/intercity-milford-sound-tour/"><img src="/assets/intercity12/main/ICONSMENU/milford_ico" style="float:left;"/></a>
# <a href="/intercity-milford-sound-"></a>
# <a href="/intercity-milford-sound-tour/"> </a>
# <a href="/intercity-milford-sound-tour/">Day trip from Queenstown from $119*</a>
# <a href="/intercity-hobbiton-excursion-auckland-to-auckland/"><img src="/assets/intercity1" style="float:left"/></a>
# None
# <a href="/intercity-hobbiton-excursion-auckland-to-auckland/">
# <h2>Hobbiton Movie Set</h2>
# </a>
# <a href="/intercity-hobbiton-excursion-auckland-to-auckland/"></a>
# None
# <a href="/dart-river-jet/"><img src="/assets/intercity12/main/ICONSMENU/Dart-River_icon.png" style="float:left;"/></a>
# <a href="/dart-river-jet/">
# <h2>Dart River</h2></a>
# <a href="/dart-river-jet/"> </a>
# <a href="/tours/waitomo-caves-tour/"></a>
# None
# <a href="/tours/waitomo-caves-tour/">
# <h2>Waitomo Caves Tour</h2>
# </a>
# <a href="/tours/waitomo-caves-tour/"></a>
# <a href="/intercity-dolphin-cruise-tour"></a>
# None
# <a href="/intercity-dolphin-cruise-tour/">
# <h2>Bay of Islands</h2>
# </a>
# <a href="/intercity-dolphin-cruise-tour/"></a>
# <a href="/the-l"></a>
# None
# <a href="/the-lord-of-the-rings-film-locations/">
# <h2></h2></a>
# <a href="/the-lord-of-the-rings-film-locations/"> </a>
# <a href="/the-lord-of-the-rings-film-locations/">Discover the films' locations in NZ</a>
# <a href="/Auckland-Morning-City-tour/"><img src="/asse" style="float:left;"/></a>
# None
# <a href="/Auckland-Morning-City-tour/">
# <h2>Auckland City Tour</h2>
# </a>
# <a href="/Auckland-Morning-City-tour/"></a>
# <a href="/hukafalls-jet/"><img style="float:left;"/></a>
# None
# <a href="/hukafalls-jet/">
# <h2>Hukafalls Jet</h2>
# </a>
# <a href="/hukafalls-jet/">Daily from Taupo from $109*</a>
# None
# <a href="/tamaki-maori-village-experien"></a>
# <a href="/tamaki-maori-village-experience/"> </a>
# <a href="/tamaki-maori-village-experience/">Daily from Rotorua from $110*</a>
# None
# <a class="flyout-toggle" href="/#"><span></span></a>
# <a href="/passes/flexi-options/">Flexi Options</a>
# None
# None
# <a href="/passes/intercity-commuter/">InterCity Commuter</a>
# None
# None
# <a href="/flexi-options/"><img src="/assets/intercity12/main/ICONSMENU/flex" style="float:left;"/></a>
# <a href="/flexi-options/">
# <h2></h2></a>
# <a href="/flexi-options/"> </a>
# None
# <a hre=""></a>
# None
# <a href="/travel-pass/">
# <h2>Fixed Itinerary Passes</h2>
# </a>
# <a href="/travel-pass/"></a>
# None
# <a href="/intercity-commuter/"><img src="/assets/intercity12/main/ICONSMENU/commuter.jp" style="float:left;"/></a>
# None
# <a href="/intercity-commuter/">Save up to 38%* on regular fares between Hamilton/Auckland.  Over 20 services per day be</a>
# <a href="/student-bus-pa"></a>
# None
# <a href="/student-bus-pass/">
# <h2>Student Passes</h2>
# </a>
# <a href="/student-bus-pass/"></a>
# None
# <a class="link" href="http://www.booking.com/index.html?aid=369493">Accommodation</a>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <a class="stoppicker" data-stopfield-id="SectorSearchForm_Form_From" data-title="Travelling from" href="#" title="Choos"></a>
# None
# None
# None
# <a cla="" href="#"></a>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <a href="#stoppickerdialog-si">South Island All Stops</a>
# None
# <a data-stop-code="PIH" title="Maritime Building, Adjacent Wharf">Paihia</a>
# <a data-stop-code="AIR" title="Bus Stop 2008 International Termi"></a>
# <a data-stop-code="MNK" title="Leyton Way near foodcourt">Manukau Cit</a>
# <a data-stop-code="HLZ" title="Hamilton Transport Centre, Cnr Bryce &amp; Anglesea, Platforms A - D.">Hamilton</a>
# <a data-stop-code="TUO" title="Taupo Travel Centre, "></a>
# <a data-stop-code="GIS" title="Outside Gisborne I-Site, 209 Grey Street">Gisborne</a>
# <a data-stop-code="NPL" title="19 Ariki"></a>
# <a data-stop-code="PMR" title="Travel Centre Corner Pitt &amp; Main Streets">Palmerston</a>
# <a data-stop-code="WLG" title="Railway Station, Platform 9">Wellington</a>
# <a data-stop-code="PCN" title="Outside Main Ent"></a>
# <a data-stop-code="NSN" title="Outside Travel Centre, 27 Bridge Street">Nelso</a>
# <a data-stop-code="GRM" title="Greymouth Railway Station, 164 MacKay St">Greymouth</a>
# <a data-stop-code="DUD" title="Ritchies/InterCi"></a>
# <a data-stop-code="ZQN" title="Athol Street in the m"></a>
# <a data-stop-code="WHO" title="Franz Josef Bus Stop, Main Road">Franz Josef</a>
# <a data-stop-code="IVC" title="Inver"></a>
# None
# <a data="" href="#"></a>
# <a data-stop-code="AHT" href="#">Ahititi Turn Off</a>
# <a data-stop-code="ALY" href="#">Albany (Auckland)</a>
# <a data-stop-code="ASH" href="#">Ashhurst</a>
# <a data-stop-code="ATI" href="#">Atiamuri</a>
# None
# None
# <a data-stop-code="ADA" href="#">Auckland Domestic Airport</a>
# <a data-stop-code="AVC" href="#">Auckland Vector Arena</a>
# <a data-stop-code="AWK" href="#">Awakeri</a>
# <a data-stop-code="AAI" href="#">Awanui</a>
# <a data-stop-code="MMB" href="#">Bayfair</a>
# <a data-stop-code="BVW" href="#">Bayview</a>
# <a data-stop-code="BOX" href="#">Bombay (Auckland)</a>
# <a data-stop-code="BRY" href="#"></a>
# <a data-stop-code="BLS" href="#">Bulls</a>
# None
# None
# <a data-stop-code="WPJ" href="#">Cats Pajamas Backpackers (Whitianga)</a>
# <a data-stop-code="CLV" href="#">Clive</a>
# None
# <a data-stop-code="COG" href="#">Coroglen</a>
# <a data-stop-code="CMP" href="#">Coromandel Kapanga Road</a>
# None
# <a data-stop-code="DVK" href="#">Dannevir</a>
# <a data-s="" href="#"></a>
# None
# <a data-stop-code="EDG" href="#">Edgecumbe</a>
# <a data-stop-code="EMJ" href="#">Eight Mile Junction</a>
# None
# <a data-stop-code="EKT" href="#">Eketahuna</a>
# None
# <a data-stop-code="FNR" href="#">Featherston</a>
# <a data-stop-code="FTZ" href="#">Fitzroy</a>
# <a data-stop-code="" href="#"></a>
# <a data-stop-code="FXN" href="#">Foxton</a>
# <a data-stop-c="" href="#"></a>
# <a data-stop-code="GIS" href="#">Gisborne</a>
# <a data-stop-code="GSP" href="#">Golden Springs</a>
# None
# <a data-stop-code="GTN" href="#">Greerton</a>
# <a data-stop-code="GUM" href="#">Gumboot Manor Restaurant Taihape</a>
# <a data-stop-code="HL" href="#"></a>
# <a data-stop-code="HGT" href="#">Hangatiki</a>
# <a data-stop-code="HST" href="#">Hastings</a>
# <a data-stop-code="HKI" href="#">Hikuai</a>
# None
# <a data-stop-code="HKR" href="#">Hikurangi</a>
# <a data-stop-code="HMT" href="#">Himatangi</a>
# <a data-stop-code="HVL" href="#">Hunterville</a>
# None
# <a data-stop-code="IGD" href="#">Inglewood</a>
# None
# <a data-stop-code="IWT" href="#">Iwitahi</a>
# <a data-stop-code="JVL" href="#">Johnsonville (Wellington)</a>
# <a data-stop-="" href="#"></a>
# None
# <a data-stop-code="KAE" href="#">Kaeo</a>
# <a data-stop-code="KAI" href="#">Kai Iwi</a>
# <a data-stop-code="KAT" href="#">Kaitaia</a>
# <a data-stop-code="KKT" href="#">Kakatahi</a>
# <a data-stop-code="KAR" href="#">Karapiro</a>
# None
# None
# <a data-stop-code="KTK" href="#">Katikati</a>
# <a data-stop-code="KAW" href="#">Kawerau</a>
# <a data-stop-code="KIH" href="#">Kihikihi</a>
# <a data-stop-code="KOP" href="#">Kopu</a>
# <a data-stop-code="KTR" href="#">Kutarere</a>
# <a d="" href="#"></a>
# <a data-stop-code="LVN" href="#">Levin</a>
# None
# <a data-stop-code="LIN" href="#">Linton</a>
# <a data-stop-code="LKM" href="#">Lower Kaimai</a>
# <a data-stop-code="" href="#"></a>
# <a data-stop-code="MKA" href="#">Makaraka</a>
# <a data-stop-code="MNA" href="#">Mana (Wellington)</a>
# <a data-stop-code="MAA" href="#">Manaia</a>
# <a data-stop-code="MNG" href="#">Mangonui</a>
# <a data-stop-code="MNT" href="#">Manutahi</a>
# <a data-stop-code="MPU" href="#">Mapiu</a>
# <a data-stop-code="MSY" href="#">Massey University (Palmerston Nth)</a>
# <a data-stop-code="MRO" href="#">Masterton</a>
# None
# None
# None
# None
# <a data-stop-code="MMU" href="#">Matamau</a>
# <a data-stop-code="MWI" href="#">Matawai</a>
# <a data-stop-code="MID" href="#">Midhurst</a>
# <a data-stop-code="MOE" href="#">Moerewa</a>
# <a data-stop-code="MRR" href="#">Morere Hot Springs</a>
# <a data-stop-code="MPA" href="#">Motuoapa</a>
# <a data-stop-code="MVY" href="#">Mountain Valley</a>
# <a data-stop-code="MMN" href="#">Mt Maunganui</a>
# <a data-stop-code="MRW" href="#">Muriwai</a>
# <a data-stop-code="NPE" href="#"></a>
# <a data-stop-code="NPA" href="#">Napier Airport</a>
# <a data-stop-code="NPL" href="#">New Plymouth</a>
# <a data-stop-code="NGR" href="#">Ngarua</a>
# None
# <a data-stop-code="NGA" href="#">Ngaruawahia</a>
# <a data-stop-code="NBY" href="#">Normanby</a>
# <a data-stop-code="NHK" href="#">Nuhaka</a>
# <a data-stop-code="OAK" href="#">Oakleigh</a>
# <a data-stop-code="OHW" href="#">Ohaeawai</a>
# <a data-stop-code="OGT" href="#">Ohingaiti</a>
# <a data-stop-code="OHR" href="#">Ohura Turn Off</a>
# <a data-stop-code="OKF" href="#">Okere Falls</a>
# <a data-stop-code="WOB" href="#">On the Beach Backpackers (Whitianga)</a>
# <a data-stop-code="OPN" href="#">Opononi</a>
# <a data-stop-code="OYH" href="#">Opononi YHA</a>
# None
# None
# None
# <a data-stop-code="OPO" href="#">Opotiki</a>
# <a data-stop-code="OPU" href="#">Opua Hill</a>
# <a data-stop-code="OWA" href="#">Orewa (Auckland)</a>
# <a data-stop-code="ORT" href="#">Oruaiti</a>
# <a data-stop-code="OTK" href="#">Otaki</a>
# <a data-stop-code="OTO" href="#">Otoko (Poverty Bay)</a>
# <a data-stop-code="OHA" href="#">Otorohanga</a>
# None
# <a data-stop-code="BBP" href="#">Pacific International Hotel Management Sc</a>
# <a data-stop-code="PAE" href="#">Paekakariki (Wellington)</a>
# <a data-stop-code="POA" href="#">Paeroa</a>
# <a data-stop-code="PIH" href="#">Paihia (Bay of Islands)</a>
# <a data-stop-code="PAK" href="#">Papakura (Auckland)</a>
# <a data-stop-code="PPR" href="#">Paparoa</a>
# None
# None
# None
# <a data-stop-code="PPQ" href="#">Paraparaumu (Wellington)</a>
# <a data-stop-code="PIO" href="#">Piopio</a>
# <a data-stop-code="POK" href="#">Pokeno (Auckland)</a>
# <a data-stop-code="PUH" href="#">Puhoi</a>
# <a data-stop-code="PUT" href="#">Putaruru</a>
# <a data-stop-code="PTR" href="#">Putorino</a>
# <a data-stop-code="RAE" href="#">Raetihi</a>
# <a data-stop-code="RRR" href="#">Rangiriri</a>
# <a data-stop-code="RAN" href="#">Ratana Turn Off</a>
# <a data-stop-code="RRM" href="#">Raurimu</a>
# None
# None
# <a data-stop-code="RAV" href="#">Rhythm &amp; Vines Festival Entran</a>
# <a data-stop-code="RTI" href="#">Rotoiti</a>
# <a data-stop-code="ROT" href="#">Rotorua</a>
# <a data-stop-code="RAK" href="#">Ruakaka</a>
# None
# <a data-stop-code="SAN" href="#">Sanson</a>
# <a data-stop-code="SBT" href="#">Sea Breeze Holiday Park</a>
# <a data-stop-code="SHP" href="#">SheepWorld (near Warkworth)</a>
# None
# <a data-stop-code="SFM" href="#"></a>
# <a data-stop-code="SPC" href="#">St Peters School (Cambridge)</a>
# <a data-stop-code="SFD" href="#">Stratford</a>
# None
# <a data-stop-code="TPE" href="#"></a>
# <a data-stop-code="TPA" href="#">Taipa</a>
# <a data-stop-code="TKP" href="#">Takapau</a>
# <a data-stop-code="TPP" href="#">Tapapa</a>
# <a data-stop-code="TRW" href="#">Tarawera</a>
# <a data-stop-code="TMN" href="#">Taumarunui</a>
# <a data-stop-code="TUO" href="#">Taupo</a>
# <a data-stop-code="TRH" href="#">Te Aroha</a>
# <a data-stop-code="TAW" href="#">Te Awamutu</a>
# <a data-stop-code="THT" href="#">Te Haroto</a>
# <a data-stop-code="TEK" href="#">Te Karaka</a>
# <a data-stop-code="TEA" href="#">Te Kouma Turn Off</a>
# <a data-stop-code="TEM" href="#">Te Mata</a>
# None
# None
# None
# None
# None
# <a data-stop-code="TNG" href="#">Te Ngae</a>
# <a data-stop-code="TOI" href="#">Te Poi</a>
# <a data-stop-code="TPK" href="#">Te Puke</a>
# <a data-stop-code="TPU" href="#">Te Puru</a>
# <a data-stop-code="TRP" href="#">Te Rapa</a>
# <a data-stop-code="TBA" href="#">The Big Apple (Otorohanga)</a>
# <a data-stop-code="THB" href="#">Thorntons Bay</a>
# <a data-stop-code="TDW" href="#">Tidewater Tourist Park YHA (Coromandel)</a>
# <a data-stop-code="TKM" href="#">Tokomaru</a>
# <a data-stop-code="TGP" href="#">Tongaporutu</a>
# <a data-stop-code="TOW" href="#">Towai</a>
# <a data-stop-code="TGI" href="#">Turangi</a>
# <a data-stop-code="TTR" href="#">Tutira</a>
# <a data-s="" href="#"></a>
# None
# <a data-stop-code="URT" href="#">Uruti</a>
# <a data-stop-code="WAH" href="#">Waihi</a>
# <a data-stop-code="WHB" href="#">Waihi Beach Reserve</a>
# <a data-stop-code="WAE" href="#">Waikanae (Wellington)</a>
# <a data-stop-code="WKW" href="#">Waikawau</a>
# <a data-stop-code="WTN" href="#">Waimate North</a>
# <a data-stop-code="WKP" href="#">Waioeka Pa</a>
# <a data-stop-code="WIR" href="#">Waiouru</a>
# <a data-stop-code="WPW" href="#">Waipawa</a>
# <a data-stop-code="WPK" href="#">Waipukurau</a>
# <a data-stop-code="WRT" href="#">Wairata</a>
# <a data-stop-code="WTK" href="#">Waitakaruru</a>
# None
# None
# None
# None
# <a d="" href="#"></a>
# <a data-stop-code="WAT" href="#">Waitara</a>
# <a data-stop-code="WOA" href="#">Waitoa</a>
# <a data-stop-code="WCC" href="#">Waitomo Township</a>
# <a data-stop-code="WWA" href="#">Waiwera (Auckland)</a>
# <a data-stop-code="WWC" href="#">Warkworth (Auckland)</a>
# <a data-stop-code="WLG" href="#">Wellington - Central</a>
# <a data-stop-code="WFD" href="#">Wellsford</a>
# <a data-stop-code="WHK" href="#">Whakatane</a>
# <a data-stop-code="WGP" href="#">Whangapoua Turn Off</a>
# <a data-stop-code="WKT" href="#">Whenuakite</a>
# <a data-stop-code="WHT" href="#">Whitianga</a>
# None
# <a data-stop-code="AKA" href="#">Akaroa</a>
# <a data-stop-code="ALN" href="#">Allanton</a>
# <a data-stop-code="AMB" href="#">Amberley</a>
# None
# None
# <a data-stop-code="AWJ" href="#">Arrow Junction</a>
# <a data-stop-code="ASG" href="#">Ashburton</a>
# <a data-stop-code="ATH" href="#">Athol</a>
# <a href="#"></a>
# <a data-stop-code="BFR" href="#">Balfour</a>
# <a data-stop-code="BLF" href="#">Belfast</a>
# <a data-stop-code="WPB" href="#">Bella Vist Motel (Franz Josef)</a>
# None
# <a data-stop-code="BHE" href="#">Blenheim</a>
# <a data-stop-code="BTW" href="#">Brightwater</a>
# <a data-stop-code="BMC" href="#">Bushmans Centre</a>
# <a href=""></a>
# <a data-stop-code="CUC" href="#">Canterbury University</a>
# <a data-stop-code="CVN" href="#">Canvastown</a>
# <a data-stop-code="CST" href="#">Charleston</a>
# <a data-stop-code="CHC" href="#">Christchurch - Main Stop</a>
# <a data-stop-code="CCR" href="#">Church Corner (Christchurch)</a>
# None
# None
# <a data-stop-code="CNT" href="#">C</a>
# <a data-stop-code="CYD" href="#">Clyde</a>
# <a data-stop-code="CWD" href="#">Collingwood</a>
# <a data-stop-code="CPT" href="#">Copeland Track (Karangarua)</a>
# <a data-stop-code="CMW" href="#">Cromwell</a>
# <a data-stop-code="CVD" href="#">Culverden</a>
# <a data-stop-code="DCR" href="#">Dacre</a>
# <a data-stop-code="DUD" href="#">Dunedin</a>
# None
# <a data-stop-code="DPH" href="#">Dunedin Public Hospital</a>
# <a data-stop-code="DSD" href="#">Dunsandel</a>
# <a data-stop-code="EDN" href="#">Edendale</a>
# None
# <a data-stop-code="EVD" href="#">Evansdale</a>
# <a data-stop-code="FRY" href="#"></a>
# <a data-stop-code="FRL" href="#">Fairlie</a>
# None
# <a data-stop-code="FKT" href="#">Frankton</a>
# None
# <a data-stop-="" href="#"></a>
# <a data-stop-code="WMI" href="#">Franz Josef Hotel Douglas Graham Wings</a>
# <a data-stop-code="WHF" href="#">Franz Josef Hotel Meuller Wing</a>
# <a data-stop-code="FYH" href="#">Franz Josef YHA (Franz Josef)</a>
# None
# None
# <a data-stop-code="FGR" href="#">Glacier Country Hotels (Fox Glacier)</a>
# <a data-stop-code="WGG" href="#">Glacier Gateway Motel</a>
# <a data-stop-code="GFV" href="#">Glen Fern Villas (Franz Josef)</a>
# None
# None
# <a data-stop-code="GNY" href="#">Glenorchy</a>
# None
# <a data-stop-code="GRI" href="#">Green Island (Dunedin)</a>
# <a data-stop-code="GRM" href="#">Greymouth</a>
# <a data-stop-code="HAS" href="#"></a>
# <a data-stop-code="HMP" href="#">Hampden</a>
# <a data-stop-code="HAR" href="#">Harihari</a>
# <a data-stop-code="HAW" href="#">Hawarden</a>
# None
# None
# <a data-stop-code="HIR" href="#">Hira</a>
# <a data-stop-code="HKT" href="#">Hokitika i-SITE</a>
# <a data-stop-code="HRN" href="#">Hurunui Hotel</a>
# None
# <a data-stop-code="INJ" href="#">Inangahua Junction</a>
# <a data-stop-code="IVC" href="#">Invercargill</a>
# <a data-sto="" href="#"></a>
# None
# None
# <a data-stop-code="KKR" href="#">Kaikoura</a>
# <a data-stop-code="KRI" href="#">Kaiteriteri</a>
# <a data-stop-code="KEK" href="#">Kekerengu</a>
# None
# None
# <a data-stop-code="NKH" href="#">Kingsgate Motel (Nelson)</a>
# <a data-stop-code="KWL" href="#">Knightswood Lodge (Franz Josef)</a>
# <a data-stop-code="KOR" href="#">Korere</a>
# <a data-stop-code="KMJ" href="#">Kumara Junction</a>
# <a data-stop-code="YHQ" href="#">Lake Es</a>
# <a data-stop-code="LHD" href="#">Lake Hawea Dam</a>
# <a data-stop-code="LOU" href="#">Lake Ohau Turn-off</a>
# None
# <a data-stop-code="LAW" href="#">Law</a>
# <a data-stop-code="LTF" href="#">Leithfield</a>
# <a data-stop-code="LMS" href="#">Lumsden</a>
# <a data-stop-code="MHE" href="#">Maheno</a>
# <a data-stop-code="MHT" href="#">Mahitahi Lodge</a>
# <a data-stop-code="MKK" href="#">Makikihi</a>
# <a data-stop-code="MAP" href="#">Mapua</a>
# <a data-stop-code="MSC" href="#">Mararoa School</a>
# <a data-stop-code="MYF" href="#">Mayfield</a>
# <a data-stop-code="MFN" href="#">Milford Sound</a>
# None
# None
# <a data-st="" href="#"></a>
# <a data-stop-code="MIL" href="#">Milton</a>
# <a data-stop-code="MRK" href="#">Moeraki Turn Off</a>
# <a data-stop-code="MOS" href="#">Mossburn</a>
# <a data-stop-code="MTS" href="#">Mount Somers</a>
# <a data-stop-code="MON" href="#">Mt Cook</a>
# <a data-stop-code="MCH" href="#">Murchison</a>
# <a data-stop-code="" href="#"></a>
# <a data-stop-code="NBC" href="#">Nelson College</a>
# None
# <a data-stop-code="NSI" href="#">Nelson i-SITE</a>
# <a data-stop-code="NTW" href="#">Northwood (Christchurch)</a>
# None
# <a data-stop-code="OAM" href="#">Oamaru</a>
# <a data-stop-code="OGL" href="#">Olive Grove Lodge</a>
# None
# <a data-stop-code="OMA" href="#">Omarama</a>
# <a data-stop-code="DUU" href="#">Otago University (Dunedin)</a>
# None
# <a data-stop-code="PAL" href="#">Palmerston</a>
# <a data-stop-code="PRR" href="#">Pareora</a>
# <a data-stop-code="PAO" href="#">Paroa</a>
# None
# <a data-sto="" href="#"></a>
# <a data-stop-code="PCN" href="#">Picton</a>
# <a data-stop-code="PKR" href="#">Pukerau</a>
# <a data-stop-code="PRV" href="#">Punakaiki Resort</a>
# <a data-stop-="" href="#"></a>
# None
# <a data-stop-code="ZQA" href="#">Queenstown Airport</a>
# <a data-stop-code="RAJ" href="#">Raes Junction</a>
# <a data-stop-code="RAI" href="#">Rai Valley</a>
# <a data-stop-code="FGF" href="#">Rainforest Motel (Fox Glacier)</a>
# <a data-stop-code="RGR" href="#">Rangiora</a>
# <a data-stop-code="RED" href="#">Redwood</a>
# <a data-stop-code="RIC" href="#">Riccarton Rd (Christchurch)</a>
# None
# None
# <a data-stop-code="RCH" href="#">Richmond</a>
# <a data-stop-code="RDL" href="#">Riversdale</a>
# <a data-stop-code="CHN" href="#">Rolleston Ave (Christchurch)</a>
# <a data-stop-code="RTM" href="#">Rotherham</a>
# None
# None
# <a data-stop-code="SDN" href="#">Seddon</a>
# <a data-stop-code="STA" href="#">St Andrews</a>
# None
# <a data-stop-code="SBC" href="#">St Bedes College (Papanui)</a>
# <a data-stop-code="STK" href="#">Stoke</a>
# None
# <a data-stop-code="TAN" href="#">Tahunanui</a>
# <a data-stop-code="TRS" href="#">Tarras</a>
# <a data-stop-code="TEU" href="#">Te Anau</a>
# <a data-stop-code="TPO" href="#">Tekapo</a>
# None
# None
# <a data-stop-code="TMK" href="#">T</a>
# <a data-stop-code="WTM" href="#">Terrace Motel (Franz Jozef)</a>
# <a data-stop-code="TIU" href="#">Timaru</a>
# <a data-stop-code="TRM" href="#">Tiromoana</a>
# <a data-stop-code="TUM" href="#">Tua Marina</a>
# None
# <a data-stop-code="WPS" href="#">Waihi Prep School (South Island)</a>
# <a data-stop-code="WIK" href="#">Waikari</a>
# <a data-stop-code="WKU" href="#">Waikuku</a>
# <a data-stop-code="WET" href="#">Waimate Turn Off</a>
# <a data-stop-code="WPA" href="#">Waipara</a>
# <a data-stop-code="WKF" href="#">Wakefield</a>
# None
# None
# <a data-stop-code="" href="#"></a>
# <a data-stop-code="WRD" href="#">Ward</a>
# <a data-stop-code="WSZ" href="#">Westport</a>
# <a data-stop-code="WWL" href="#">Westwood Lodge</a>
# <a data-stop-code="WCH" href="#">Winchester</a>
# <a data-stop-code="WDD" href="#">Woodend</a>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <a href="/passes/flexi-options" onclick="_gaq.push(['_trac"></a>
# None
# None
# None
# <a href="#" oncl=""></a>
# None
# None
# None
# None
# <a href="/bus-and-ferry-combos/" onclick="_gaq.pu"></a>
# None
# None
# None
# None
# <a href="/tours/" style="text-decoration:none"><span class="content-box-highlight-red"></span></a>
# None
# None
# <a href="/tours/" onclick=""></a>
# None
# None
# <a href="http://www.booking.com/index.html?aid=369493" style="text-decoration:none"><span c=""></span></a>
# None
# None
# <a href=""></a>
# None
# None
# <a href="travel-info/timetable/" style="text-decoration:none"><span class="c"></span></a>
# None
# None
# <a href="travel-info"></a>
# None
# None
# <a href="/bus-to-auckland-airport" style="text-decoration:none"><span class="content-box-hig"></span></a>
# None
# None
# <a href="/bus-to-auckland-a"></a>
# None
# None
# <a href="http://www.milford-sound.co.nz/" style="text-decoration:none"><span class="content-box-highlight-r"></span></a>
# None
# None
# <a hre=""></a>
# None
# None
# <a href="/passes/flexi-options/" sty=""></a>
# None
# None
# None
# <a href="/passes/flexi-options/" onclick="_gaq.push(['_trackEvent', 'HP Promo', 'Find Out More', 'N"></a>
# None
# None
# <a href="/about-us">About Us</a>
# <a href="/privacy-policy">Privacy</a>
# <a href="/help/">Site Map</a>
# <a href="/frequently-asked-questions/">FAQs</a>
# <a href="/delays-and-cancellations/">Delays &amp; Disruptions</a>
# <a href="/rewards">Freeway Login</a>
# <a href="/feedback">Contact Us</a>
# <a href="/tours">Tours</a>
# <a href="http://www.dolphincruises.co.nz/" target="blank">Dolphin Cruise</a>
# <a href="http://flexipass.intercity.co.nz/" target="blank">Flexipass</a>
# <a href="http://travelpass.intercity.co.nz">TravelPass</a>
# <a href="/passes/student-bus-pass/">Student Pass</a>
# <a href="http://www.facebook.com/intercity.coachlines" target="blank"><img class="left" src="assets"/></a>
# <a href="http://www.twitter.com/Inter"></a>
# None
# <a href="http://plus.google.com/100713504200361907253" target="blank"><img class="left" src="assets/intercity12/ma"/></a>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
for site in loadSite:
    print'print site'
    inter = BeautifulSoup(site)
    print inter.titlefor site in loadSite:
    print'print site'
    inter = BeautifulSoup(site)
    print inter.title
# Out:
#   File "<ipython-input-9-cbfacba43087>", line 4
#     print inter.titlefor site in loadSite:
#                             ^
# SyntaxError: invalid syntax

# %%
for site in loadSite:
    print'print site'
    inter = BeautifulSoup(site)
    print inter.title

# %%
print inter

# %%
    print inter
# Out:
#   File "<ipython-input-10-939521066744>", line 1
#     print inter
#     ^
# IndentationError: unexpected indent
